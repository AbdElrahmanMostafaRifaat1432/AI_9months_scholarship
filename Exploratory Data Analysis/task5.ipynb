# %%
import pandas as pd
import numpy as numpy

# %%
df  = pd.read_csv("italy-covid-daywise.csv" , )

# %%
df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
# number of columns
len(df.columns)
# Out:
# 4

# %%
# number of rows
len(df)
# Out:
# 248

# %%
df.select_dtypes("number").describe()
# Out:
#          new_cases  new_deaths     new_tests
# count   248.000000  248.000000    135.000000
# mean   1094.818548  143.133065  31699.674074
# std    1554.508002  227.105538  11622.209757
# min    -148.000000  -31.000000   7841.000000
# 25%     123.000000    3.000000  25259.000000
# 50%     342.000000   17.000000  29545.000000
# 75%    1371.750000  175.250000  37711.000000
# max    6557.000000  971.000000  95273.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        248 non-null    object
#  1   new_cases   248 non-null    float64
#  2   new_deaths  248 non-null    float64
#  3   new_tests   135 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 7.9+ KB

# %%
list(df.columns)
# Out:
# ['date', 'new_cases', 'new_deaths', 'new_tests']

# %%
df[df["new_cases"]>1000]
# Out:
#            date  new_cases  new_deaths  new_tests
# 68   2020-03-08     1247.0        36.0        NaN
# 69   2020-03-09     1492.0       133.0        NaN
# 70   2020-03-10     1797.0        98.0        NaN
# 72   2020-03-12     2313.0       196.0        NaN
# 73   2020-03-13     2651.0       189.0        NaN
# ..          ...        ...         ...        ...
# 241  2020-08-28     1409.0         5.0    65135.0
# 242  2020-08-29     1460.0         9.0    64294.0
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 247  2020-09-03     1326.0         6.0        NaN
#
# [72 rows x 4 columns]

# %%
df['positive_rate'] = df['new_cases']/df['new_tests']
df
# Out:
#            date  new_cases  new_deaths  new_tests  positive_rate
# 0    2019-12-31        0.0         0.0        NaN            NaN
# 1    2020-01-01        0.0         0.0        NaN            NaN
# 2    2020-01-02        0.0         0.0        NaN            NaN
# 3    2020-01-03        0.0         0.0        NaN            NaN
# 4    2020-01-04        0.0         0.0        NaN            NaN
# ..          ...        ...         ...        ...            ...
# 243  2020-08-30     1444.0         1.0    53541.0       0.026970
# 244  2020-08-31     1365.0         4.0    42583.0       0.032055
# 245  2020-09-01      996.0         6.0    54395.0       0.018311
# 246  2020-09-02      975.0         8.0        NaN            NaN
# 247  2020-09-03     1326.0         6.0        NaN            NaN
#
# [248 rows x 5 columns]

# %%
df.drop(columns=['positive_rate'] , inplace=True)
df
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
df.sort_values(by=['new_cases'] , ascending=False)
# Out:
#            date  new_cases  new_deaths  new_tests
# 82   2020-03-22     6557.0       795.0        NaN
# 87   2020-03-27     6153.0       660.0        NaN
# 81   2020-03-21     5986.0       625.0        NaN
# 89   2020-03-29     5974.0       887.0        NaN
# 88   2020-03-28     5959.0       971.0        NaN
# ..          ...        ...         ...        ...
# 28   2020-01-28        0.0         0.0        NaN
# 30   2020-01-30        0.0         0.0        NaN
# 32   2020-02-01        0.0         0.0        NaN
# 33   2020-02-02        0.0         0.0        NaN
# 172  2020-06-20     -148.0        47.0    29875.0
#
# [248 rows x 4 columns]

# %%
df['date'].dtype
# Out:
# dtype('O')

# %%
df['date'] =  pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        248 non-null    datetime64[ns]
#  1   new_cases   248 non-null    float64
#  2   new_deaths  248 non-null    float64
#  3   new_tests   135 non-null    float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 7.9 KB

# %%
df
# Out:
#           date  new_cases  new_deaths  new_tests
# 0   2019-12-31        0.0         0.0        NaN
# 1   2020-01-01        0.0         0.0        NaN
# 2   2020-01-02        0.0         0.0        NaN
# 3   2020-01-03        0.0         0.0        NaN
# 4   2020-01-04        0.0         0.0        NaN
# ..         ...        ...         ...        ...
# 243 2020-08-30     1444.0         1.0    53541.0
# 244 2020-08-31     1365.0         4.0    42583.0
# 245 2020-09-01      996.0         6.0    54395.0
# 246 2020-09-02      975.0         8.0        NaN
# 247 2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
df['day'] = df['date'].apply(lambda x:str(x).split("-")[2][0:2])

# %%
df['month'] = df['date'].apply(lambda x:str(x).split("-")[1])

# %%
df['year'] = df['date'].apply(lambda x:str(x).split("-")[0])

# %%
df['weekday'] = df['date'].apply(lambda x:str(x)[5:10])

# %%
df
# Out:
#           date  new_cases  new_deaths  new_tests day month  year weekday
# 0   2019-12-31        0.0         0.0        NaN  31    12  2019   12-31
# 1   2020-01-01        0.0         0.0        NaN  01    01  2020   01-01
# 2   2020-01-02        0.0         0.0        NaN  02    01  2020   01-02
# 3   2020-01-03        0.0         0.0        NaN  03    01  2020   01-03
# 4   2020-01-04        0.0         0.0        NaN  04    01  2020   01-04
# ..         ...        ...         ...        ...  ..   ...   ...     ...
# 243 2020-08-30     1444.0         1.0    53541.0  30    08  2020   08-30
# 244 2020-08-31     1365.0         4.0    42583.0  31    08  2020   08-31
# 245 2020-09-01      996.0         6.0    54395.0  01    09  2020   09-01
# 246 2020-09-02      975.0         8.0        NaN  02    09  2020   09-02
# 247 2020-09-03     1326.0         6.0        NaN  03    09  2020   09-03
#
# [248 rows x 8 columns]

# %%
df[df['month']=="05"][['new_cases','new_deaths','new_tests']].sum()
# Out:
# new_cases       29073.0
# new_deaths       5658.0
# new_tests     1078720.0
# dtype: float64

# %%
df[df['new_cases'] == df['new_cases'].max()]['day']
# Out:
# 82    22
# Name: day, dtype: object

# %%
df2 = df[['month' , 'new_cases' ,'new_deaths' ,'new_tests' ]].groupby('month').sum()
df2
# Out:
#        new_cases  new_deaths  new_tests
# month
# 01           3.0         0.0        0.0
# 02         885.0        21.0        0.0
# 03      100851.0     11570.0        0.0
# 04      101852.0     16091.0   419591.0
# 05       29073.0      5658.0  1078720.0
# 06        7772.0      1404.0   830354.0
# 07        6722.0       388.0   797692.0
# 08       21060.0       345.0  1098704.0
# 09        3297.0        20.0    54395.0
# 12           0.0         0.0        0.0

# %%
df2.reset_index(inplace=True)
df2
# Out:
#   month  new_cases  new_deaths  new_tests
# 0    01        3.0         0.0        0.0
# 1    02      885.0        21.0        0.0
# 2    03   100851.0     11570.0        0.0
# 3    04   101852.0     16091.0   419591.0
# 4    05    29073.0      5658.0  1078720.0
# 5    06     7772.0      1404.0   830354.0
# 6    07     6722.0       388.0   797692.0
# 7    08    21060.0       345.0  1098704.0
# 8    09     3297.0        20.0    54395.0
# 9    12        0.0         0.0        0.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
sns.lineplot(data = df , x='date' , y='new_cases' )
# Out:
# <Axes: xlabel='date', ylabel='new_cases'>
