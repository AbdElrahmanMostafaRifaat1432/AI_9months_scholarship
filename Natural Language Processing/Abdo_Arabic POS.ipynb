# %% [markdown]
# **Instruction for POS Tagging Using RNNs with Arabic Dataset**
#
# **Dataset:**
# The dataset provided is named "Assignment 2 - Arabic POS.conllu". It contains labeled data for Arabic text with Part-of-Speech (POS) tags in CoNLL-U format.
#
# **Objective:**
# Your objective is to perform Part-of-Speech (POS) tagging on Arabic text using Recurrent Neural Networks (RNNs). Specifically, you will use the Universal POS (UPOS) tags for tagging. UPOS is a standardized set of POS tags that aims to cover all languages.
#
# **Evaluation metric:**
# Accuracy
#
# **Instructions:**
# 1. **Data Preprocessing:**
#    - Load the provided dataset "Assignment 2 - Arabic POS.conllu". You can use pyconll library
#    - Preprocess the data as necessary, including tokenization
#
# 2. **Model Building:**
#    - Design an RNN-based model architecture suitable for POS tagging. You may consider using recurrent layers such as (LSTM) or (GRU).
#    - Define the input and output layers of the model. The input layer should accept sequences of tokens, and the output layer should produce the predicted UPOS tags for each token.
#
# 3. **Training:**
#
# 4. **Evaluation:**
#
# **Additional Notes:**
# - Make sure to document your code thoroughly and provide clear explanations for each step.
# - Feel free to explore different RNN architectures, hyperparameters, and optimization techniques to improve the model's accuracy.

# %% [markdown]
# ### Import used libraries

# %%
import pyconll
import numpy as np
from collections import Counter
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, TimeDistributed, Dropout, Bidirectional
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Load Dataset

# %%
conllu_file = 'Assignment 2 - Arabic POS.conllu'
data = pyconll.load_from_file(conllu_file)

# %% [markdown]
# ### Data splitting

# %%
sentences = []
pos_tags = []

for sentence in data:
    tokens = []
    tags = []
    for token in sentence:
        if token.form and token.upos:
            tokens.append(token.form)
            tags.append(token.upos)
    sentences.append(tokens)
    pos_tags.append(tags)

# %%
sentences
# Out:
# [['برلين',
#   'ترفض',
#   'حصول',
#   'شركة',
#   'اميركية',
#   'على',
#   'رخصة',
#   'تصنيع',
#   'دبابة',
#   '"',
#   'ليوبارد',
#   '"',
#   'الالمانية'],
#  ['برلين',
#   '15',
#   '-',
#   '7',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'افادت',
#   'صحيفة',
#   'الاحد',
#   'الالمانية',
#   '"',
#   'ويلت',
#   'ام',
#   'سونتاغ',
#   '"',
#   'في',
#   'عدد',
#   'ها',
#   'الصادر',
#   'غدا',
#   '،',
#   'ان',
#   'المستشار',
#   'غيرهارد',
#   'شرودر',
#   'يرفض',
#   'حصول',
#   'المجموعة',
#   'الاميركية',
#   '"',
#   'جنرال',
#   'ديناميكس',
#   '"',
#   'على',
#   'رخصة',
#   'ل',
#   'تصنيع',
#   'الدبابة',
#   'الالمانية',
#   '"',
#   'ليوبارد',
#   '2',
#   '"',
#   'عبر',
#   'شراء',
#   'المجموعة',
#   'الحكومية',
#   'الاسبانية',
#   'ل',
#   'الأسلحة',
#   '"',
#   'سانتا',
#   'بربارة',
#   '"',
#   '.'],
#  ['و',
#   'في',
#   'نيسان',
#   '/',
#   'ابريل',
#   'الماضي',
#   '،',
#   'تخلت',
#   'الدولة',
#   'الاسبانية',
#   'عن',
#   'مجموعة',
#   '"',
#   'سانتا',
#   'بربارة',
#   '"',
#   'التي',
#   'تصنع',
#   'دبابات',
#   'ليوبارد',
#   'الالمانية',
#   '،',
#   'الى',
#   '"',
#   'جنرال',
#   'ديناميكس',
#   '"',
#   'التي',
#   'تنتج',
#   'الدبابة',
#   'الاميركية',
#   '"',
#   'ام',
#   '1',
#   'ابرامس',
#   '"',
#   'المعتبرة',
#   'المنافسة',
#   'الرئيسية',
#   'ل',
#   'دبابة',
#   'ليوبارد',
#   'في',
#   'الاسواق',
#   '.'],
#  ['و',
#   'كانت',
#   'خسائر',
#   'المجموعة',
#   'الاسبانية',
#   'الرسمية',
#   'تراكمت',
#   'في',
#   'السنوات',
#   'العشر',
#   'الاخيرة',
#   'ل',
#   'تبلغ',
#   '920',
#   'مليون',
#   'يورو',
#   '.'],
#  ['و',
#   'أشارت',
#   'صحيفة',
#   'الاحد',
#   'الى',
#   'ان',
#   'المستشار',
#   'شرودر',
#   'يعتبر',
#   'ان',
#   'حصول',
#   'المجموعة',
#   'الاميركية',
#   'على',
#   'رخصة',
#   'تصنيع',
#   'ليوبارد',
#   '2',
#   'يعرض',
#   'ل',
#   'الخطر',
#   'المصالح',
#   'التكنولوجية',
#   'الاساسية',
#   'ل',
#   'ألمانيا',
#   'و',
#   'طلب',
#   'من',
#   'وزير',
#   'الدفاع',
#   'رودولف',
#   'شاربينغ',
#   'التوجه',
#   'الى',
#   'اسبانيا',
#   '.'],
#  ['و',
#   'تعذر',
#   'ل',
#   'متحدثة',
#   'ب',
#   'اسم',
#   'وزارة',
#   'الدفاع',
#   'الالمانية',
#   'ان',
#   'تؤكد',
#   'اليوم',
#   'السبت',
#   'هذه',
#   'المعلومات',
#   '.'],
#  ['و',
#   'في',
#   '21',
#   'حزيران',
#   '/',
#   'يونيو',
#   '،',
#   'شدد',
#   'وزير',
#   'الدفاع',
#   'الاسباني',
#   'فيديريكو',
#   'تريو',
#   'على',
#   'ان',
#   'العقد',
#   'الموقع',
#   'في',
#   'نهاية',
#   'عام',
#   '1998',
#   'بين',
#   'سانتا',
#   'بربارة',
#   'و',
#   'منتجي',
#   'الدبابة',
#   'الالمانية',
#   '،',
#   'ك',
#   'روس',
#   'مافييه',
#   'ورينمينتال',
#   'ل',
#   'تصنيع',
#   'الدبابة',
#   'في',
#   'اسبانيا',
#   'و',
#   'إنتاج',
#   '235',
#   'دبابة',
#   'ليوبارد',
#   '2',
#   'خلال',
#   'عشر',
#   'سنوات',
#   '،',
#   'يتضمن',
#   'بندا',
#   'ل',
#   'حماية',
#   'التكنولوجيا',
#   'الالمانية',
#   'و',
#   'يجب',
#   'في',
#   '"',
#   'جميع',
#   'الاحوال',
#   '"',
#   'ان',
#   'تحترم',
#   'ه',
#   'شركة',
#   '"',
#   'جنرال',
#   'ديناميكس',
#   '"',
#   'الاميركية',
#   '.'],
#  ['مقتل',
#   'ما',
#   'لا',
#   'يقل',
#   'عن',
#   '12',
#   'شخصا',
#   'في',
#   'مواجهات',
#   'في',
#   'احدى',
#   'اسواق',
#   'لاغوس'],
#  ['لاغوس',
#   '15',
#   '-',
#   '7',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'ذكرت',
#   'الشرطة',
#   'النيجيرية',
#   'اليوم',
#   'السبت',
#   'ان',
#   'ما',
#   'لا',
#   'يقل',
#   'عن',
#   '12',
#   'شخصا',
#   'قتلوا',
#   'في',
#   'مواجهات',
#   'استمرت',
#   'يومين',
#   'في',
#   'سوق',
#   'في',
#   'لاغوس',
#   'بين',
#   'تجار',
#   'و',
#   'زقاقيين',
#   '.'],
#  ['و',
#   'أعلن',
#   'متحدث',
#   'ب',
#   'اسم',
#   'الشرطة',
#   'ل',
#   'وكالة',
#   'فرانس',
#   'برس',
#   'ان',
#   'المواجهات',
#   'التي',
#   'بدأت',
#   'الخميس',
#   'بين',
#   'التجار',
#   'في',
#   'سوق',
#   'الابا',
#   'في',
#   'لاغوس',
#   '،',
#   'و',
#   'عدد',
#   'من',
#   'الزقاقيين',
#   '،',
#   'اسفرت',
#   'ايضا',
#   'عن',
#   'اصابة',
#   'عدد',
#   'من',
#   'الاشخاص',
#   'ب',
#   'جروح',
#   '.'],
#  ['و',
#   'بدأت',
#   'اعمال',
#   'العنف',
#   'فيما',
#   'كان',
#   'الزقاقيون',
#   'يحاولون',
#   'نهب',
#   'المحلات',
#   'التجارية',
#   'ب',
#   'حجة',
#   'أن',
#   'هم',
#   'يبحثون',
#   'عن',
#   'سارق',
#   '.'],
#  ['و',
#   'استمرت',
#   'المواجهات',
#   'حتى',
#   'يوم',
#   'الجمعة',
#   'عندما',
#   'تمكنت',
#   'الشرطة',
#   'من',
#   'فرض',
#   'النظام',
#   'مجددا',
#   '.'],
#  ['و',
#   'لم',
#   'يتم',
#   'اعتقال',
#   'احد',
#   'ب',
#   'حسب',
#   'المتحدث',
#   'ب',
#   'اسم',
#   'الشرطة',
#   '.'],
#  ['هذا', 'اليوم', 'في', 'التاريخ', '16', 'تموز', '/', 'يوليو'],
#  ['1945',
#   '-',
#   'الولايات',
#   'المتحدة',
#   'تقوم',
#   'ب',
#   'اختبار',
#   'اول',
#   'قنبلة',
#   'نووية',
#   'في',
#   'نيومكسيكو',
#   '.'],
#  ['1948',
#   '-',
#   'الحرب',
#   'العربية',
#   'الاسرائيلية',
#   ':',
#   'مجلس',
#   'الامن',
#   'الدولي',
#   'يتبنى',
#   'مشروع',
#   'قرار',
#   'اميركي',
#   'يرى',
#   'في',
#   'الحرب',
#   '"',
#   'خطرا',
#   'على',
#   'السلام',
#   'العالمي',
#   'و',
#   'يدعو',
#   'الى',
#   'وقف',
#   'القتال',
#   'خلال',
#   'ثلاثة',
#   'ايام',
#   'تحت',
#   'طائلة',
#   'فرض',
#   'عقوبات',
#   'اقتصادية',
#   'و',
#   'عسكرية',
#   'على',
#   'من',
#   'يخالف',
#   'ذلك',
#   '"',
#   '.'],
#  ['1951',
#   '-',
#   'بلجيكا',
#   ':',
#   'الملك',
#   'ليوبولد',
#   'الثاني',
#   'يتنازل',
#   'عن',
#   'العرش',
#   'ل',
#   'ابن',
#   'ه',
#   'بودوان',
#   'بعد',
#   'حركة',
#   'شعبية',
#   'واسعة',
#   'طالبت',
#   'ب',
#   'عزل',
#   'ه',
#   '.'],
#  ['1955',
#   '-',
#   'الرئيس',
#   'السوري',
#   'الاسبق',
#   'شكري',
#   'القوتلي',
#   'يعود',
#   'الى',
#   'سوريا',
#   'بعد',
#   'ان',
#   'امضى',
#   'في',
#   'منفى',
#   'ه',
#   'في',
#   'مصر',
#   'ست',
#   'سنوات',
#   '.'],
#  ['1965',
#   '-',
#   'الاتحاد',
#   'السوفياتي',
#   'يطلق',
#   'خمسة',
#   'اقمار',
#   'اصطناعية',
#   '"',
#   'كوسموس',
#   '"',
#   'على',
#   'متن',
#   'صاروخ',
#   'فضائي',
#   'واحد',
#   '.'],
#  ['1979',
#   '-',
#   'نائب',
#   'رئيس',
#   'مجلس',
#   'قيادة',
#   'الثورة',
#   'في',
#   'العراق',
#   'صدام',
#   'حسين',
#   'يصبح',
#   'رئيسا',
#   'ل',
#   'الدولة',
#   'بعد',
#   'غياب',
#   'حسن',
#   'البكر',
#   'عن',
#   'الساحة',
#   'السياسية',
#   '.'],
#  ['1985', '-', 'وفاة', 'الكاتب', 'الالماني', 'هاينريش', 'بول', '.'],
#  ['1989', '-', 'وفاة', 'قائد', 'الاوكسترا', 'هيربرت', 'فون', 'كارايان', '.'],
#  ['1995',
#   '-',
#   'وزير',
#   'الخارجية',
#   'السعودي',
#   'الامير',
#   'سعود',
#   'الفيصل',
#   'يعلن',
#   'تطبيع',
#   'العلاقات',
#   'الدبلوماسية',
#   'بين',
#   'السعودية',
#   'و',
#   'الأردن',
#   'بعد',
#   'قطيعة',
#   'دامت',
#   'خمس',
#   'سنوات',
#   '.'],
#  ['1995',
#   '-',
#   'اقالة',
#   'وزير',
#   'الدفاع',
#   'العراقي',
#   'علي',
#   'حسن',
#   'المجيد',
#   'من',
#   'منصب',
#   'ه',
#   'و',
#   'تكليف',
#   'ه',
#   'مهام',
#   'في',
#   'حزب',
#   'البعث',
#   'الحاكم',
#   '.'],
#  ['1995',
#   '-',
#   'العراق',
#   'يفرج',
#   'عن',
#   'اثنين',
#   'من',
#   'الاميركيين',
#   'بعد',
#   'سجن',
#   'هما',
#   '113',
#   'يوما',
#   'ب',
#   'تهمة',
#   'عبور',
#   'الحدود',
#   'العراقية',
#   'الكويتية',
#   'ب',
#   'طريقة',
#   'غير',
#   'شرعية',
#   '.'],
#  ['هذا', 'اليوم', 'في', 'التاريخ', '17', 'تموز', '/', 'يوليو'],
#  ['1913',
#   '-',
#   'مولد',
#   'الكاتب',
#   'و',
#   'الفيلسوف',
#   'الفرنسي',
#   'روجيه',
#   'غارودي',
#   '.'],
#  ['1918',
#   '-',
#   'الثورة',
#   'البلشفية',
#   'تعدم',
#   'قيصر',
#   'روسيا',
#   'نيكةلاس',
#   'اتلثاني',
#   'و',
#   'أفراد',
#   'عائلة',
#   'ه',
#   '.'],
#  ['1945',
#   '-',
#   'افتتاح',
#   'مؤتمر',
#   'بوتسدام',
#   'بين',
#   'قادة',
#   'الاتحاد',
#   'السوفياتي',
#   'و',
#   'بريطانيا',
#   'و',
#   'الولايات',
#   'المتحدة',
#   'الذي',
#   'رسم',
#   'حدود',
#   'الدول',
#   'الاوروبية',
#   'بعد',
#   'الحرب',
#   'العالمية',
#   'الثانية',
#   '.'],
#  ['1951',
#   '-',
#   'اغتيال',
#   'رياض',
#   'الصلح',
#   'في',
#   'عمان',
#   'على',
#   'يد',
#   'ثلاثة',
#   'من',
#   'اعضاء',
#   'الحزب',
#   'القومي',
#   'السوري',
#   'الاجتماعي',
#   'ردا',
#   'على',
#   'اعدام',
#   'مؤسس',
#   'و',
#   'زعيم',
#   'الحزب',
#   'انطون',
#   'سعادة',
#   'في',
#   '1949',
#   '.'],
#  ['1958',
#   '-',
#   'اثر',
#   'سقوط',
#   'النظام',
#   'الملكي',
#   'الهاشمي',
#   'في',
#   'العراق',
#   '،',
#   'وصلت',
#   'قوات',
#   'بريطانية',
#   'الى',
#   'الاردن',
#   'ب',
#   'طلب',
#   'من',
#   'الملك',
#   'حسين',
#   '.'],
#  ['1968',
#   '-',
#   'انقلاب',
#   'عسكري',
#   'في',
#   'العراق',
#   'يطيح',
#   'نظام',
#   'عبد',
#   'الرحمن',
#   'عارف',
#   'و',
#   'مجلس',
#   'قيادة',
#   'الثورة',
#   'يختار',
#   'احمد',
#   'حسن',
#   'البكر',
#   'رئيسا',
#   'ل',
#   'الجمهورية',
#   '.'],
#  ['1971',
#   '-',
#   'العاهل',
#   'الاردني',
#   'الملك',
#   'حسين',
#   'يلغي',
#   'الاتفاقات',
#   'التي',
#   'تسمح',
#   'ل',
#   'التنظيمات',
#   'الفلسطينية',
#   'ب',
#   'إقامة',
#   'قواعد',
#   'ل',
#   'ها',
#   'في',
#   'الاردن',
#   '.'],
#  ['1973',
#   '-',
#   'توقيع',
#   '"',
#   'ميثاق',
#   'ل',
#   'العمل',
#   'الوطني',
#   '"',
#   'بين',
#   'حزب',
#   'البعث',
#   'الحاكم',
#   'في',
#   'العراق',
#   'و',
#   'الحزب',
#   'الشيوعي',
#   'العراقي',
#   '.'],
#  ['1979',
#   '-',
#   'نيكاراغوا',
#   ':',
#   'الجنرال',
#   'سوموزا',
#   'يتخلى',
#   'عن',
#   'الحكم',
#   'بعد',
#   'معارك',
#   'استمرت',
#   'خمسة',
#   'اسابيع',
#   'ضد',
#   'الساندينيين',
#   'و',
#   'أسفرت',
#   'عن',
#   'مقتل',
#   'حوالي',
#   '40',
#   'الف',
#   'مدني',
#   '.'],
#  ['1987',
#   '-',
#   'قطع',
#   'العلاقات',
#   'الدبلوماسية',
#   'بين',
#   'فرنسا',
#   'و',
#   'إيران',
#   'اثر',
#   'رفض',
#   'مترجم',
#   'السفارة',
#   'الايرانية',
#   'في',
#   'باريس',
#   'وحيد',
#   'غورجي',
#   'المثول',
#   'امام',
#   'القضاء',
#   'في',
#   'اطار',
#   'التحقيق',
#   'في',
#   'اعتداءات',
#   'وقعت',
#   'في',
#   '1986',
#   'في',
#   'باريس',
#   '.'],
#  ['1998',
#   '-',
#   'الاسد',
#   'في',
#   'باريس',
#   'ل',
#   'المرة',
#   'الاولى',
#   'منذ',
#   '22',
#   'عاما',
#   'و',
#   'الزيارة',
#   'استغرقت',
#   'ثلاثة',
#   'ايام',
#   '.',
#   'و',
#   'في',
#   'اليوم',
#   'ذات',
#   'ه',
#   '،',
#   'زارت',
#   'بارجتان',
#   'بريطانيتان',
#   'ل',
#   'أول',
#   'مرة',
#   'منذ',
#   '48',
#   'عاما',
#   '،',
#   'مرفأ',
#   'اللاذقية',
#   'السوري',
#   '.'],
#  ['1998',
#   '-',
#   'صنعاء',
#   'تتهم',
#   'الرياض',
#   'ب',
#   'احتلال',
#   'مناطق',
#   'حدودية',
#   '.',
#   'السعوديون',
#   'اكدوا',
#   'في',
#   '21',
#   'من',
#   'الشهر',
#   'ذات',
#   'ه',
#   'حصول',
#   '"',
#   'حوادث',
#   '"',
#   'ادت',
#   'الى',
#   'مقتل',
#   'ثلاثة',
#   'يمنيين',
#   'و',
#   'إصابة',
#   'تسعة',
#   'آخرين',
#   'ب',
#   'جروح',
#   '.',
#   'و',
#   'في',
#   '27',
#   'من',
#   'الشهر',
#   'نفس',
#   'ه',
#   '،',
#   'تفاهم',
#   'البلدان',
#   'على',
#   'اجراءات',
#   'ل',
#   'منع',
#   'تكرار',
#   'مثل',
#   'هذه',
#   'الحوادث',
#   '.'],
#  ['مقتل',
#   'شخصين',
#   'و',
#   'إصابة',
#   'آخر',
#   'ب',
#   'جروح',
#   'في',
#   'حرائق',
#   'في',
#   'بلغاريا'],
#  ['صوفيا',
#   '16',
#   '-',
#   '7',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'اعلن',
#   'بيان',
#   'ل',
#   'المركز',
#   'الصحافي',
#   'التابع',
#   'ل',
#   'الحكومة',
#   'البلغارية',
#   'ان',
#   'رجلين',
#   'قتلا',
#   'و',
#   'أصيب',
#   'شخص',
#   'آخر',
#   'ب',
#   'جروح',
#   'خطرة',
#   'امس',
#   'السبت',
#   'في',
#   'حرائق',
#   'اندلعت',
#   'في',
#   'الايام',
#   'الاخيرة',
#   'في',
#   'بلغاريا',
#   '.'],
#  ['و',
#   'أوضح',
#   'المصدر',
#   'ان',
#   'دينتشو',
#   'دينيف',
#   '(',
#   '72',
#   'عاما',
#   ')',
#   'التهمت',
#   'ه',
#   'النيران',
#   'حيا',
#   'ليل',
#   'الجمعة',
#   'السبت',
#   'في',
#   'منزل',
#   'ه',
#   'في',
#   'بلدة',
#   'دراغانوفو',
#   'في',
#   'منطقة',
#   'ترنوفو',
#   '(',
#   'شمال',
#   'شرق',
#   ')',
#   '.'],
#  ['و',
#   'توفي',
#   'ديانكو',
#   'ديانكوف',
#   '(',
#   '66',
#   'عاما',
#   ')',
#   'ليل',
#   'الجمعة',
#   'السبت',
#   'في',
#   'مستشفى',
#   'مدينة',
#   'بورغاس',
#   '(',
#   'جنوب',
#   'شرق',
#   ')',
#   'متاثرا',
#   'ب',
#   'جروح',
#   'ه',
#   'التي',
#   'غطت',
#   '90',
#   '%',
#   'من',
#   'جسد',
#   'ه',
#   'اثر',
#   'حريق',
#   'اندلع',
#   'الخميس',
#   'في',
#   'منطقة',
#   'هاسكوفو',
#   '(',
#   'جنوب',
#   ')',
#   '.'],
#  ['و',
#   'كان',
#   'شخص',
#   'آخر',
#   '،',
#   'اتاناس',
#   'يانف',
#   '(',
#   '54',
#   'عاما',
#   ')',
#   'يصارع',
#   'امس',
#   'السبت',
#   'الموت',
#   'في',
#   'مستشفى',
#   'بورغاس',
#   'ايضا',
#   'اثر',
#   'إصابة',
#   'ه',
#   'الخميس',
#   'ب',
#   'حروق',
#   'بليغة',
#   '.'],
#  ['و',
#   'كانت',
#   'ست',
#   'حرائق',
#   'لا',
#   'تزال',
#   'مشتعلة',
#   'امس',
#   'السبت',
#   'في',
#   'وسط',
#   'جنوبي',
#   'و',
#   'جنوب',
#   'شرقي',
#   'البلاد',
#   '.'],
#  ['و',
#   'قال',
#   'الكسندر',
#   'براماتارسكي',
#   '،',
#   'وزير',
#   'الحالات',
#   'الطارئة',
#   '"',
#   'ان',
#   'الوضع',
#   'يعود',
#   'الى',
#   'طبيعة',
#   'ه',
#   'و',
#   'لٰكن',
#   'من',
#   'غير',
#   'المستبعد',
#   'ان',
#   'تنشب',
#   'حرائق',
#   'اخرى',
#   '"',
#   '.'],
#  ['و',
#   'شارك',
#   '1200',
#   'رجل',
#   'من',
#   'رجال',
#   'الاطفاء',
#   'و',
#   'ألف',
#   'جندي',
#   'و',
#   '150',
#   'متطوعا',
#   'من',
#   'الدفاع',
#   'المدني',
#   'اول',
#   'من',
#   'امس',
#   'الجمعة',
#   'في',
#   'مكافحة',
#   'الحرائق',
#   'في',
#   'البلاد',
#   '.'],
#  ['الولايات',
#   'المتحدة',
#   'تريد',
#   'تكثيف',
#   'وتيرة',
#   'المفاوضات',
#   'في',
#   'كامب',
#   'ديفيد'],
#  ['ثورمونت',
#   '(',
#   'الولايات',
#   'المتحدة',
#   ')',
#   '16',
#   '-',
#   '7',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'اعلنت',
#   'الولايات',
#   'المتحدة',
#   'مساء',
#   'امس',
#   'السبت',
#   'عزم',
#   'ها',
#   'على',
#   'تكثيف',
#   'وتيرة',
#   'مفاوضات',
#   'السلام',
#   'الاسرائيلية',
#   'الفلسطينية',
#   'في',
#   'قمة',
#   'كامب',
#   'ديفيد',
#   'في',
#   'محاولة',
#   'ل',
#   'التوصل',
#   'الى',
#   'اتفاق',
#   'حول',
#   'الملفات',
#   'الكبرى',
#   'ل',
#   'الحل',
#   'النهائي',
#   'ل',
#   'النزاع',
#   'قبل',
#   'مغادرة',
#   'الرئيس',
#   'بيل',
#   'كلينتون',
#   'الى',
#   'قمة',
#   'مجموعة',
#   'الثماني',
#   'الاربعاء',
#   'المقبل',
#   '.'],
#  ['و',
#   'قال',
#   'احد',
#   'المتحدثين',
#   'ب',
#   'اسم',
#   'البيت',
#   'الابيض',
#   'بي',
#   'جي',
#   'كراولي',
#   '"',
#   'اعتقد',
#   'ب',
#   'أن',
#   'نا',
#   'س',
#   'نسعى',
#   'الى',
#   'تكثيف',
#   'هذه',
#   'المحادثات',
#   'فيما',
#   'نصل',
#   'الى',
#   'اليوم',
#   'السادس',
#   'من',
#   'القمة',
#   '"',
#   '.'],
#  ['و',
#   'أضاف',
#   '"',
#   'لا',
#   'نزال',
#   'نرغب',
#   'في',
#   'التوصل',
#   'الى',
#   'اتفاق',
#   'حول',
#   'المسائل',
#   'التي',
#   'تشكل',
#   'صلب',
#   'الوضع',
#   'النهائي',
#   '(',
#   'ل',
#   'الأراضي',
#   'الفلسطينية',
#   ')',
#   'قبل',
#   'توجه',
#   'الرئيس',
#   'الى',
#   'طوكيو',
#   '"',
#   '.'],
#  ['و',
#   'قرر',
#   'الرئيس',
#   'الاميركي',
#   'ان',
#   'يغادر',
#   'الاربعاء',
#   'صباحا',
#   'الولايات',
#   'المتحدة',
#   'ل',
#   'المشاركة',
#   'في',
#   'آخر',
#   'قمة',
#   'ل',
#   'ه',
#   'ل',
#   'مجموعة',
#   'الثماني',
#   '(',
#   'الدول',
#   'الصناعية',
#   'الكبرى',
#   'السبع',
#   'و',
#   'روسيا',
#   ')',
#   'التي',
#   'س',
#   'تجري',
#   'في',
#   'جزيرة',
#   'اوكيناوا',
#   'و',
#   'س',
#   'يعود',
#   'الى',
#   'واشنطن',
#   'الاحد',
#   'في',
#   '23',
#   'الجاري',
#   '.',
#   'و',
#   'س',
#   'يجري',
#   'على',
#   'هامش',
#   'القمة',
#   'محادثات',
#   'ثنائية',
#   'مع',
#   'الرئيس',
#   'الروسي',
#   'فلاديمير',
#   'بوتين',
#   '.'],
#  ['و',
#   'كان',
#   'المتحدث',
#   'الاميركي',
#   'اشار',
#   'امس',
#   'الى',
#   'ان',
#   'محادثات',
#   'قمة',
#   'كامب',
#   'ديفيد',
#   'اتسمت',
#   'ب',
#   'طابع',
#   'اقل',
#   'رسمية',
#   'من',
#   'الايام',
#   'السابقة',
#   'ب',
#   'سبب',
#   'العطلة',
#   'الاسبوعية',
#   'لدى',
#   'اليهود',
#   '.'],
#  ['دراسة',
#   ':',
#   'العنف',
#   'المنزلي',
#   'في',
#   'الولايات',
#   'المتحدة',
#   'يطال',
#   '25',
#   '%',
#   'من',
#   'النساء',
#   'و',
#   '7،5',
#   'من',
#   'الرجال'],
#  ['واشنطن',
#   '16',
#   '-',
#   '7',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'افادت',
#   'دراسة',
#   'نشر',
#   'ها',
#   'امس',
#   'السبت',
#   'المعهد',
#   'الوطني',
#   'ل',
#   'العدالة',
#   'ان',
#   'العنف',
#   'المنزلي',
#   'في',
#   'الولايات',
#   'المتحدة',
#   'يطال',
#   'ربع',
#   'النساء',
#   'تقريبا',
#   'خلال',
#   'حياة',
#   'هم',
#   '.'],
#  ['و',
#   'أوضحت',
#   'هذه',
#   'الدراسة',
#   'التي',
#   'اجريت',
#   'لدى',
#   'ثمانية',
#   'الاف',
#   'امرأة',
#   'و',
#   'ثمانية',
#   'الاف',
#   'رجل',
#   '،',
#   'ان',
#   'نحو',
#   '25',
#   '%',
#   'من',
#   'النساء',
#   'و',
#   '7،5',
#   '%',
#   'من',
#   'الرجال',
#   'يتعرضون',
#   'مرة',
#   'واحدة',
#   'في',
#   'حياة',
#   'هم',
#   'ل',
#   'الاغتصاب',
#   'او',
#   'الاعتداء',
#   'الجسدي',
#   'من',
#   'قبل',
#   'الزوج',
#   '(',
#   'الحالي',
#   'او',
#   'السابق',
#   ')',
#   'او',
#   'الشريك',
#   'الجنسي',
#   '.'],
#  ['و',
#   'ذكر',
#   'المعهد',
#   'الوطني',
#   'ل',
#   'العدالة',
#   'ان',
#   'قرابة',
#   '1،5',
#   '%',
#   'من',
#   'النساء',
#   'و',
#   '0،9',
#   '%',
#   'من',
#   'الرجال',
#   'الذين',
#   'شملت',
#   'هم',
#   'الدراسة',
#   '،',
#   'اي',
#   'ما',
#   'يساوي',
#   '1،5',
#   'مليون',
#   'امرأة',
#   'و',
#   '834732',
#   'رجلا',
#   'من',
#   'مجمل',
#   'السكان',
#   '،',
#   'تعرضوا',
#   'ل',
#   'هٰذا',
#   'النوع',
#   'من',
#   'العنف',
#   'خلال',
#   'الاشهر',
#   '12',
#   'التي',
#   'سبقت',
#   'التحقيق',
#   '.'],
#  ['و',
#   'من',
#   'جهة',
#   'اخرى',
#   '،',
#   'هناك',
#   'ضحايا',
#   'يتعرضون',
#   'ل',
#   'أعمال',
#   'عنف',
#   'مرات',
#   'عدة',
#   'في',
#   'السنة',
#   '،',
#   'ف',
#   'النساء',
#   'يتعرضن',
#   'ل',
#   'مثل',
#   'هذه',
#   'الاعمال',
#   '4،9',
#   'ملايين',
#   'مرة',
#   'تقريبا',
#   'و',
#   'الرجال',
#   '2،9',
#   'مليون',
#   'مرة',
#   'في',
#   'السنة',
#   '.'],
#  ['و',
#   'أخيرا',
#   'اشارت',
#   'الدراسة',
#   'الى',
#   'ان',
#   '41،5',
#   '%',
#   'من',
#   'النساء',
#   'اللواتي',
#   'يتعرضن',
#   'ل',
#   'العنف',
#   'الجسدي',
#   'من',
#   'قبل',
#   'شريك',
#   'حميم',
#   '،',
#   'اصبن',
#   'ب',
#   'جروح',
#   'خلال',
#   'تعرض',
#   'هن',
#   'ل',
#   'الاعتداء',
#   'الاخير',
#   'مقابل',
#   '19،9',
#   '%',
#   'ل',
#   'الرجال',
#   '.'],
#  ['العثور',
#   'على',
#   'جثة',
#   'تاسعة',
#   'في',
#   'مخيم',
#   'منكوب',
#   'ب',
#   'إعصار',
#   'اجتاحا',
#   'البرتا'],
#  ['باين',
#   'لايك',
#   '(',
#   'كندا',
#   ')',
#   '16',
#   '-',
#   '7',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'اعلنت',
#   'الشرطة',
#   'الملكية',
#   'في',
#   'كندا',
#   'العثور',
#   'على',
#   'جثة',
#   'تاسعة',
#   'في',
#   'مخيم',
#   'اجتاح',
#   'ه',
#   'اعصار',
#   'في',
#   'باين',
#   'لايك',
#   'في',
#   'البرتا',
#   '(',
#   'غرب',
#   ')',
#   'و',
#   'أدى',
#   'ايضا',
#   'الى',
#   'اصابة',
#   'اكثر',
#   'من',
#   '200',
#   'شخص',
#   'ب',
#   'جروح',
#   '.'],
#  ['و',
#   'تخشى',
#   'السلطات',
#   'من',
#   'ارتفاع',
#   'عدد',
#   'الضحايا',
#   'اذ',
#   'ان',
#   'رجال',
#   'الاسعاف',
#   'الذين',
#   'ارسلوا',
#   'الى',
#   'مكان',
#   'الكارثة',
#   'و',
#   'عدد',
#   'هم',
#   'يزيد',
#   'عن',
#   'المائة',
#   '،',
#   'لم',
#   'يتمكنوا',
#   'عند',
#   'منتصف',
#   'النهار',
#   'امس',
#   'الا',
#   'من',
#   'تمشيط',
#   'ربع',
#   'المخيم',
#   'بحثا',
#   'عن',
#   'الضحايا',
#   'بين',
#   'الانقاض',
#   '.'],
#  ['و',
#   'كان',
#   'رجال',
#   'الانقاذ',
#   'و',
#   'بين',
#   'هم',
#   'غطاسون',
#   '،',
#   'لا',
#   'يزالون',
#   'يبحثون',
#   'في',
#   'بحيرة',
#   'قرب',
#   'المخيم',
#   'اذ',
#   'ان',
#   'عددا',
#   'من',
#   'الاشخاص',
#   'كانوا',
#   'يبحرون',
#   'في',
#   'ها',
#   'على',
#   'متن',
#   'الزوارق',
#   'اثناء',
#   'العاصفة',
#   '.',
#   'و',
#   'قال',
#   'عنصر',
#   'من',
#   'الشرطة',
#   'الملكية',
#   'الكندية',
#   '،',
#   'باتريك',
#   'ويب',
#   '"',
#   'ان',
#   'الابحاث',
#   'مستمرة',
#   '"',
#   '.'],
#  ['و',
#   'بين',
#   'الجرحى',
#   '،',
#   'اعتبر',
#   '16',
#   'أن',
#   'هم',
#   'في',
#   'حال',
#   'خطرة',
#   '.'],
#  ['الجمارك', 'البلغارية', 'تضبط', 'نحو', '40', 'كيلوغراما', 'من', 'الهيرويين'],
#  ['صوفيا',
#   '16',
#   '-',
#   '7',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'ضبط',
#   'رجال',
#   'الجمارك',
#   'البلغارية',
#   'امس',
#   'السبت',
#   'في',
#   'مركز',
#   '"',
#   'كابيتان',
#   'اندرييفو',
#   '"',
#   'على',
#   'الحدود',
#   'البلغارية',
#   'التركية',
#   '،',
#   'على',
#   '39،56',
#   'كيلوغراما',
#   'من',
#   'الهيرويين',
#   '،',
#   'كما',
#   'اعلن',
#   'متحدث',
#   'ب',
#   'اسم',
#   'الجمارك',
#   '.'],
#  ['و',
#   'عثر',
#   'على',
#   'هذه',
#   'المخدرات',
#   'التي',
#   'قدرت',
#   'قيمة',
#   'ها',
#   'ب',
#   '4،3',
#   'ملايين',
#   'يورو',
#   '،',
#   'في',
#   'باص',
#   'كان',
#   'قادما',
#   'من',
#   'تركيا',
#   'و',
#   'متوجها',
#   'الى',
#   'البانيا',
#   '.'],
#  ['و',
#   'أوضح',
#   'المتحدث',
#   'ب',
#   'اسم',
#   'قيادة',
#   'الجمارك',
#   'البلغارية',
#   'ايفان',
#   'كوتيفسكي',
#   '،',
#   'ان',
#   'الهيرويين',
#   'كانت',
#   'في',
#   '76',
#   'علبة',
#   'موضوعة',
#   'في',
#   'مخبأ',
#   'اعد',
#   'في',
#   'سقف',
#   'الباص',
#   '.'],
#  ['و',
#   'أشار',
#   'المصدر',
#   'نفس',
#   'ه',
#   'الى',
#   'ان',
#   'سائقي',
#   'الباص',
#   'الثلاثة',
#   'و',
#   'هم',
#   'مواطنان',
#   'تركيان',
#   'و',
#   'مقدوني',
#   '،',
#   'اوقفوا',
#   'و',
#   'تم',
#   'فتح',
#   'تحقيق',
#   '.'],
#  ['و',
#   'منذ',
#   'مطلع',
#   'هذا',
#   'العام',
#   '،',
#   'ضبط',
#   'على',
#   '775،56',
#   'كيلوغراما',
#   'من',
#   'الهيرويين',
#   'في',
#   'مركز',
#   'كابيتان',
#   'اندرييفو',
#   'الحدودي',
#   '.'],
#  ['خلاف',
#   'بين',
#   'لندن',
#   'و',
#   'بكين',
#   'حول',
#   'التحقيق',
#   'في',
#   'قضية',
#   'الضحايا',
#   'المهاجرين'],
#  ['لندن',
#   '16',
#   '-',
#   '7',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'ذكرت',
#   'صحيفة',
#   '"',
#   'صنداي',
#   'تلغراف',
#   '"',
#   'اليوم',
#   'الاحد',
#   'ان',
#   'الصين',
#   'و',
#   'بريطانيا',
#   'رفضتا',
#   'منح',
#   'تاشيرات',
#   'ل',
#   'ممثلي',
#   'كل',
#   'من',
#   'هما',
#   'المكلفين',
#   'التحقيق',
#   'في',
#   'وفاة',
#   '58',
#   'مهاجرا',
#   'صينيا',
#   'غير',
#   'شرعي',
#   'الشهر',
#   'الماضي',
#   'داخل',
#   'حافلة',
#   'ل',
#   'نقل',
#   'البضائع',
#   '.'],
#  ['و',
#   'أشارت',
#   'الصحيفة',
#   'الى',
#   'ان',
#   'السلطات',
#   'الصينية',
#   'رفضت',
#   'منح',
#   'تاشيرات',
#   'الى',
#   'عناصر',
#   'من',
#   'رجال',
#   'الشرطة',
#   'البريطانية',
#   'كانوا',
#   'يريدون',
#   'فتح',
#   'تحقيق',
#   'حول',
#   'ماضي',
#   'الضحايا',
#   'الذين',
#   'عثر',
#   'علي',
#   'هم',
#   'مختنقين',
#   'في',
#   '18',
#   'حزيران',
#   '/',
#   'يونيو',
#   'بعد',
#   'ان',
#   'نقلت',
#   'شاحنة',
#   'هم',
#   'على',
#   'متن',
#   'سفينة',
#   'من',
#   'بلجيكا',
#   'الى',
#   'دوفر',
#   '.'],
#  ['و',
#   'نقلت',
#   'صنداي',
#   'تلغراف',
#   'عن',
#   'مسؤول',
#   'بريطاني',
#   'قول',
#   'ه',
#   'ان',
#   'السلطات',
#   'الصينية',
#   'رفضت',
#   'منح',
#   'التاشيرات',
#   'ب',
#   'سبب',
#   'تحفظات',
#   'لندن',
#   'ب',
#   'السماح',
#   'ل',
#   'مسؤولين',
#   'صينيين',
#   'ب',
#   'الدخول',
#   'الى',
#   'بريطانيا',
#   'ل',
#   'استجواب',
#   'اثنين',
#   'من',
#   'الناجين',
#   'من',
#   'هذه',
#   'الماساة',
#   '.'],
#  ['و',
#   'أضاف',
#   'المسؤول',
#   '"',
#   'إن',
#   'هم',
#   '(',
#   'الصينيون',
#   ')',
#   'يريدون',
#   'ان',
#   'يصعبوا',
#   'ل',
#   'نا',
#   'الامور',
#   'لأن',
#   'نا',
#   'لا',
#   'نسمح',
#   'ل',
#   'هم',
#   'ب',
#   'التحدث',
#   'الى',
#   'الباقين',
#   'على',
#   'قيد',
#   'الحياة',
#   '.',
#   'و',
#   'كان',
#   'من',
#   'المقرر',
#   'ان',
#   'نسافر',
#   'يوم',
#   'الاثنين',
#   'و',
#   'لٰكن',
#   'الصينيين',
#   'يؤخرون',
#   'المعاملات',
#   '"',
#   'و',
#   'أضاف',
#   '"',
#   'إن',
#   'ه',
#   'امر',
#   'كلاسيكي',
#   'يندرج',
#   'في',
#   'اطار',
#   'المعاملة',
#   'ب',
#   'المثل',
#   '"',
#   '.'],
#  ['و',
#   'أشارت',
#   'الصحيفة',
#   'الى',
#   'ان',
#   'لندن',
#   'لا',
#   'تسمح',
#   'ل',
#   'مسؤولين',
#   'صينيين',
#   'ب',
#   'الدخول',
#   'الى',
#   'بريطانيا',
#   'ب',
#   'سبب',
#   'احتمال',
#   'القيام',
#   'ب',
#   'أعمال',
#   'انتقامية',
#   'ضد',
#   'اعضاء',
#   'من',
#   'عائلات',
#   'الناجين',
#   'لا',
#   'يزالون',
#   'في',
#   'الصين',
#   '.'],
#  ['و',
#   'أكدت',
#   'صنداي',
#   'تلغراف',
#   'ان',
#   'المحققين',
#   'البريطانيين',
#   'تمكنوا',
#   'من',
#   'تحديد',
#   'هوية',
#   'معظم',
#   'الضحايا',
#   'و',
#   'لٰكن',
#   'هم',
#   'يرغبون',
#   'في',
#   'التحقق',
#   'من',
#   'هوية',
#   'عدد',
#   'من',
#   'هم',
#   'ب',
#   'التوجه',
#   'الى',
#   'مسقط',
#   'رأس',
#   'هم',
#   'في',
#   'محافظة',
#   'فوجيان',
#   'ل',
#   'الحصول',
#   'على',
#   'عينات',
#   'من',
#   'الحمض',
#   'الريبي',
#   'النووي',
#   '.'],
#  ['عرفات', 'فى', 'فيتنام', 'ل', 'عدة', 'ساعات'],
#  ['هانوي',
#   '15',
#   '-',
#   '8',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'اعلنت',
#   'وزارة',
#   'الخارجية',
#   'الفيتنامية',
#   'ان',
#   'الرئيس',
#   'الفلسطيني',
#   'ياسر',
#   'عرفات',
#   'وصل',
#   'اليوم',
#   'الثلاثاء',
#   'الى',
#   'هانوي',
#   'فى',
#   'زيارة',
#   'عمل',
#   'ل',
#   'فيتنام',
#   'ل',
#   'عدة',
#   'ساعات',
#   '.'],
#  ['و',
#   'أوضح',
#   'المصدر',
#   'نفس',
#   'ه',
#   'ان',
#   'عرفات',
#   'س',
#   'يلتقي',
#   'نظير',
#   'ه',
#   'الفيتنامي',
#   'تران',
#   'دوك',
#   'لوونغ',
#   '.'],
#  ['و',
#   'قد',
#   'وصل',
#   'الزعيم',
#   'الفلسطينيني',
#   'قادما',
#   'من',
#   'الصين',
#   'التى',
#   'زار',
#   'ها',
#   'ل',
#   'مدة',
#   '24',
#   'ساعة',
#   'و',
#   'حصل',
#   'في',
#   'ها',
#   'على',
#   'تاييد',
#   'حذر',
#   'ل',
#   'مشروع',
#   'اعلان',
#   'الدولة',
#   'الفلسطينية',
#   'في',
#   '13',
#   'ايلول',
#   '/',
#   'سبتمبر',
#   'من',
#   'جانب',
#   'واحد',
#   '.'],
#  ['و',
#   'كان',
#   'عرفات',
#   'زار',
#   'بعد',
#   'فشل',
#   'قمة',
#   'كامب',
#   'ديفيد',
#   'في',
#   '25',
#   'تموز',
#   '/',
#   'يوليو',
#   'عشرين',
#   'من',
#   'دون',
#   'ان',
#   'يحظى',
#   'على',
#   'ما',
#   'يبدو',
#   'ب',
#   'دعم',
#   'حاسم',
#   'ل',
#   'مشروع',
#   'اعلان',
#   'الدولة',
#   'الفلسطينية',
#   '.'],
#  ['و',
#   'قد',
#   'حذرت',
#   'روسيا',
#   'الحليف',
#   'التقليدي',
#   'ل',
#   'الفلسطينيين',
#   'الجمعة',
#   'الماضي',
#   'عرفات',
#   'من',
#   'التسرع',
#   'فى',
#   'اعلان',
#   'الدولة',
#   '.'],
#  ['و',
#   'سبق',
#   'ل',
#   'عرفات',
#   'فى',
#   'نيسان',
#   '/',
#   'ابريل',
#   '1999',
#   'ان',
#   'زار',
#   'هانوي',
#   'التى',
#   'كانت',
#   'على',
#   'الدوام',
#   'تعرب',
#   'عن',
#   'مواقف',
#   'مؤيدة',
#   'ل',
#   'القضية',
#   'الفلسطينية',
#   'مع',
#   'سعي',
#   'ها',
#   'الى',
#   'تنمية',
#   'علاقات',
#   'ها',
#   'الاقتصادية',
#   'مع',
#   'اسرائيل',
#   '.'],
#  ['كما',
#   'استضافت',
#   'هانوي',
#   'مؤتمرا',
#   'اسيويا',
#   'ل',
#   'الأمم',
#   'المتحدة',
#   'حول',
#   'فلسطينيين',
#   'فى',
#   'اذار',
#   '/',
#   'مارس',
#   'الماضي',
#   '.'],
#  ['و',
#   'من',
#   'المقرر',
#   'ان',
#   'يزور',
#   'عرفات',
#   'ايضا',
#   'كلا',
#   'من',
#   'كوالا',
#   'لمبور',
#   'و',
#   'جاكرتا',
#   'و',
#   'طوكيو',
#   'وفق',
#   'ما',
#   'اكدت',
#   'المصادر',
#   'الفلسطينية',
#   '.'],
#  ['بدا', 'لم', 'شمل', 'العائلات', 'بين', 'شطري', 'كوريا'],
#  ['سيول',
#   '15',
#   '-',
#   '8',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'بدا',
#   'اليوم',
#   'الثلاثاء',
#   'لم',
#   'شمل',
#   'العائلات',
#   'الكورية',
#   'بين',
#   'شطري',
#   'شبه',
#   'الجزيرة',
#   'التى',
#   'قسمت',
#   'ها',
#   'الحرب',
#   'قبل',
#   'نصف',
#   'قرن',
#   '،',
#   'و',
#   'هبطت',
#   'طائرة',
#   'تابعة',
#   'ل',
#   'الخطوط',
#   'الجوية',
#   'الكورية',
#   '"',
#   'اير',
#   'كوريو',
#   '"',
#   'في',
#   'مطار',
#   'سيول',
#   'اليوم',
#   'الثلاثاء',
#   'ل',
#   'تصبح',
#   'اول',
#   'طائرة',
#   'كورية',
#   'شمالية',
#   'تهبط',
#   'في',
#   'كوريا',
#   'الجنوبية',
#   'منذ',
#   'الحرب',
#   'الكورية',
#   'التي',
#   'استمرت',
#   'من',
#   '1950',
#   'الى',
#   '1953',
#   '.'],
#  ['و',
#   'كانت',
#   'الطائرة',
#   'و',
#   'هي',
#   'من',
#   'نوع',
#   'اليوشن',
#   '62',
#   'تنقل',
#   '151',
#   'شخصا',
#   '.',
#   'و',
#   'س',
#   'يلتقي',
#   '100',
#   'من',
#   'الكوريين',
#   'الشماليين',
#   'على',
#   'متن',
#   'الطائرة',
#   'مع',
#   'عدد',
#   'من',
#   'الصحافيين',
#   'و',
#   'الرسميين',
#   'خلال',
#   'النهار',
#   'اقارب',
#   'ل',
#   'هم',
#   'يقيمون',
#   'في',
#   'كوريا',
#   'الجنوبية',
#   'و',
#   'لا',
#   'يعرفون',
#   'شيئا',
#   'عن',
#   'هم',
#   'منذ',
#   'فترة',
#   'طويلة',
#   '،',
#   'و',
#   'غالبا',
#   'منذ',
#   'نهاية',
#   'الحرب',
#   '.'],
#  ['و',
#   'قد',
#   'عادت',
#   'الطائرة',
#   'نفس',
#   'ها',
#   'الى',
#   'بيونغيانغ',
#   'و',
#   'على',
#   'متن',
#   'ها',
#   '100',
#   'كوري',
#   'جنوبي',
#   'ل',
#   'لقاء',
#   'اقارب',
#   'في',
#   'عاصمة',
#   'كوريا',
#   'الشمالية',
#   '.'],
#  ['و',
#   'هٰذا',
#   'التبادل',
#   'الاول',
#   'ل',
#   'الزيارات',
#   'العائلية',
#   'منذ',
#   '1985',
#   'قد',
#   'تقرر',
#   'خلال',
#   'اول',
#   'قمة',
#   'بين',
#   'رئيسي',
#   'الكوريتين',
#   'في',
#   'حزيران',
#   '/',
#   'يونيو',
#   'الماضي',
#   '.'],
#  ['ف',
#   'قد',
#   'تعهد',
#   'الرئيس',
#   'الكوري',
#   'الجنوبي',
#   'كيم',
#   'داي',
#   '-',
#   'جونغ',
#   'و',
#   'رئيس',
#   'كوريا',
#   'الشمالية',
#   'كيم',
#   'جونغ',
#   '-',
#   'ايل',
#   'انذاك',
#   'ب',
#   'طي',
#   'صفحة',
#   'نصف',
#   'قرن',
#   'من',
#   'العداء',
#   'و',
#   'السعي',
#   'الى',
#   'اعادة',
#   'توحيد',
#   'البلاد',
#   '.'],
#  ['اسرائيل',
#   'تقترح',
#   'ترتيبات',
#   'ل',
#   'لقاء',
#   'العائلات',
#   'على',
#   'الحدود',
#   'مع',
#   'لبنان'],
#  ['القدس',
#   '15',
#   '-',
#   '8',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'اقترح',
#   'رئيس',
#   'الوزراء',
#   'الاسرائيلي',
#   'ايهود',
#   'باراك',
#   'اليوم',
#   'الثلاثاء',
#   'ان',
#   'تعمل',
#   'اسرائيل',
#   'و',
#   'لبنان',
#   'على',
#   'تنظيم',
#   'نقاط',
#   'تتم',
#   'عند',
#   'ها',
#   'اللقاءات',
#   'العائلية',
#   'على',
#   'الحدود',
#   'بين',
#   'هما',
#   '.'],
#  ['و',
#   'قالت',
#   'الاذاعة',
#   'الاسرائيلية',
#   'العامة',
#   'ان',
#   'باراك',
#   'اقترح',
#   'ان',
#   'تكون',
#   'هذه',
#   'النقاط',
#   '"',
#   'تحت',
#   'اشراف',
#   'الامم',
#   'المتحدة',
#   '"',
#   '.'],
#  ['و',
#   'أضافت',
#   'ان',
#   'الترتيبات',
#   'س',
#   'تتيح',
#   'ل',
#   'العائلات',
#   'خصوصا',
#   'الفلسطينية',
#   'ان',
#   'تلتقي',
#   'ب',
#   'طريقة',
#   'اكثر',
#   'انسانية',
#   'مع',
#   'توفير',
#   'الحد',
#   'الادنى',
#   'من',
#   'الراحة',
#   '.'],
#  ['و',
#   'قال',
#   'باراك',
#   'الذي',
#   'يمضى',
#   'حاليا',
#   'اجازة',
#   'فى',
#   'شمال',
#   'اسرائيل',
#   'ان',
#   'الدولة',
#   'العبرية',
#   'لم',
#   'تكن',
#   'تسمح',
#   'حتى',
#   'الان',
#   'ب',
#   'مثل',
#   'هذه',
#   'اللقاءات',
#   'في',
#   'المنطقة',
#   'التى',
#   'تعتبر',
#   'ها',
#   '"',
#   'منطقة',
#   'عسكرية',
#   'مقفلة',
#   '"',
#   '.'],
#  ['و',
#   'قد',
#   'راحت',
#   'العائلات',
#   'الفلسطينية',
#   'في',
#   'لبنان',
#   'و',
#   'إسرائيل',
#   'بعد',
#   'انسحاب',
#   'القوات',
#   'الاسرائيلية',
#   'من',
#   'جنوب',
#   'لبنان',
#   'فى',
#   '24',
#   'ايار',
#   '/',
#   'مايو',
#   'الماضي',
#   'تتوجه',
#   'الى',
#   'جانبي',
#   'الحدود',
#   'لكي',
#   'تلتقي',
#   '،',
#   'لكن',
#   'الجيش',
#   'الاسرائيلي',
#   'منع',
#   'مثل',
#   'هذه',
#   'اللقاءات',
#   'بعد',
#   'وقوع',
#   'عدد',
#   'من',
#   'الصدامات',
#   'عند',
#   'الاسلاك',
#   'الشائكة',
#   'على',
#   'الحدود',
#   '.'],
#  ['من',
#   'جهة',
#   'اخرى',
#   'اعلن',
#   'الجنرال',
#   'غابي',
#   'اشكينازي',
#   'قائد',
#   'المنطقة',
#   'الشمالية',
#   'التى',
#   'تشمل',
#   'الحدود',
#   'مع',
#   'لبنان',
#   'اليوم',
#   'الثلاثاء',
#   'ان',
#   'اسرائيل',
#   '"',
#   'تبذل',
#   'ما',
#   'تستطيع',
#   'ل',
#   'تجنب',
#   'التصعيد',
#   'فى',
#   'لبنان',
#   '"',
#   'على',
#   'الرغم',
#   'مما',
#   'يسبب',
#   'ه',
#   'رشق',
#   'الحجارة',
#   'من',
#   'اذى',
#   '.'],
#  ['و',
#   'ندد',
#   'الجنرال',
#   'اشكينازي',
#   'ب',
#   'استمرار',
#   'رشق',
#   'الحجارة',
#   'على',
#   'بوابة',
#   'فاطمة',
#   'مشيرا',
#   'الى',
#   'ان',
#   'وحدات',
#   'من',
#   'المظلييين',
#   'نشرت',
#   'فى',
#   'المنطقة',
#   'و',
#   'هي',
#   'مزودة',
#   'ب',
#   'أوامر',
#   'ل',
#   'ضبط',
#   'النفس',
#   '.'],
#  ['دورة', 'مونتريال', ':', 'كورنيكوفا', 'الى', 'المرحلة', 'الثانية'],
#  ['مونتريال',
#   '15',
#   '-',
#   '8',
#   '(',
#   'أ',
#   'ف',
#   'ب',
#   ')',
#   '-',
#   'بلغت',
#   'الروسية',
#   'آنا',
#   'كورنيكوفا',
#   'المرحلة',
#   'الثانية',
#   'من',
#   'دورة',
#   'مونتريال',
#   'الكندية',
#   'الدولية',
#   'ل',
#   'كرة',
#   'المضرب',
#   'البالغة',
#   'جوائز',
#   'ها',
#   '08',
#   'ر',
#   '1',
#   'مليون',
#   'دولار',
#   'ب',
#   'فوز',
#   'ها',
#   'على',
#   'كارا',
#   'بلاك',
#   'من',
#   'زيمبابوي',
#   '6',
#   '-',
#   '3',
#   'و',
#   '7',
#   '-',
#   '6',
#   '(',
#   '7',
#   '-',
#   '4',
#   ')',
#   '.'],
#  ['و',
#   'فازت',
#   'الاميركية',
#   'تشاندا',
#   'روبن',
#   'على',
#   'الارجنتينية',
#   'باولا',
#   'سواريز',
#   '6',
#   '-',
#   '7',
#   '(',
#   '5',
#   '-',
#   '7',
#   ')',
#   'و',
#   '6',
#   '-',
#   '2',
#   'و',
#   '6',
#   '-',
#   '2',
#   '،',
#   'و',
#   'الإسبانية',
#   'فيرجينيا',
#   'روانو',
#   'باسكوال',
#   'على',
#   'الكندية',
#   'فانيسا',
#   'ويب',
#   '6',
#   '-',
#   '4',
#   'و',
#   '6',
#   '-',
#   '4',
#   '،',
#   'و',
#   'الفرنسية',
#   'ناتالي',
#   'ديشي',
#   'على',
#   'الاميركية',
#   'الكساندرا',
#   'ستيفنسون',
#   '6',
#   '-',
#   '3',
#   'و',
#   '6',
#   '-',
#   '4',
#   '،',
#   'و',
#   'السويسرية',
#   'باتي',
#   'شنايدر',
#   'على',
#   'الروسية',
#   'ايلينا',
#   'ليخوفتسيفا',
#   '7',
#   '-',
#   '5',
#   'و',
#   '6',
#   '-',
#   '3',
#   '،',
#   'و',
#   'السلوفاكية',
#   'هنرييتا',
#   'ناغيوفا',
#   'على',
#   'التشيكية',
#   'دينيزا',
#   'شلادكوفا',
#   '2',
#   '-',
#   '6',
#   'و',
#   '7',
#   '-',
#   '5',
#   'و',
#   '6',
#   '-',
#   '3',
#   '،',
#   'و',
#   'الفرنسية',
#   'ساره',
#   'بيتكوفسكي',
#   'على',
#   'الاسبانية',
#   'ماغي',
#   'سيرنا',
#   '6',
#   '-',
#   '2',
#   'و',
#   '6',
#   '-',
#   '2',
#   '،',
#   'و',
#   'الرومانية',
#   'روكساندرا',
#   'دراغومير',
#   'على',
#   'الاسبانية',
#   'انجيليس',
#   'مونتوليو',
#   '6',
#   '-',
#   '1',
#   'و',
#   '7',
#   '-',
#   '5',
#   '،',
#   'و',
#   'الإسبانية',
#   'غالا',
#   'ليون',
#   'غارسيا',
#   'على',
#   'اليابانية',
#   'اي',
#   'سوغيياما',
#   '4',
#   '-',
#   '6',
#   'و',
#   '6',
#   '-',
#   'صفر',
#   'و',
#   '6',
#   '-',
#   '1',
#   '،',
#   'واللوكسمبورغية',
#   'آن',
#   'كريمير',
#   'على',
#   'الروسية',
#   'اناستازيا',
#   'ميسكينا',
#   '6',
#   '-',
#   '4',
#   'و',
#   '6',
#   '-',
#   '1',
#   '.'],
#  ['و',
#   'فازت',
#   'البلجيكية',
#   'جوستين',
#   'هنين',
#   'على',
#   'السويدية',
#   'ازا',
#   'كارلسون',
#   '6',
#   '-',
#   '2',
#   'و',
#   '4',
#   '-',
#   '6',
#   'و',
#   '6',
#   '-',
#   '3',
#   '،',
#   'و',
#   'الروسية',
#   'تاتيانا',
#   'بانوفا',
#   'على',
#   'الكولومبية',
#   'فابيولا',
#   'زولواغا',
#   '6',
#   '-',
#   '4',
#   'و',
#   '6',
#   '-',
#   '1',
#   '،',
#   'و',
#   'البلجيكية',
#   'سابين',
#   'ابلمانس',
#   'على',
#   'الاسترالية',
#   'يلينا',
#   'دوكيتش',
#   '6',
#   '-',
#   '7',
#   '(',
#   '6',
#   '-',
#   '8',
#   ')',
#   'و',
#   '6',
#   '-',
#   '4',
#   'و',
#   '7',
#   '-',
#   '6',
#   '(',
#   '7',
#   '-',
#   '5',
#   ')',
#   '،',
#   'و',
#   'الأميركية',
#   'آني',
#   'ميلر',
#   'على',
#   'مواطنة',
#   'ها',
#   'اريكا',
#   'دي',
#   'لون',
#   '6',
#   '-',
#   '4',
#   'و',
#   '3',
#   '-',
#   '6',
#   'و',
#   '6',
#   '-',
#   '1',
#   '،',
#   'و',
#   'الجنوب',
#   'افريقية',
#   'اماندا',
#   'كوتزر',
#   'على',
#   'التايلاندية',
#   'تامارين',
#   'تاناسوغارن',
#   '6',
#   '-',
#   '2',
#   'و',
#   '6',
#   '-',
#   '2',
#   '،',
#   'و',
#   'الكندية',
#   'يانا',
#   'نييدلي',
#   'على',
#   'الاميركية',
#   'سامانتا',
#   'ريفز',
#   '6',
#   '-',
#   '3',
#   'و',
#   '6',
#   '-',
#   '3',
#   '.'],
#  ['شركة',
#   '+',
#   'ميغ',
#   '+',
#   'الروسية',
#   'ل',
#   'الطائرات',
#   'تريد',
#   'تعزيز',
#   'موقع',
#   'ها',
#   'في',
#   'السوق',
#   'الاوروبية'],
#  ['موسكو',
#   '15',
#   '-',
#   '8',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'اعلن',
#   'غينادي',
#   'ارخيبوف',
#   'نائب',
#   'مدير',
#   'شركة',
#   '+',
#   'ميغ',
#   '+',
#   'ل',
#   'صنع',
#   'الطائرات',
#   'امس',
#   'الاثنين',
#   'ان',
#   'الشركة',
#   'تجري',
#   'مفاوضات',
#   'مع',
#   'المجر',
#   'و',
#   'النمسا',
#   'و',
#   'تسعى',
#   'الى',
#   'تعزيز',
#   'موقع',
#   'ها',
#   'في',
#   'السوق',
#   'الاوروبية',
#   '.'],
#  ['و',
#   'نقلت',
#   'وكالة',
#   'انباء',
#   'انترفاكس',
#   'عن',
#   'ارخيبوف',
#   'قول',
#   'ه',
#   'ان',
#   'الشركة',
#   'س',
#   'توقع',
#   'في',
#   'الاسابيع',
#   'المقبلة',
#   'عقدا',
#   'مع',
#   'المجر',
#   'ل',
#   'تحديث',
#   'طائرات',
#   'ها',
#   'من',
#   'نوع',
#   'ميغ',
#   '-',
#   '29',
#   '.',
#   'و',
#   'أضاف',
#   '"',
#   'هذا',
#   'ليس',
#   'مشروعا',
#   'كبيرا',
#   'في',
#   'نظر',
#   'نا',
#   '"',
#   '،',
#   'لٰكن',
#   'ه',
#   'اوضح',
#   '"',
#   'ان',
#   'العقد',
#   'س',
#   'يكون',
#   'بالغ',
#   'الاهمية',
#   'على',
#   'الصعيد',
#   'السياسي',
#   '"',
#   '.'],
#  ['و',
#   'أشار',
#   'ارخيبوف',
#   'الى',
#   'ان',
#   'دولا',
#   'اخرى',
#   'من',
#   'اوروبا',
#   'الوسطى',
#   'و',
#   'الشرقية',
#   'التي',
#   'اصبح',
#   'أسطول',
#   'ها',
#   'الجوي',
#   'من',
#   'المقاتلات',
#   'الروسية',
#   'متهالكا',
#   '،',
#   'يمكن',
#   'ان',
#   'تقتدي',
#   'ب',
#   'المجر',
#   'و',
#   'تبدأ',
#   'توقيع',
#   'عقود',
#   '.'],
#  ['و',
#   'تجري',
#   'شركة',
#   '+',
#   'ميغ',
#   '+',
#   'ايضا',
#   'مفاوضات',
#   'مع',
#   'النمسا',
#   'ل',
#   'تزويد',
#   'أسطول',
#   'ها',
#   'الجوي',
#   'ب',
#   'طائرات',
#   'ميغ',
#   '-',
#   '29',
#   'اس',
#   '.',
#   'ام',
#   '.',
#   'تي',
#   'المجهزة',
#   'ب',
#   'أحدث',
#   'الانظمة',
#   'الدفاعية',
#   'و',
#   'المزودة',
#   'ب',
#   'خزان',
#   'اضافي',
#   'ل',
#   'المحروقات',
#   'و',
#   'ب',
#   'جهاز',
#   'تحكم',
#   'الكتروني',
#   'حديث',
#   '.'],
#  ['و',
#   'أضاف',
#   'ارخيبوف',
#   'ان',
#   'المنافسة',
#   'ل',
#   'الفوز',
#   'ب',
#   'عقود',
#   'الطيران',
#   'العسكري',
#   'الاوروبي',
#   'قاسية',
#   '،',
#   'لأن',
#   'الولايات',
#   'المتحدة',
#   'تعرض',
#   'طائرات',
#   'ها',
#   'اف',
#   '-',
#   '16',
#   'ب',
#   'أسعار',
#   'متدنية',
#   'جدا',
#   'و',
#   'لأن',
#   'اوروبا',
#   'تسعى',
#   'الى',
#   'تطوير',
#   'طائرات',
#   'ها',
#   'المقاتلة',
#   '"',
#   'يوروفايتر',
#   '"',
#   '.',
#   'لكن',
#   'اي',
#   'دولة',
#   'ليست',
#   'مستعدة',
#   'ل',
#   'التخلي',
#   'ب',
#   'الكامل',
#   'عن',
#   'طائرات',
#   'الميغ',
#   'الروسية',
#   '.'],
#  ['و',
#   'تعتزم',
#   'الهند',
#   'من',
#   'جهة',
#   'ها',
#   'شراء',
#   'حاملة',
#   'الطائرات',
#   'الروسية',
#   '"',
#   'اميرال',
#   'غورشكوف',
#   '"',
#   'و',
#   'س',
#   'تشتري',
#   'طائرات',
#   'ميغ',
#   '-',
#   '29',
#   'الوحيدة',
#   'التي',
#   'تتلاءم',
#   'مع',
#   'حاملة',
#   'الطائرات',
#   'هذه',
#   '.',
#   'و',
#   'قد',
#   'يشمل',
#   'العقد',
#   'شراء',
#   '60',
#   'طائرة',
#   '.'],
#  ['دورة',
#   'انديانابوليس',
#   ':',
#   'فوز',
#   'العيناوي',
#   'و',
#   'خسارة',
#   'ارازي',
#   'في',
#   'المرحلة',
#   'الاولى'],
#  ['انديانابوليس',
#   '(',
#   'الولايات',
#   'المتحدة',
#   ')',
#   '15',
#   '-',
#   '8',
#   '(',
#   'أ',
#   'ف',
#   'ب',
#   ')',
#   '-',
#   'بلغ',
#   'المغربي',
#   'يونس',
#   'العيناوي',
#   'المرحلة',
#   'الثانية',
#   'من',
#   'دورة',
#   'انديانابوليس',
#   'الاميركية',
#   'الدولية',
#   'ل',
#   'كرة',
#   'المضرب',
#   'البالغة',
#   'جوائز',
#   'ها',
#   '800',
#   'الف',
#   'دولار',
#   'ب',
#   'فوز',
#   'ه',
#   'على',
#   'السويدي',
#   'توماس',
#   'يوهانسون',
#   '7',
#   '-',
#   '6',
#   '(',
#   '7',
#   '-',
#   '4',
#   ')',
#   'و',
#   '6',
#   '-',
#   '4',
#   '.'],
#  ['و',
#   'خرج',
#   'المغربي',
#   'الاخر',
#   'هشام',
#   'ارازي',
#   'مبكرا',
#   'من',
#   'الدورة',
#   'اثر',
#   'خسارة',
#   'ه',
#   'امام',
#   'الاسباني',
#   'كارلوس',
#   'مويا',
#   '4',
#   '-',
#   '6',
#   'و',
#   '4',
#   '-',
#   '6',
#   '.'],
#  ['و',
#   'فاز',
#   'الاسباني',
#   'البرت',
#   'كوستا',
#   'على',
#   'الكرواتي',
#   'غوران',
#   'ايفانيسيفيتش',
#   '7',
#   '-',
#   '5',
#   'و',
#   '6',
#   '-',
#   '2',
#   '،',
#   'و',
#   'الإسرائيلي',
#   'هاريل',
#   'ليفي',
#   'على',
#   'الارجنتيني',
#   'ماريانو',
#   'زاباليتا',
#   '6',
#   '-',
#   '3',
#   'و',
#   '6',
#   '-',
#   '1',
#   '،',
#   'و',
#   'الإيطالي',
#   'جانلوكا',
#   'بوتزي',
#   'على',
#   'الروماني',
#   'اندري',
#   'بافل',
#   '7',
#   '-',
#   '6',
#   '(',
#   '7',
#   '-',
#   'صفر',
#   ')',
#   'و',
#   '2',
#   '-',
#   '6',
#   'و',
#   '6',
#   '-',
#   '2',
#   '،',
#   'و',
#   'السويدي',
#   'ميكايل',
#   'تيلستروم',
#   'على',
#   'الارجنتيني',
#   'خوان',
#   'شيلا',
#   '7',
#   '-',
#   '5',
#   'و',
#   '5',
#   '-',
#   '7',
#   'و',
#   '6',
#   '-',
#   '1',
#   '،',
#   'و',
#   'الإسباني',
#   'البرتو',
#   'مارتن',
#   'على',
#   'الاميركي',
#   'جيمس',
#   'بلاك',
#   '6',
#   '-',
#   '3',
#   'و',
#   '6',
#   '-',
#   '2',
#   '.'],
#  ['و',
#   'تغلب',
#   'ايضا',
#   'واين',
#   'بلاك',
#   'من',
#   'زيمبابوي',
#   'على',
#   'مواطن',
#   'ه',
#   'كيفن',
#   'اولييت',
#   '6',
#   '-',
#   '3',
#   'و',
#   '6',
#   '-',
#   'صفر',
#   '،',
#   'و',
#   'الفرنسي',
#   'سيباستيان',
#   'غروجان',
#   'على',
#   'البيلاروسي',
#   'ماكس',
#   'ميرنيي',
#   '3',
#   '-',
#   '6',
#   'و',
#   '7',
#   '-',
#   '6',
#   '(',
#   '7',
#   '-',
#   '5',
#   ')',
#   '6',
#   '-',
#   '4',
#   '،',
#   'و',
#   'البلجيكي',
#   'كزافييه',
#   'ماليس',
#   'على',
#   'الاسرائيلي',
#   'ليور',
#   'مور',
#   '6',
#   '-',
#   '3',
#   'و',
#   '6',
#   '-',
#   '2',
#   '،',
#   'و',
#   'النمسوي',
#   'ستيفان',
#   'كوبيك',
#   'على',
#   'الاميركي',
#   'ديفيد',
#   'ويتون',
#   '6',
#   '-',
#   '4',
#   'و',
#   '3',
#   '-',
#   '6',
#   'و',
#   '7',
#   '-',
#   '6',
#   '(',
#   '7',
#   '-',
#   '5',
#   ')',
#   '،',
#   'و',
#   'الأميركي',
#   'تود',
#   'مارتن',
#   'على',
#   'مواطن',
#   'ه',
#   'سيسيل',
#   'مامييت',
#   '6',
#   '-',
#   '3',
#   'و',
#   '6',
#   '-',
#   '3',
#   '،',
#   'و',
#   'الفرنسي',
#   'بول',
#   'هنري',
#   'ماتيو',
#   'على',
#   'السويدي',
#   'يوناش',
#   'بيوركمان',
#   '6',
#   '-',
#   '3',
#   'و',
#   '6',
#   '-',
#   '4',
#   '.'],
#  ['بحارة',
#   'الغواصة',
#   'النووية',
#   'الروسية',
#   'الغارقة',
#   'ما',
#   'زالوا',
#   'احياء',
#   'لكن',
#   'الوضع',
#   'خطير'],
#  ['موسكو',
#   '15',
#   '-',
#   '8',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'نقلت',
#   'وكالة',
#   'انباء',
#   'انترفاكس',
#   'عن',
#   'قائد',
#   'سلاح',
#   'البحرية',
#   'الروسية',
#   'الاميرال',
#   'فلاديمير',
#   'كورويدوف',
#   'اليوم',
#   'الثلاثاء',
#   'ان',
#   'البحارة',
#   'المئة',
#   'و',
#   'ستة',
#   'عشر',
#   'على',
#   'متن',
#   'الغواصة',
#   'النووية',
#   'الروسية',
#   'كورسك',
#   'التى',
#   'استقرت',
#   'على',
#   'عمق',
#   '100',
#   'متر',
#   'فى',
#   'البحر',
#   '"',
#   'ما',
#   'زالوا',
#   'احياء',
#   'حتى',
#   'الان',
#   '،',
#   'لكن',
#   'الوضع',
#   'خطير',
#   'و',
#   'السلطات',
#   'تخشى',
#   'الاسوأ',
#   'ب',
#   'النسبة',
#   'الى',
#   'حياة',
#   'الطاقم',
#   '"',
#   '.'],
#  ['و',
#   'أضاف',
#   'كورويدوف',
#   'ان',
#   '"',
#   'امكان',
#   'انتهاء',
#   'عملية',
#   'الانقاذ',
#   'على',
#   'خير',
#   'رهن',
#   'الى',
#   'حد',
#   'كبير',
#   'ب',
#   'الوضع',
#   'داخل',
#   'الغواصة',
#   '"',
#   '،',
#   'موضحا',
#   'ان',
#   'بقاء',
#   'البحارة',
#   'على',
#   'قيد',
#   'الحياة',
#   'متعلق',
#   'ب',
#   'سلسلة',
#   'من',
#   'العوامل',
#   '"',
#   '.'],
#  ['و',
#   'قال',
#   'ان',
#   '"',
#   'ان',
#   'عدد',
#   'الحجرات',
#   'التي',
#   'غمرت',
#   'ها',
#   'المياه',
#   'و',
#   'ارتفاع',
#   'الضغط',
#   'الجوي',
#   'و',
#   'درجات',
#   'الحرارة',
#   'و',
#   'وضع',
#   'مخزون',
#   'الهواء',
#   '،',
#   'كل',
#   'ها',
#   'عوامل',
#   'تؤثر',
#   'على',
#   'المهلة',
#   'المتاحة',
#   'أمام',
#   'هم',
#   'ل',
#   'البقاء',
#   'على',
#   'قيد',
#   'الحياة',
#   '"',
#   '.'],
#  ['و',
#   'مضى',
#   'يقول',
#   '"',
#   'ان',
#   'فرق',
#   'الانقاذ',
#   'مدركة',
#   'ل',
#   'كل',
#   'ما',
#   'سبق',
#   'و',
#   'س',
#   'تبذل',
#   'ما',
#   'ب',
#   'وسع',
#   'ها',
#   'ل',
#   'إنقاذ',
#   'طاقم',
#   'الغواصة',
#   'على',
#   'الرغم',
#   'من',
#   'سوء',
#   'الاحوال',
#   'الجوية',
#   '"',
#   '.'],
#  ['و',
#   'أشار',
#   'الى',
#   'أن',
#   'ه',
#   'لا',
#   'يملك',
#   'اي',
#   'معلومات',
#   'حول',
#   'وقوع',
#   'قتلى',
#   'او',
#   'جرحى',
#   'بين',
#   'طاقم',
#   'الغواصة',
#   '.'],
#  ['و',
#   'كانت',
#   'السلطات',
#   'الروسية',
#   'اعلنت',
#   'في',
#   'وقت',
#   'سابق',
#   'اليوم',
#   'ان',
#   'العواصف',
#   'القوية',
#   'فى',
#   'بحر',
#   'بارنتس',
#   'تحول',
#   'دون',
#   'مواصلة',
#   'عمليات',
#   'الاغاثة',
#   '.'],
#  ['و',
#   'أعلن',
#   'الاميرال',
#   'كورويدوف',
#   'ان',
#   '"',
#   'البحر',
#   'شديد',
#   'الموج',
#   'و',
#   'فرق',
#   'الانقاذ',
#   'لا',
#   'تستطيع',
#   'ان',
#   'تلقي',
#   'مراسي',
#   'ها',
#   '"',
#   '.'],
#  ['و',
#   'أشار',
#   'الى',
#   'ان',
#   'فرق',
#   'الانقاذ',
#   'تتفحص',
#   'حاليا',
#   'خارج',
#   'الغواصة',
#   '"',
#   'اذ',
#   'لم',
#   'تعرف',
#   'بعد',
#   'اسباب',
#   'غرق',
#   'الغواصة',
#   '"',
#   'التي',
#   'رجحت',
#   'مصادر',
#   'البحرية',
#   'ان',
#   'يكون',
#   'ناجما',
#   'عن',
#   'اصطدام',
#   'ها',
#   'ب',
#   'سفينة',
#   'اخرى',
#   '.'],
#  ['من',
#   'جهة',
#   'اخرى',
#   'قال',
#   'نائب',
#   'رئيس',
#   'الوزراء',
#   'ايليا',
#   'كليبانوف',
#   'ان',
#   'البحرية',
#   'تعتزم',
#   'اجلاء',
#   'طاقم',
#   'الغواصة',
#   'الا',
#   'ان',
#   'العاصفة',
#   'تحول',
#   'حاليا',
#   'دون',
#   'القيام',
#   'ب',
#   'ذٰلك',
#   '.'],
#  ['و',
#   'قال',
#   '"',
#   'ان',
#   'الوضع',
#   'صعب',
#   '"',
#   'لٰكن',
#   'ه',
#   'رفض',
#   'عرض',
#   'المساعدة',
#   'الذي',
#   'تقدمت',
#   'ب',
#   'ه',
#   'واشنطن',
#   'موضحا',
#   '"',
#   'لدي',
#   'نا',
#   'كل',
#   'الوسائل',
#   'الفنية',
#   'اللازمة',
#   'و',
#   'هي',
#   'ليست',
#   'اقل',
#   'مما',
#   'لدى',
#   'الاميركيين',
#   '"',
#   '.'],
#  ['و',
#   'أشارت',
#   'مصادر',
#   'في',
#   'هيئة',
#   'اركان',
#   'البحرية',
#   'الى',
#   'ان',
#   'اي',
#   'اتصال',
#   'لاسلكي',
#   'لم',
#   'يكن',
#   'ممكنا',
#   'مع',
#   'الطاقم',
#   'منذ',
#   'الاحد',
#   '.',
#   'الا',
#   'أن',
#   'ه',
#   'كان',
#   'من',
#   'الممكن',
#   '"',
#   'الاتصال',
#   'سمعيا',
#   '"',
#   'و',
#   'التخاطب',
#   'ب',
#   'واسطة',
#   'اشارات',
#   'المورس',
#   '.'],
#  ['و',
#   'نقلت',
#   'انترفاكس',
#   'عن',
#   'المتحدث',
#   'ب',
#   'اسم',
#   'اسطول',
#   'الشمال',
#   'فلاديمير',
#   'نافروتسكي',
#   'قول',
#   'ه',
#   '"',
#   'إن',
#   'ه',
#   'ليس',
#   'من',
#   'الممكن',
#   'حاليا',
#   'التحدث',
#   'عن',
#   'نتائج',
#   'ايجابية',
#   '"',
#   'ل',
#   'عمليات',
#   'الانقاذ',
#   '.'],
#  ['و',
#   'أشارت',
#   'التلفزيونات',
#   'اليوم',
#   'الى',
#   'ان',
#   'قائد',
#   'الاسطول',
#   'لم',
#   'يدل',
#   'ب',
#   'أي',
#   'معلومات',
#   'محددة',
#   'حول',
#   'وضع',
#   'عمليات',
#   'الانقاذ',
#   '.',
#   'و',
#   'اكتفت',
#   'انترفاكس',
#   'ب',
#   'القول',
#   'ان',
#   '"',
#   'جهازين',
#   'ل',
#   'الإنقاذ',
#   'عجزا',
#   'عن',
#   'القيام',
#   'ب',
#   'مهمة',
#   'هما',
#   'ب',
#   'سبب',
#   'سوء',
#   'الاحوال',
#   'الجوية',
#   '"',
#   '.'],
#  ['و',
#   'كان',
#   'من',
#   'المفترض',
#   'ان',
#   'يلتحم',
#   'الجهازان',
#   'ب',
#   'الغواصة',
#   'ل',
#   'إمداد',
#   'ها',
#   'ب',
#   'الأوكسجين',
#   'و',
#   'الطاقة',
#   'و',
#   'التحضير',
#   'ل',
#   'إجلاء',
#   'الطاقم',
#   'من',
#   'ها',
#   '.'],
#  ['و',
#   'أفادت',
#   'البحرية',
#   'الروسية',
#   'ان',
#   'الغواصة',
#   'مجهزة',
#   'ب',
#   '24',
#   'صاروخا',
#   'الا',
#   'ان',
#   'ايا',
#   'من',
#   'ها',
#   'لا',
#   'يملك',
#   'رأسا',
#   'نوويا',
#   '.'],
#  ['و',
#   'قد',
#   'غرقت',
#   'كورسك',
#   'و',
#   'هي',
#   'من',
#   'احدث',
#   'قطع',
#   'البحرية',
#   'الروسية',
#   'على',
#   'بعد',
#   '150',
#   'كلم',
#   'تقريبا',
#   'من',
#   'قاعدة',
#   'سيفيرومورسك',
#   'على',
#   'بعد',
#   '69،4',
#   'درجات',
#   'شمالا',
#   'و',
#   '37،5',
#   'درجات',
#   'جنوبا',
#   '،',
#   'في',
#   'منطقة',
#   'دولية',
#   'تقع',
#   'بين',
#   'روسيا',
#   'و',
#   'النروج',
#   '.'],
#  ['و',
#   'أشار',
#   'المعهد',
#   'النروجي',
#   'ل',
#   'الوقاية',
#   'من',
#   'الاشعاعات',
#   'النووية',
#   '(',
#   'ستراليفيرن',
#   ')',
#   'الى',
#   'أن',
#   'ه',
#   'لم',
#   'يتم',
#   'كشف',
#   'اي',
#   'تلوث',
#   'اشعاعي',
#   'حتى',
#   'مساء',
#   'امس',
#   'الاثنين',
#   '.'],
#  ['و',
#   'هٰذا',
#   'الحادث',
#   'الذي',
#   'تعرضت',
#   'ل',
#   'ه',
#   'الغواصة',
#   'التي',
#   'بدأ',
#   'العمل',
#   'ب',
#   'ها',
#   'في',
#   '1995',
#   '،',
#   'هو',
#   'الاخطر',
#   'منذ',
#   'غرق',
#   'الغواصة',
#   'السوفياتية',
#   'كومسوموليتس',
#   'قبالة',
#   'سواحل',
#   'النروج',
#   'في',
#   '1989',
#   'مما',
#   'اسفر',
#   'عن',
#   'مقتل',
#   '42',
#   'شخصا',
#   '.'],
#  ['دورة', 'واشنطن', ':', 'نتائج'],
#  ['واشنطن',
#   '15',
#   '-',
#   '8',
#   '(',
#   'أ',
#   'ف',
#   'ب',
#   ')',
#   '-',
#   'في',
#   'المرحلة',
#   'الاولى',
#   'من',
#   'دورة',
#   'واشنطن',
#   'الاميركية',
#   'الدولية',
#   'ل',
#   'كرة',
#   'المضرب',
#   'فاز',
#   'الفرنسي',
#   'جيروم',
#   'غولمار',
#   'على',
#   'السلوفاكي',
#   'يان',
#   'كروسلاك',
#   '6',
#   '-',
#   '4',
#   'و',
#   '6',
#   '-',
#   '2',
#   '،',
#   'و',
#   'الإيطالي',
#   'اندريا',
#   'غاودنزي',
#   'على',
#   'الالماني',
#   'راينر',
#   'شوتلر',
#   '6',
#   '-',
#   '4',
#   'و',
#   '6',
#   '-',
#   '4',
#   '،',
#   'و',
#   'البلجيكي',
#   'كريستوف',
#   'روشو',
#   'على',
#   'الاميركي',
#   'بوب',
#   'براين',
#   '3',
#   '-',
#   '6',
#   'و',
#   '6',
#   '-',
#   '3',
#   'و',
#   '6',
#   '-',
#   '4',
#   '،',
#   'و',
#   'الأرجنتيني',
#   'غييرمو',
#   'كوريا',
#   'على',
#   'السويسري',
#   'جورج',
#   'باستل',
#   '6',
#   '-',
#   '3',
#   'و',
#   '7',
#   '-',
#   '6',
#   'و',
#   '(',
#   '7',
#   '-',
#   '5',
#   ')',
#   '،',
#   'و',
#   'البرازيلي',
#   'فرناندو',
#   'ميليغيني',
#   'على',
#   'الكوستاريكي',
#   'خوان',
#   'انطونيو',
#   'مارين',
#   '6',
#   '-',
#   '7',
#   '(',
#   '4',
#   '-',
#   '7',
#   ')',
#   'و',
#   '6',
#   '-',
#   'صفر',
#   'و',
#   '6',
#   '-',
#   '1',
#   '.'],
#  ['و',
#   'فاز',
#   'التايلاندي',
#   'بارادورن',
#   'سريشافان',
#   'على',
#   'الاسترالي',
#   'جايسون',
#   'ستولتنبرغ',
#   '6',
#   '-',
#   '4',
#   'و',
#   '6',
#   '-',
#   '4',
#   '،',
#   'و',
#   'التشيكي',
#   'ييري',
#   'فانيك',
#   'على',
#   'الالماني',
#   'لارش',
#   'بورغسمولر',
#   '6',
#   '-',
#   '4',
#   'و',
#   '6',
#   '-',
#   '4',
#   '،',
#   'و',
#   'الإيطالي',
#   'دافيدي',
#   'سانغينتي',
#   'على',
#   'المجري',
#   'اتيلا',
#   'سافولت',
#   '6',
#   '-',
#   '3',
#   'و',
#   '6',
#   '-',
#   '2',
#   '،',
#   'و',
#   'الأميركي',
#   'كيفن',
#   'كيم',
#   'على',
#   'مواطن',
#   'ه',
#   'ديفيد',
#   'كيلدويل',
#   '6',
#   '-',
#   '3',
#   'و',
#   '4',
#   '-',
#   '6',
#   'و',
#   '6',
#   '-',
#   '3',
#   '،',
#   'و',
#   'التشيلي',
#   'فرناندو',
#   'غونزاليز',
#   'على',
#   'الاميركي',
#   'كريس',
#   'وودروف',
#   '6',
#   '-',
#   '4',
#   'و',
#   '1',
#   '-',
#   '6',
#   'و',
#   '6',
#   '-',
#   '3',
#   '،',
#   'و',
#   'الأسترالي',
#   'واين',
#   'ارثرز',
#   'على',
#   'الاميركي',
#   'ماشيسكا',
#   'واشنطن',
#   '6',
#   '-',
#   'صفر',
#   'و',
#   '6',
#   '-',
#   '1',
#   '،',
#   'و',
#   'الكرواتي',
#   'ايفان',
#   'ليوبيسيتش',
#   'على',
#   'الفرنسي',
#   'ستيفان',
#   'هويه',
#   '6',
#   '-',
#   '2',
#   'و',
#   '6',
#   '-',
#   '3',
#   '،',
#   'و',
#   'الإسباني',
#   'غالو',
#   'بلانكو',
#   'على',
#   'الاميركي',
#   'مايك',
#   'براين',
#   '7',
#   '-',
#   '5',
#   'و',
#   '6',
#   '-',
#   '7',
#   '(',
#   '4',
#   '-',
#   '7',
#   ')',
#   '6',
#   '-',
#   '1',
#   '،',
#   'و',
#   'الأميركي',
#   'اندي',
#   'روديك',
#   'على',
#   'الروماني',
#   'ادريان',
#   'فونيا',
#   '6',
#   '-',
#   '3',
#   'و',
#   '6',
#   '-',
#   '4',
#   '،',
#   'و',
#   'السلوفاكي',
#   'كارول',
#   'كوتشيرا',
#   'على',
#   'الاميركي',
#   'بول',
#   'هارسانيي',
#   '6',
#   '-',
#   '1',
#   'و',
#   '6',
#   '-',
#   'صفر',
#   '.'],
#  ['كوريا',
#   'الجنوبية',
#   'تطالب',
#   'ب',
#   'محادثات',
#   'عسكرية',
#   'مع',
#   'كوريا',
#   'الشمالية'],
#  ['سيول',
#   '15',
#   '-',
#   '8',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'طالب',
#   'رئيس',
#   'كوريا',
#   'الجنوبية',
#   'كيم',
#   'داي',
#   'جونغ',
#   'اليوم',
#   'الثلاثاء',
#   'ب',
#   'إجراء',
#   'محادثات',
#   'بين',
#   'وزيري',
#   'الدفاع',
#   'في',
#   'الكوريتين',
#   'ل',
#   'السماح',
#   'ب',
#   'انفراج',
#   'في',
#   'العلاقات',
#   'العسكرية',
#   'بين',
#   'هما',
#   '.'],
#  ['و',
#   'دعا',
#   'كيم',
#   'في',
#   'كلمة',
#   'ألقى',
#   'ها',
#   'ب',
#   'مناسبة',
#   'الذكرى',
#   'الخامسة',
#   'و',
#   'الخمسين',
#   'ل',
#   'التحرر',
#   'من',
#   'الاحتلال',
#   'الياباني',
#   'الى',
#   'وضع',
#   'حد',
#   'ل',
#   'خمسين',
#   'عاما',
#   'من',
#   'الحرب',
#   'الباردة',
#   'في',
#   'شبه',
#   'الجزيرة',
#   'الكورية',
#   '.'],
#  ['و',
#   'اعتبر',
#   'أن',
#   'ه',
#   'من',
#   'الضروري',
#   'عقد',
#   'اجتماع',
#   'بين',
#   'وزيري',
#   'الدفاع',
#   'ل',
#   'رفع',
#   'اي',
#   'تهديد',
#   'ب',
#   'الحرب',
#   'في',
#   'شبه',
#   'الجزيرة',
#   'الكورية',
#   'المنقسمة',
#   'منذ',
#   'العام',
#   '1945',
#   'و',
#   'التي',
#   'شهدت',
#   'حربا',
#   '(',
#   '1950',
#   '-',
#   '1953',
#   ')',
#   'بين',
#   'الكوريتين',
#   '.'],
#  ['و',
#   'شدد',
#   'في',
#   'الوقت',
#   'نفس',
#   'ه',
#   'على',
#   'ان',
#   'هذه',
#   'التبادلات',
#   'على',
#   'الصعيد',
#   'العسكري',
#   'يجب',
#   'ان',
#   'تتم',
#   'من',
#   'دون',
#   'اعادة',
#   'النظر',
#   'في',
#   'انتشار',
#   '37',
#   'الف',
#   'جندي',
#   'اميركي',
#   'في',
#   'كوريا',
#   'الجنوبية',
#   '.'],
#  ['و',
#   'قال',
#   'كيم',
#   '"',
#   'ان',
#   'القوات',
#   'الاميركية',
#   'تلعب',
#   'دورا',
#   'في',
#   'غاية',
#   'الاهمية',
#   'ليس',
#   'فقط',
#   'ل',
#   'جهة',
#   'تفادي',
#   'وقوع',
#   'حرب',
#   'بل',
#   'ايضا',
#   'على',
#   'صعيد',
#   'استقرار',
#   'المنطقة',
#   'في',
#   'شمال',
#   'شرق',
#   'اسيا',
#   '"',
#   '.'],
#  ['و',
#   'طلبت',
#   'كوريا',
#   'الجنوبية',
#   'خلال',
#   'القمة',
#   'التاريخية',
#   'بين',
#   'كيم',
#   'داي',
#   'جونغ',
#   'و',
#   'كين',
#   'جونغ',
#   'ايل',
#   'في',
#   'حزيران',
#   '/',
#   'يونيو',
#   'الماضي',
#   'اقامة',
#   'خط',
#   'هاتفي',
#   'عسكري',
#   'مباشر',
#   'ل',
#   'تفادي',
#   'اي',
#   'حادث',
#   'في',
#   'المستقبل',
#   '،',
#   'الا',
#   'ان',
#   'بيونغ',
#   'يانغ',
#   'لم',
#   'تعلق',
#   'بعد',
#   'على',
#   'الموضوع',
#   '.'],
#  ['وزير',
#   'اسرائيلي',
#   ':',
#   'اسرائيل',
#   'و',
#   'الفلسطينيون',
#   '"',
#   'قريبون',
#   '"',
#   'من',
#   'التوصل',
#   'الى',
#   'اتفاق',
#   'سلام'],
#  ['القدس',
#   '15',
#   '-',
#   '8',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'قال',
#   'وزير',
#   'العدل',
#   'الاسرائيلي',
#   'يوسي',
#   'بيلين',
#   'الثلاثاء',
#   'ان',
#   'اسرائيل',
#   'و',
#   'الفلسطينيين',
#   '"',
#   'قريبون',
#   '"',
#   'من',
#   'التوصل',
#   'الى',
#   'اتفاق',
#   'سلام',
#   '.'],
#  ['و',
#   'أضاف',
#   'بيلين',
#   'فى',
#   'تصريحات',
#   'ل',
#   'الإذاعة',
#   'الاسرائيلية',
#   'العامة',
#   '"',
#   'إن',
#   'نا',
#   'قريبون',
#   'من',
#   'الاتفاق',
#   'و',
#   'أقرب',
#   'مما',
#   'كنا',
#   'في',
#   'اي',
#   'وقت',
#   'مضى',
#   '"',
#   '.'],
#  ['و',
#   'تابع',
#   'الوزير',
#   'الذي',
#   'كان',
#   'يرد',
#   'على',
#   'اسئلة',
#   'الاذاعة',
#   'من',
#   'كندا',
#   'التى',
#   'يزور',
#   'ها',
#   'حاليا',
#   '"',
#   'ان',
#   'الطرفين',
#   'يعرفان',
#   'ب',
#   'شأن',
#   'مسالة',
#   'القدس',
#   'و',
#   'اللاجئين',
#   'ايضا',
#   '،',
#   'الى',
#   'اين',
#   'يتجهان',
#   'و',
#   'أين',
#   'هي',
#   'الخطوط',
#   'الحمر',
#   'ل',
#   'كل',
#   'طرف',
#   '"',
#   '.'],
#  ['و',
#   'كان',
#   'بيلين',
#   'الذي',
#   'يعتبر',
#   'احد',
#   'مهندسي',
#   'اتفاقات',
#   'اوسلو',
#   'ل',
#   'عام',
#   '1993',
#   'دعا',
#   'الى',
#   'ايجاد',
#   '"',
#   'حلول',
#   'خلاقة',
#   '"',
#   'بشان',
#   'مسالة',
#   'القدس',
#   '"',
#   'تطال',
#   'الرموز',
#   'و',
#   'لا',
#   'تؤثر',
#   'فعلا',
#   'على',
#   'الوضع',
#   'القائم',
#   'على',
#   'الارض',
#   '"',
# ...
#   'دولي',
#   'ل',
#   'المرة',
#   'الاخيرة',
#   'في',
#   '30',
#   'تموز',
#   '/',
#   'يوليو',
#   'عام',
#   '1999',
#   'خلال',
#   'دورة',
#   'الالعاب',
#   'الاميركية',
#   ':',
#   '"',
#   'كانت',
#   'لياقة',
#   'ي',
#   'جيدة',
#   'لكن',
#   'العصبية',
#   'غلبت',
#   'على',
#   'أداء',
#   'ي',
#   '"',
#   '.'],
#  ['و',
#   'كان',
#   'الاتحاد',
#   'الدولي',
#   'اوقف',
#   'سوتومايور',
#   'ل',
#   'مدة',
#   'سنتين',
#   'في',
#   'اب',
#   '/',
#   'اغسطس',
#   'العام',
#   'الماضي',
#   'ل',
#   'ثبوت',
#   'تناول',
#   'ه',
#   'كوكايين',
#   'خلال',
#   'الالعاب',
#   'الاميركية',
#   'قبل',
#   'ان',
#   'يخفف',
#   'العقوبة',
#   'قبل',
#   'اسبوعين',
#   'الى',
#   'سنة',
#   'واحدة',
#   'فقط',
#   '،',
#   'و',
#   'ب',
#   'التالي',
#   'السماح',
#   'ل',
#   'ه',
#   'ب',
#   'المشاركة',
#   'في',
#   'دورة',
#   'الالعاب',
#   'الاولمبية',
#   'في',
#   'سيدني',
#   'الشهر',
#   'المقبل',
#   '.'],
#  ['و',
#   'قال',
#   'سوتومايور',
#   'عندما',
#   'تلقى',
#   'نبأ',
#   'تخفيف',
#   'العقوبة',
#   ':',
#   '"',
#   'كنت',
#   'سعيدا',
#   'ل',
#   'الغاية',
#   'و',
#   'احتفلت',
#   'مع',
#   'بعض',
#   'الاصدقاء',
#   '،',
#   'و',
#   'لم',
#   'اكن',
#   'اشك',
#   'ابدا',
#   'في',
#   'براءة',
#   'ي',
#   '"',
#   '.'],
#  ['و',
#   'أضاف',
#   '"',
#   'كنت',
#   'واثقا',
#   'من',
#   'مشاركة',
#   'ي',
#   'في',
#   'سيدني',
#   'و',
#   'من',
#   'ان',
#   'الاتحاد',
#   'الدولي',
#   'س',
#   'يقف',
#   'الى',
#   'جانب',
#   'ي',
#   'لان',
#   'قضية',
#   'ي',
#   'عادلة',
#   '"',
#   '.'],
#  ['بيد',
#   'ان',
#   'هذا',
#   'الامر',
#   'لا',
#   'يعني',
#   'ان',
#   'سوتومايور',
#   'قلب',
#   'الصفحة',
#   'مع',
#   'الاتحاد',
#   'الدولي',
#   'و',
#   'يقول',
#   'في',
#   'هذا',
#   'الصدد',
#   ':',
#   '"',
#   'س',
#   'أتشاور',
#   'مع',
#   'محامي',
#   'ي',
#   'بعد',
#   'سيدني',
#   'ل',
#   'معرفة',
#   'امكانية',
#   'اللجوء',
#   'الى',
#   'المحكمة',
#   'ل',
#   'محو',
#   'الاثار',
#   'التي',
#   'شوهت',
#   'سمعة',
#   'ي',
#   '"',
#   '.'],
#  ['و',
#   'اعترف',
#   'سوتومايور',
#   'ب',
#   'أن',
#   'الرقم',
#   'الذي',
#   'سجل',
#   'ه',
#   'اليوم',
#   'ليس',
#   'كافيا',
#   'ل',
#   'المنافسة',
#   'على',
#   'المراكز',
#   'الثلاثة',
#   'الاولى',
#   'في',
#   'سيدني',
#   '،',
#   'و',
#   'ب',
#   'أن',
#   'علي',
#   'ه',
#   'بذل',
#   'المزيد',
#   'من',
#   'الجهود',
#   'في',
#   'الايام',
#   'التي',
#   'تفصل',
#   'ه',
#   'عن',
#   'الموعد',
#   'الكبير',
#   '.'],
#  ['و',
#   'س',
#   'يخوض',
#   'سوتومايور',
#   'لقاء',
#   'موناكو',
#   'الفرنسي',
#   'ضمن',
#   'الدوري',
#   'الذهبي',
#   'يوم',
#   'الجمعة',
#   'المقبل',
#   '.'],
#  ['و',
#   'لقي',
#   'النجم',
#   'العائد',
#   'استقبالا',
#   'حافلا',
#   'من',
#   'الجمهور',
#   'و',
#   'بدأ',
#   'المسابقة',
#   'على',
#   'ارتفاع',
#   '19',
#   'ر',
#   '2',
#   'م',
#   'ب',
#   'سهولة',
#   'ثم',
#   '28',
#   'ر',
#   '2',
#   'م',
#   '،',
#   'في',
#   'حين',
#   'فشل',
#   '3',
#   'مرات',
#   'في',
#   'اجتياز',
#   'ارتفاع',
#   '33',
#   'ر',
#   '2',
#   'م',
#   '.'],
#  ['و',
#   'ختم',
#   'الكوبي',
#   'الطائر',
#   'حامل',
#   'ذهبية',
#   'اولمبياد',
#   'برشلونة',
#   'عام',
#   '1992',
#   ':',
#   '"',
#   'يتمثل',
#   'الحلم',
#   'في',
#   'احراز',
#   'ذهبية',
#   'اولمبياد',
#   'سيدني',
#   '،',
#   'على',
#   'اي',
#   'حال',
#   'ف',
#   'إن',
#   'احتلال',
#   'احد',
#   'المراكز',
#   'الثلاثة',
#   'الاولى',
#   'يؤكد',
#   'ب',
#   'أن',
#   'ني',
#   'استعيد',
#   'مستوى',
#   'ي',
#   'السابق',
#   'تدريجيا',
#   '"',
#   '.'],
#  ['دورة', 'قطر', 'الدولية', ':', 'فوز', 'ايران', 'على', 'مصر', '3', '-', '2'],
#  ['الدوحة',
#   '15',
#   '-',
#   '8',
#   '(',
#   'أ',
#   'ف',
#   'ب',
#   ')',
#   '-',
#   'حققت',
#   'ايران',
#   'فوزا',
#   'مثيرا',
#   'على',
#   'مصر',
#   '3',
#   '-',
#   '2',
#   '(',
#   'الاشواط',
#   '31',
#   '-',
#   '29',
#   'و',
#   '26',
#   '-',
#   '24',
#   'و',
#   '26',
#   '-',
#   '28',
#   'و',
#   '22',
#   '-',
#   '25',
#   'و',
#   '15',
#   '-',
#   '10',
#   ')',
#   'و',
#   'صعدت',
#   'الى',
#   'المركز',
#   'الاول',
#   'في',
#   'البطولة',
#   'الدولية',
#   'الودية',
#   'في',
#   'الكرة',
#   'الطائرة',
#   'التي',
#   'تستضيف',
#   'ها',
#   'قطر',
#   'و',
#   'تختتم',
#   'غدا',
#   'الاربعاء',
#   '.'],
#  ['و',
#   'رفعت',
#   'ايران',
#   'رصيد',
#   'ها',
#   'الى',
#   '9',
#   'نقاط',
#   'تلي',
#   'ها',
#   'قطر',
#   '8',
#   'نقاط',
#   'ثم',
#   'مصر',
#   'و',
#   'ل',
#   'ها',
#   '7',
#   'نقاط',
#   '.'],
#  ['و',
#   'في',
#   'مباراة',
#   'ثانية',
#   '،',
#   'حقق',
#   'الاردن',
#   'فوز',
#   'ه',
#   'الاول',
#   'و',
#   'كان',
#   'على',
#   'منتخب',
#   'شباب',
#   'مصر',
#   '3',
#   '-',
#   '2',
#   '(',
#   '26',
#   '-',
#   '24',
#   'و',
#   '23',
#   '-',
#   '25',
#   'و',
#   '27',
#   '-',
#   '25',
#   'و',
#   '20',
#   '-',
#   '25',
#   'و',
#   '19',
#   '-',
#   '17',
#   '.'],
#  ['و',
#   'تلعب',
#   'غدا',
#   'قطر',
#   'مع',
#   'مصر',
#   '،',
#   'و',
#   'في',
#   'حال',
#   'فوز',
#   'الاولى',
#   'س',
#   'تتوج',
#   'بطلة',
#   '،',
#   'في',
#   'حين',
#   'يلعب',
#   'شباب',
#   'مصر',
#   'مع',
#   'الطيران',
#   'الكوري',
#   'في',
#   'مباراة',
#   'هامشية',
#   '.'],
#  ['قوة',
#   'من',
#   'الشرطة',
#   'القضائية',
#   'و',
#   'الجيش',
#   'اللبناني',
#   'تقتل',
#   'رئيس',
#   'عصابة',
#   'اجرامية',
#   'في',
#   'تبادل',
#   'اطلاق',
#   'نار'],
#  ['بيروت',
#   '15',
#   '-',
#   '8',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'اعلن',
#   'مصدر',
#   'رسمي',
#   'اليوم',
#   'الثلاثاء',
#   'ان',
#   'عناصر',
#   'من',
#   'الشرطة',
#   'القضائية',
#   'و',
#   'الجيش',
#   'اللبناني',
#   'قتلت',
#   'المطلوب',
#   'طيفور',
#   'المقداد',
#   'في',
#   'شرق',
#   'لبنان',
#   'حيث',
#   'ينتشر',
#   'الجيش',
#   'السوري',
#   '.'],
#  ['و',
#   'قالت',
#   'الوكالة',
#   'الوطنية',
#   'ل',
#   'الإعلام',
#   'ان',
#   '"',
#   'عناصر',
#   'من',
#   'الشرطة',
#   'القضائية',
#   'ب',
#   'مؤازرة',
#   'من',
#   'الجيش',
#   'اللبناني',
#   'قامت',
#   'ب',
#   'مداهمة',
#   'منزل',
#   'المطلوب',
#   'طيفور',
#   'المقداد',
#   '(',
#   '39',
#   'سنة',
#   ')',
#   'في',
#   'مقنة',
#   'قضاء',
#   'بعلبك',
#   'ف',
#   'بادر',
#   'الدورية',
#   'ب',
#   'النار',
#   'التي',
#   'ردت',
#   'علي',
#   'ه',
#   'ب',
#   'المثل',
#   'مما',
#   'ادى',
#   'الى',
#   'إصابة',
#   'ه',
#   'و',
#   'نقل',
#   'ه',
#   'الى',
#   'احد',
#   'مستشفيات',
#   'المنطقة',
#   'حيث',
#   'ما',
#   'لبث',
#   'ان',
#   'فارق',
#   'الحياة',
#   '"',
#   '.'],
#  ['و',
#   'جاء',
#   'في',
#   'بيان',
#   'ل',
#   'مديرية',
#   'التوجيه',
#   'في',
#   'الجيش',
#   'اللبناني',
#   'أن',
#   'ه',
#   '"',
#   'ب',
#   'تاريخ',
#   'اليوم',
#   'الثلاثاء',
#   'داهمت',
#   'دورية',
#   'من',
#   'الشرطة',
#   'القضائية',
#   'تؤازر',
#   'ها',
#   'قوة',
#   'من',
#   'الجيش',
#   'منزل',
#   'المدعو',
#   'طيفور',
#   'المقداد',
#   'في',
#   'بلدة',
#   'مقنة',
#   'في',
#   'قضاء',
#   'بعلبك',
#   'و',
#   'المتهم',
#   'ب',
#   'جرائم',
#   'مختلفة',
#   '،',
#   'و',
#   'تعرضت',
#   'ل',
#   'إطلاق',
#   'نار',
#   'من',
#   'داخل',
#   'المنزل',
#   'ف',
#   'ردت',
#   'على',
#   'النار',
#   'ب',
#   'المثل',
#   'مما',
#   'ادى',
#   'الى',
#   'مقتل',
#   'ه',
#   '"',
#   '.'],
#  ['و',
#   'أضاف',
#   'البيان',
#   'ان',
#   '"',
#   'بعضا',
#   'من',
#   'مرافقي',
#   'ه',
#   'فروا',
#   'في',
#   'ما',
#   'بعد',
#   'الى',
#   'الجرود',
#   'المجاورة',
#   'و',
#   'لا',
#   'تزال',
#   'قوى',
#   'الجيش',
#   'تقوم',
#   'ب',
#   'تطويق',
#   'المنطقة',
#   'و',
#   'ملاحقة',
#   'الفارين',
#   '"',
#   '.'],
#  ['اوضحت',
#   'الشرطة',
#   'ان',
#   'المقداد',
#   'مطلوب',
#   'ب',
#   'موجب',
#   '177',
#   'مذكرة',
#   'عدلية',
#   'ب',
#   'جرائم',
#   'سرقة',
#   'سيارات',
#   'و',
#   'اتجار',
#   'ب',
#   'المخدرات',
#   'و',
#   'قتل',
#   'و',
#   'اتجار',
#   'ب',
#   'السلاح',
#   'و',
#   'ترويج',
#   'عملات',
#   'مزورة',
#   'و',
#   'تشكيل',
#   'عصابات',
#   'منظمة',
#   'و',
#   'مقاومة',
#   'رجال',
#   'قوى',
#   'الامن',
#   '.'],
#  ['تصفيات',
#   'مونديال',
#   '2001',
#   ':',
#   'احداث',
#   'شغب',
#   'ترافق',
#   'فوز',
#   'الاردن',
#   'على',
#   'الامارات',
#   '35',
#   '-',
#   '33'],
#  ['عمان',
#   '15',
#   '-',
#   '8',
#   '(',
#   'أ',
#   'ف',
#   'ب',
#   ')',
#   '-',
#   'فاز',
#   'الاردن',
#   'على',
#   'الامارات',
#   '35',
#   '-',
#   '33',
#   'بعد',
#   'التمديد',
#   'اثر',
#   'انتهاء',
#   'الوقت',
#   'الاصلي',
#   'ب',
#   'التعادل',
#   '28',
#   '-',
#   '28',
#   '(',
#   'الشوط',
#   'الاول',
#   '16',
#   '-',
#   '16',
#   ')',
#   'اليوم',
#   'الثلاثاء',
#   'في',
#   'مباراة',
#   'تحديد',
#   'المركزين',
#   'الخامس',
#   'و',
#   'السادس',
#   'ضمن',
#   'تصفيات',
#   'مجموعة',
#   'غرب',
#   'آسيا',
#   'ل',
#   'كرة',
#   'اليد',
#   'التي',
#   'تقام',
#   'في',
#   'الاردن',
#   'و',
#   'المؤهلة',
#   'الى',
#   'نهائيات',
#   'كأس',
#   'العالم',
#   'المقررة',
#   'في',
#   'فرنسا',
#   'من',
#   '23',
#   'كانون',
#   'الثاني',
#   '/',
#   'يناير',
#   'الى',
#   '4',
#   'شباط',
#   '/',
#   'فبراير',
#   'المقبلين',
#   '.'],
#  ['و',
#   'طغت',
#   'احداث',
#   'الشغب',
#   'على',
#   'اجواء',
#   'المباراة',
#   '،',
#   'اذ',
#   'اشتبك',
#   'لاعبو',
#   'المنتخبين',
#   'في',
#   'ما',
#   'بين',
#   'هم',
#   'عقب',
#   'نهاية',
#   'ها',
#   'ل',
#   'دقائق',
#   'عدة',
#   '.'],
#  ['و',
#   'كانت',
#   'بداية',
#   'اعمال',
#   'الشغب',
#   'اندلعت',
#   'اثر',
#   'اشتباك',
#   'اللاعب',
#   'الاردني',
#   'اسماعيل',
#   'بني',
#   'هاني',
#   'مع',
#   'لاعب',
#   'اماراتي',
#   'قرب',
#   'غرف',
#   'تبديل',
#   'الملابس',
#   '،',
#   'ف',
#   'ما',
#   'كان',
#   'من',
#   'ه',
#   'بعد',
#   'الا',
#   'ان',
#   'غادر',
#   'ارض',
#   'الملعب',
#   'و',
#   'جلس',
#   'على',
#   'المدرجات',
#   'في',
#   'الشوط',
#   'الاول',
#   'احتجاجا',
#   'على',
#   'استبدال',
#   'ه',
#   '.'],
#  ['و',
#   'بعد',
#   'المباراة',
#   '،',
#   'و',
#   'بينما',
#   'كان',
#   'لاعبو',
#   'الاردن',
#   'يصافحون',
#   'الرئيسة',
#   'الفخرية',
#   'ل',
#   'الاتحاد',
#   'الاردني',
#   'ل',
#   'اللعبة',
#   'الاميرة',
#   'سمية',
#   'بنت',
#   'الحسين',
#   'على',
#   'المنصة',
#   '،',
#   'شاهدوا',
#   'لاعبي',
#   'الامارات',
#   'يلاحقون',
#   'زميل',
#   'هم',
#   'بني',
#   'هاني',
#   '،',
#   'ف',
#   'عادوا',
#   'ب',
#   'سرعة',
#   'الى',
#   'ارض',
#   'الملعب',
#   'ل',
#   'الدفاع',
#   'عن',
#   'ه',
#   'ف',
#   'شمل',
#   'الاشتباك',
#   'جميع',
#   'لاعبي',
#   'المنتخبين',
#   'في',
#   'مشهد',
#   'مؤلم',
#   'استخدمت',
#   'في',
#   'ه',
#   'الكراسي',
#   'و',
#   'زجاجات',
#   'المياه',
#   'و',
#   'حقائب',
#   'اللاعبين',
#   'و',
#   'تدخلت',
#   'الشرطة',
#   'الاردنية',
#   'ب',
#   'الهراوات',
#   'و',
#   'أصيب',
#   'من',
#   'ها',
#   'اربعة',
#   'اشخاص',
#   'بعد',
#   'ان',
#   'حاولوا',
#   'تدارك',
#   'الاحداث',
#   '.'],
#  ['يذكر',
#   'ان',
#   'الدورة',
#   'شهدت',
#   'احداث',
#   'شغب',
#   'ايضا',
#   'امس',
#   'الاثنين',
#   'قبل',
#   'نهاية',
#   'مباراة',
#   'الكويت',
#   'و',
#   'سوريا',
#   '.'],
#  ['اصابة',
#   'ثلاثة',
#   'في',
#   'اشتباك',
#   'بين',
#   'جنود',
#   'اسرائيليين',
#   'و',
#   'رجال',
#   'شرطة',
#   'فلسطينيين',
#   'في',
#   'غزة'],
#  ['غزة',
#   '15',
#   '-',
#   '8',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'اكد',
#   'مصدر',
#   'امني',
#   'فلسطيني',
#   'اليوم',
#   'الثلاثاء',
#   'ل',
#   'وكالة',
#   'فرانس',
#   'برس',
#   'ان',
#   'اشتباكا',
#   'ب',
#   'الأيدي',
#   'وقع',
#   'مساء',
#   'اليوم',
#   'بين',
#   'جنود',
#   'اسرائيليين',
#   'و',
#   'عناصر',
#   'من',
#   'قوات',
#   'الامن',
#   'الوطني',
#   'الفلسطيني',
#   'عند',
#   'حاجز',
#   'مشترك',
#   'قرب',
#   'مستوطنة',
#   'نتساريم',
#   'جنوب',
#   'غزة',
#   '،',
#   'مما',
#   'ادى',
#   'الى',
#   'جرح',
#   'اثنين',
#   'من',
#   'الجانب',
#   'الفلسطيني',
#   'و',
#   'جندي',
#   'اسرائيلي',
#   '.'],
#  ['و',
#   'أكد',
#   'المصدر',
#   'الامني',
#   'ان',
#   'مشادة',
#   'بين',
#   'عنصرين',
#   'من',
#   'الجانبين',
#   'لم',
#   'تتضح',
#   'أسباب',
#   'ها',
#   '،',
#   'تطورت',
#   'الى',
#   'اشتباك',
#   'استخدمت',
#   'في',
#   'ه',
#   'اعقاب',
#   'البنادق',
#   'من',
#   'الطرفين',
#   'بعد',
#   'ان',
#   'وصلت',
#   'تعزيزات',
#   'اسرائيلية',
#   '.'],
#  ['و',
#   'أضاف',
#   'المصدر',
#   'ان',
#   'ذلك',
#   'ادى',
#   'الى',
#   'اصابة',
#   'ضابط',
#   'و',
#   'أحد',
#   'عناصر',
#   'الامن',
#   'الفلسطيني',
#   'في',
#   'الراس',
#   'نتيجة',
#   'ضرب',
#   'هما',
#   'ب',
#   'أعقاب',
#   'البنادق',
#   'من',
#   'قبل',
#   'الجنود',
#   'الاسرائيليين',
#   '.',
#   'و',
#   'أصيب',
#   'ايضا',
#   'جندي',
#   'اسرائيلي',
#   'ب',
#   'جروح',
#   '.'],
#  ['و',
#   'نقل',
#   'الجريحان',
#   'الفلسطينيان',
#   'على',
#   'الفور',
#   'الى',
#   'مستشفى',
#   'الشفاء',
#   'في',
#   'غزة',
#   'ل',
#   'تلقي',
#   'العلاج',
#   'و',
#   'وصفت',
#   'حالة',
#   'الضابط',
#   'ب',
#   'السيئة',
#   '.'],
#  ['و',
#   'أشار',
#   'المصدر',
#   'نفس',
#   'ه',
#   'الى',
#   'ان',
#   'احد',
#   'الجنود',
#   'الاسرائيليين',
#   'ترك',
#   'بندقية',
#   'ه',
#   'اثناء',
#   'العراك',
#   'و',
#   'تم',
#   'تسليم',
#   'ها',
#   'في',
#   'ما',
#   'بعد',
#   'عبر',
#   'لجنة',
#   'الارتباط',
#   'الفلسطينية',
#   'الاسرائيلية',
#   'المشتركة',
#   'ل',
#   'الجانب',
#   'الاسرائيلي',
#   '،',
#   'و',
#   'أوضح',
#   'ان',
#   '"',
#   'لجنة',
#   'الارتباط',
#   'المشتركة',
#   'تحقق',
#   'في',
#   'الحادث',
#   'حاليا',
#   'بعد',
#   'ان',
#   'هدأت',
#   'الامور',
#   '"',
#   '.'],
#  ['الجبهة',
#   'الشعبية',
#   'و',
#   'حزب',
#   'الخلاص',
#   'يحذران',
#   'من',
#   'تاجيل',
#   'اعلان',
#   'الدولة',
#   'الفلسطينية'],
#  ['غزة',
#   '15',
#   '-',
#   '8',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'حذرت',
#   'الجبهة',
#   'الشعبية',
#   'ل',
#   'تحرير',
#   'فلسطين',
#   'و',
#   'حزب',
#   'الخلاص',
#   'الوطني',
#   '،',
#   'الاسلامي',
#   'القريب',
#   'من',
#   'حركة',
#   'حماس',
#   '،',
#   'من',
#   'اية',
#   'محاولات',
#   'او',
#   'اف',
#   'من',
#   'ه',
#   'الى',
#   'وكالة',
#   'فرانس',
#   'برس',
#   'الى',
#   '"',
#   'ضرورة',
#   'الحفاظ',
#   'على',
#   'المصداقية',
#   'في',
#   'هذا',
#   'الخصوص',
#   'و',
#   'إلا',
#   'ف',
#   'إن',
#   'الدولة',
#   'س',
#   'تتحول',
#   'الى',
#   'ورقة',
#   'استهلاكية',
#   'تستخدم',
#   'في',
#   'المناسبات',
#   '"',
#   '.'],
#  ['و',
#   'أكدا',
#   'على',
#   '"',
#   'ضرورة',
#   'عدم',
#   'استجابة',
#   'السلطة',
#   'الفلسطينية',
#   'ل',
#   'أي',
#   'دعوات',
#   'ل',
#   'حضور',
#   'قمة',
#   'جديدة',
#   'على',
#   'غرار',
#   'كامب',
#   'ديفيد',
#   '"',
#   'و',
#   'شددا',
#   'على',
#   'ان',
#   '"',
#   'فشل',
#   'القمة',
#   'السابقة',
#   'يجب',
#   'ان',
#   'يمثل',
#   'دافعا',
#   'ل',
#   'تجنب',
#   'المخاطر',
#   '"',
#   '.'],
#  ['و',
#   'من',
#   'جهة',
#   'اخرى',
#   'دعت',
#   'الجبهة',
#   'و',
#   'الحزب',
#   'الى',
#   '"',
#   'المباشرة',
#   'في',
#   'الاعداد',
#   'ل',
#   'تشكيل',
#   'مجلس',
#   'وطني',
#   'على',
#   'قاعدة',
#   'الانتخاب',
#   'الحر',
#   'النزيه',
#   'و',
#   'تمكين',
#   'شعب',
#   'نا',
#   'في',
#   'الوطن',
#   'و',
#   'الشتات',
#   'من',
#   'ممارسة',
#   'حق',
#   'ه',
#   'في',
#   'انتخاب',
#   'ممثلي',
#   'ه',
#   '"',
#   '.'],
#  ['يشار',
#   'الى',
#   'ان',
#   'الجبهة',
#   'الشعبية',
#   'و',
#   'الحزب',
#   'القريب',
#   'من',
#   'حماس',
#   'كانا',
#   'شاركا',
#   'في',
#   'اجتماعات',
#   'المجلس',
#   'المركزي',
#   'الفلسطيني',
#   'الذي',
#   'اتخذ',
#   'قرارا',
#   'ب',
#   'تجميد',
#   'اعلان',
#   'الدولة',
#   'الفلسطينية',
#   'المستقلة',
#   'في',
#   '13',
#   'ايلول',
#   '/',
#   'سبتمبر',
#   'المقبل',
#   '.'],
#  ['تصفيات',
#   'مونديال',
#   '2002',
#   '-',
#   'الكونكاكاف',
#   ':',
#   'فوز',
#   'كوستاريكا',
#   'على',
#   'غواتيمالا',
#   '2',
#   '-',
#   '1'],
#  ['سان',
#   'خوسيه',
#   '15',
#   '-',
#   '8',
#   '(',
#   'ا',
#   'ف',
#   'ب',
#   ')',
#   '-',
#   'قاد',
#   'مهاجم',
#   'مانشستر',
#   'سيتي',
#   'الانكليزي',
#   'الجديد',
#   'باولو',
#   'وانتشوب',
#   'منتخب',
#   'بلاد',
#   'ه',
#   'كوستاريكا',
#   'الى',
#   'الفوز',
#   'على',
#   'غواتيمالا',
#   '2',
#   '-',
#   '1',
#   'في',
#   'سان',
#   'خوسيه',
#   'مساء',
#   'اليوم',
#   'الثلاثاء',
#   'في',
#   'افتتاح',
#   'الجولة',
#   'الثالثة',
#   'من',
#   'الدور',
#   'نصف',
#   'النهائي',
#   'ل',
#   'تصفيات',
#   'المجموعة',
#   'الخامسة',
#   'ل',
#   'الكونكاكاف',
#   '(',
#   'اميركا',
#   'الشمالية',
#   'و',
#   'الوسطى',
#   'و',
#   'البحر',
#   'الكاريبي',
#   ')',
#   '.'],
#  ['و',
#   'سجل',
#   'وانتشوب',
#   'هدفي',
#   'كوستاريكا',
#   '(',
#   '33',
#   'و',
#   '57',
#   ')',
#   '،',
#   'وبيتزاروتزي',
#   '(',
#   '67',
#   ')',
#   'هدف',
#   'غواتيمالا',
#   '.'],
#  ['الغواصة',
#   'كورسك',
#   ':',
#   'ضباط',
#   'روس',
#   'استشاروا',
#   'خبراء',
#   'من',
#   'الحلف',
#   'الاطلسي'],
#  ['بروكسل',
#   '15',
#   '-',
#   '8',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'اعلن',
#   'حلف',
#   'شمال',
#   'الاطلسي',
#   'اليوم',
#   'الثلاثاء',
#   'ان',
#   'وفدا',
#   'من',
#   'الضباط',
#   'الروس',
#   'زار',
#   'رئاسة',
#   'اركان',
#   'الحلف',
#   'في',
#   'بروكسل',
#   'اليوم',
#   'و',
#   'ناقشوا',
#   'مع',
#   'خبراء',
#   'في',
#   'الحلف',
#   'امكانات',
#   'انقاذ',
#   'الغواصة',
#   'النووية',
#   'كورسك',
#   'الراسية',
#   'في',
#   'اعماق',
#   'بحر',
#   'بارنتس',
#   '.'],
#  ['و',
#   'أضاف',
#   'الحلف',
#   'ان',
#   'موسكو',
#   'لم',
#   'تتقدم',
#   'ب',
#   'طلب',
#   'رسمي',
#   '،',
#   'مشيرا',
#   'الى',
#   'ان',
#   'الضباط',
#   'الروس',
#   'تحادثوا',
#   'طوال',
#   'نصف',
#   'ساعة',
#   'ايضا',
#   'عبر',
#   'حوار',
#   'تلفوني',
#   'مع',
#   'المتخصصين',
#   'في',
#   'مسائل',
#   'الغواصات',
#   'في',
#   'الحلف',
#   'الاطلسي',
#   'في',
#   'نورثوود',
#   '(',
#   'بريطانيا',
#   ')',
#   '.'],
#  ['الانفصاليون',
#   'يؤكدون',
#   'قتل',
#   '12',
#   'شيشانيا',
#   'مواليا',
#   'ل',
#   'الروس',
#   'خلال',
#   'شهر'],
#  ['سليبتسوفسك',
#   '(',
#   'روسيا',
#   ')',
#   '15',
#   '-',
#   '8',
#   '(',
#   'اف',
#   'ب',
#   ')',
#   '-',
#   'اكد',
#   'الانفصاليون',
#   'الشيشان',
#   '،',
#   'في',
#   'بيان',
#   'أصدر',
#   'ه',
#   'المركز',
#   'الصحافي',
#   'ل',
#   'الرئيس',
#   'اصلان',
#   'مسخادوف',
#   'و',
#   'تلقت',
#   'وكالة',
#   'فرانس',
#   'برس',
#   'نسخة',
#   'من',
#   'ه',
#   'اليوم',
#   'الثلاثاء',
#   '،',
#   'أن',
#   'هم',
#   '"',
#   'نفذوا',
#   'حكم',
#   'الاعدام',
#   '"',
#   'ب',
#   '12',
#   'شيشانيا',
#   'مواليا',
#   'ل',
#   'الروس',
#   'الشهر',
#   'الماضي',
#   '.'],
#  ['و',
#   'أضاف',
#   'البيان',
#   'ان',
#   '"',
#   'اثني',
#   'عشر',
#   'خائنا',
#   'يتعاملون',
#   'مع',
#   'ادارة',
#   'احمد',
#   'قديروف',
#   '(',
#   'الذي',
#   'عينت',
#   'ه',
#   'موسكو',
#   ')',
#   'قتلوا',
#   'خلال',
#   'شهر',
#   '،',
#   'من',
#   'هم',
#   'سبعة',
#   'من',
#   'كبار',
#   'الموظفين',
#   '"',
#   '،',
#   'تنفيذا',
#   'ل',
#   'أحكام',
#   'أصدرت',
#   'ها',
#   'محكمة',
#   'الشريلتعامل',
#   'مع',
#   'الادارة',
#   'الموالية',
#   'ل',
#   'روسيا',
#   '.'],
#  ...]

# %%
pos_tags
# Out:
# [['X',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'X',
#   'PUNCT',
#   'ADJ'],
#  ['X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'X',
#   'X',
#   'X',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'SCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'X',
#   'NUM',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'DET',
#   'VERB',
#   'NOUN',
#   'X',
#   'ADJ',
#   'PUNCT',
#   'ADP',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'X',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'X',
#   'NUM',
#   'X',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'X',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'ADJ',
#   'CCONJ',
#   'VERB',
#   'NUM',
#   'NUM',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'SCONJ',
#   'NOUN',
#   'X',
#   'VERB',
#   'SCONJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'X',
#   'NUM',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'X',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'X',
#   'X',
#   'NOUN',
#   'ADP',
#   'X',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'SCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'X',
#   'X',
#   'ADP',
#   'SCONJ',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NUM',
#   'ADP',
#   'X',
#   'X',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'ADP',
#   'X',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'X',
#   'CCONJ',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'X',
#   'NUM',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'SCONJ',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'ADJ',
#   'PUNCT'],
#  ['NOUN',
#   'DET',
#   'PART',
#   'VERB',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'X'],
#  ['X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'SCONJ',
#   'DET',
#   'PART',
#   'VERB',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'X',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'SCONJ',
#   'NOUN',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'X',
#   'ADP',
#   'X',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'PUNCT',
#   'VERB',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'PART',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['DET', 'NOUN', 'ADP', 'NOUN', 'NUM', 'NOUN', 'PUNCT', 'NOUN'],
#  ['NUM',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'X',
#   'PUNCT'],
#  ['NUM',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'ADJ',
#   'ADP',
#   'DET',
#   'VERB',
#   'DET',
#   'PUNCT',
#   'PUNCT'],
#  ['NUM',
#   'PUNCT',
#   'X',
#   'PUNCT',
#   'NOUN',
#   'X',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'X',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'PUNCT'],
#  ['NUM',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'X',
#   'X',
#   'VERB',
#   'ADP',
#   'X',
#   'ADP',
#   'SCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'PUNCT'],
#  ['NUM',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'X',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'PUNCT'],
#  ['NUM',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['NUM', 'PUNCT', 'NOUN', 'NOUN', 'ADJ', 'X', 'X', 'PUNCT'],
#  ['NUM', 'PUNCT', 'NOUN', 'NOUN', 'X', 'X', 'X', 'X', 'PUNCT'],
#  ['NUM',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'X',
#   'X',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'PUNCT'],
#  ['NUM',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'X',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'CCONJ',
#   'NOUN',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'X',
#   'ADJ',
#   'PUNCT'],
#  ['NUM',
#   'PUNCT',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NUM',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['DET', 'NOUN', 'ADP', 'NOUN', 'NUM', 'NOUN', 'PUNCT', 'NOUN'],
#  ['NUM', 'PUNCT', 'NOUN', 'NOUN', 'CCONJ', 'NOUN', 'ADJ', 'X', 'X', 'PUNCT'],
#  ['NUM',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'X',
#   'X',
#   'X',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'PUNCT'],
#  ['NUM',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'X',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'PUNCT'],
#  ['NUM',
#   'PUNCT',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NUM',
#   'PUNCT'],
#  ['NUM',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'X',
#   'PUNCT'],
#  ['NUM',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'X',
#   'X',
#   'X',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'X',
#   'X',
#   'X',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['NUM',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'X',
#   'VERB',
#   'NOUN',
#   'DET',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['NUM',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'X',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'PUNCT'],
#  ['NUM',
#   'PUNCT',
#   'X',
#   'PUNCT',
#   'NOUN',
#   'X',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NUM',
#   'ADJ',
#   'PUNCT'],
#  ['NUM',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'X',
#   'CCONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'X',
#   'X',
#   'X',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NUM',
#   'ADP',
#   'X',
#   'PUNCT'],
#  ['NUM',
#   'PUNCT',
#   'X',
#   'ADP',
#   'X',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'PUNCT',
#   'X',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['NUM',
#   'PUNCT',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NUM',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'NUM',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'ADP',
#   'NUM',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT'],
#  ['NOUN',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'X'],
#  ['X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'SCONJ',
#   'NOUN',
#   'VERB',
#   'CCONJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'X',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'SCONJ',
#   'X',
#   'X',
#   'PUNCT',
#   'NUM',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'X',
#   'X',
#   'PUNCT',
#   'NUM',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'X',
#   'NOUN',
#   'X',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'DET',
#   'VERB',
#   'NUM',
#   'SYM',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'X',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'NUM',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'X',
#   'X',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'PART',
#   'VERB',
#   'ADJ',
#   'ADV',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'X',
#   'X',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'SCONJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'CCONJ',
#   'CCONJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'SCONJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'NUM',
#   'NOUN',
#   'CCONJ',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'X',
#   'ADP',
#   'ADV',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['NOUN', 'ADJ', 'VERB', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'X', 'X'],
#  ['X',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'X',
#   'X',
#   'X',
#   'PUNCT',
#   'VERB',
#   'ADP',
#   'SCONJ',
#   'PRON',
#   'AUX',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'PUNCT',
#   'PART',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'DET',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'X',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'SCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NUM',
#   'CCONJ',
#   'X',
#   'PUNCT',
#   'DET',
#   'AUX',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'X',
#   'CCONJ',
#   'AUX',
#   'VERB',
#   'ADP',
#   'X',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'ADJ',
#   'PUNCT',
#   'CCONJ',
#   'AUX',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'X',
#   'X',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADV',
#   'ADP',
#   'SCONJ',
#   'NOUN',
#   'NOUN',
#   'X',
#   'X',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'ADJ',
#   'PUNCT'],
#  ['NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NUM',
#   'SYM',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'NUM',
#   'ADP',
#   'NOUN'],
#  ['X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'SCONJ',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   'DET',
#   'VERB',
#   'ADP',
#   'NUM',
#   'NUM',
#   'NOUN',
#   'CCONJ',
#   'NUM',
#   'NUM',
#   'NOUN',
#   'PUNCT',
#   'SCONJ',
#   'ADP',
#   'NUM',
#   'SYM',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'NUM',
#   'SYM',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'CCONJ',
#   'ADJ',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'SCONJ',
#   'ADP',
#   'NUM',
#   'SYM',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'NUM',
#   'SYM',
#   'ADP',
#   'NOUN',
#   'DET',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'DET',
#   'VERB',
#   'NUM',
#   'NUM',
#   'NOUN',
#   'CCONJ',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'DET',
#   'VERB',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'ADV',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NUM',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'NUM',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'SCONJ',
#   'NUM',
#   'SYM',
#   'ADP',
#   'NOUN',
#   'DET',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NUM',
#   'SYM',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['NOUN', 'ADP', 'NOUN', 'ADJ', 'ADP', 'NOUN', 'ADJ', 'ADP', 'NOUN', 'X', 'X'],
#  ['X',
#   'X',
#   'PUNCT',
#   'X',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'X',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'X',
#   'X',
#   'ADP',
#   'X',
#   'PUNCT',
#   'X',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'SCONJ',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'PRON',
#   'VERB',
#   'ADP',
#   'NUM',
#   'PUNCT',
#   'PART',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'PART',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'ADP',
#   'PRON',
#   'X',
#   'PUNCT',
#   'PART',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'SCONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'VERB',
#   'ADP',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'X',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PART',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'NUM',
#   'SCONJ',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['NOUN', 'ADJ', 'VERB', 'ADP', 'NUM', 'X', 'ADP', 'X'],
#  ['X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'PUNCT',
#   'ADP',
#   'NUM',
#   'X',
#   'ADP',
#   'X',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'VERB',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NUM',
#   'NUM',
#   'X',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'X',
#   'CCONJ',
#   'ADJ',
#   'ADP',
#   'X',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'X',
#   'X',
#   'PUNCT',
#   'SCONJ',
#   'X',
#   'VERB',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'X',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'SCONJ',
#   'NOUN',
#   'NOUN',
#   'NUM',
#   'CCONJ',
#   'PRON',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'ADP',
#   'NOUN',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'ADP',
#   'NUM',
#   'X',
#   'ADP',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'ADJ',
#   'PUNCT'],
#  ['NOUN',
#   'ADP',
#   'X',
#   'CCONJ',
#   'X',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN'],
#  ['X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'SCONJ',
#   'NOUN',
#   'CCONJ',
#   'X',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'SCONJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'VERB',
#   'ADP',
#   'PRON',
#   'ADJ',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADP',
#   'SCONJ',
#   'VERB',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'X',
#   'ADP',
#   'X',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'SCONJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'X',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'X',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'ADP',
#   'X',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'PUNCT',
#   'SCONJ',
#   'PRON',
#   'PUNCT',
#   'ADJ',
#   'PUNCT',
#   'VERB',
#   'SCONJ',
#   'X',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'CCONJ',
#   'PRON',
#   'PART',
#   'X',
#   'ADP',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'AUX',
#   'ADP',
#   'ADJ',
#   'SCONJ',
#   'X',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'CCONJ',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'PUNCT',
#   'PART',
#   'PRON',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'SCONJ',
#   'X',
#   'PART',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'X',
#   'PART',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'X',
#   'X',
#   'SCONJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'CCONJ',
#   'PRON',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'X',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'X',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'PUNCT'],
#  ['X', 'ADP', 'X', 'ADP', 'NOUN', 'NOUN'],
#  ['X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'SCONJ',
#   'NOUN',
#   'ADJ',
#   'X',
#   'X',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'SCONJ',
#   'X',
#   'AUX',
#   'VERB',
#   'NOUN',
#   'PRON',
#   'ADJ',
#   'X',
#   'X',
#   'X',
#   'PUNCT'],
#  ['CCONJ',
#   'AUX',
#   'VERB',
#   'NOUN',
#   'X',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'DET',
#   'VERB',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'PRON',
#   'ADP',
#   'X',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'X',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'X',
#   'ADP',
#   'ADP',
#   'SCONJ',
#   'VERB',
#   'ADP',
#   'DET',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'AUX',
#   'VERB',
#   'X',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'X',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'NUM',
#   'SCONJ',
#   'VERB',
#   'X',
#   'DET',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'X',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'ADP',
#   'ADJ',
#   'SCONJ',
#   'VERB',
#   'X',
#   'ADV',
#   'NOUN',
#   'ADP',
#   'X',
#   'X',
#   'CCONJ',
#   'VERB',
#   'CCONJ',
#   'X',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   'X',
#   'PUNCT'],
#  ['VERB', 'X', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'X'],
#  ['X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'X',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'PUNCT',
#   'X',
#   'ADJ',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'X',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'X',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'VERB',
#   'ADP',
#   'NUM',
#   'ADP',
#   'NUM',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'CCONJ',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'X',
#   'NUM',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'AUX',
#   'VERB',
#   'NUM',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'X',
#   'ADP',
#   'X',
#   'ADJ',
#   'CCONJ',
#   'PART',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'AUX',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'X',
#   'CCONJ',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'NUM',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'X',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'DET',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NUM',
#   'AUX',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'AUX',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'X',
#   'X',
#   'PUNCT',
#   'X',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'ADJ',
#   'X',
#   'X',
#   'PUNCT',
#   'X',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['X', 'VERB', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'ADP', 'X'],
#  ['NOUN',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'X',
#   'X',
#   'NOUN',
#   'NOUN',
#   'SCONJ',
#   'VERB',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'SCONJ',
#   'X',
#   'VERB',
#   'SCONJ',
#   'VERB',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'SCONJ',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'SCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'X',
#   'DET',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'SCONJ',
#   'NOUN',
#   'ADJ',
#   'PART',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'DET',
#   'VERB',
#   'PRON',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'AUX',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['ADP',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'X',
#   'X',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'SCONJ',
#   'X',
#   'PUNCT',
#   'VERB',
#   'DET',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'X',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'X',
#   'ADJ',
#   'ADP',
#   'SCONJ',
#   'NOUN',
#   'ADP',
#   'X',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'PRON',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['NOUN', 'X', 'PUNCT', 'X', 'ADP', 'NOUN', 'ADJ'],
#  ['X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'X',
#   'X',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'X',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'X',
#   'X',
#   'ADP',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'X',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'ADJ',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'X',
#   'ADP',
#   'ADJ',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'X',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'ADJ',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'ADJ',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'X',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'ADJ',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT'],
#  ['NOUN',
#   'SYM',
#   'X',
#   'SYM',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'ADJ'],
#  ['X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'X',
#   'X',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'SYM',
#   'X',
#   'SYM',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'SCONJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'X',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'X',
#   'ADP',
#   'X',
#   'NOUN',
#   'PRON',
#   'SCONJ',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'X',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'PUNCT',
#   'X',
#   'AUX',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'PUNCT',
#   'PUNCT',
#   'CCONJ',
#   'PRON',
#   'VERB',
#   'PUNCT',
#   'SCONJ',
#   'NOUN',
#   'AUX',
#   'AUX',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'X',
#   'ADP',
#   'SCONJ',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'X',
#   'ADJ',
#   'CCONJ',
#   'ADJ',
#   'DET',
#   'VERB',
#   'NOUN',
#   'PRON',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'PUNCT',
#   'VERB',
#   'SCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'SYM',
#   'X',
#   'SYM',
#   'ADV',
#   'NOUN',
#   'ADP',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'X',
#   'PUNCT',
#   'NUM',
#   'X',
#   'PUNCT',
#   'X',
#   'PUNCT',
#   'X',
#   'ADJ',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'ADJ',
#   'CCONJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'X',
#   'SCONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'PRON',
#   'X',
#   'PUNCT',
#   'NUM',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'CCONJ',
#   'CCONJ',
#   'X',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'NOUN',
#   'PUNCT',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'CCONJ',
#   'ADJ',
#   'NOUN',
#   'AUX',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'X',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'CCONJ',
#   'AUX',
#   'VERB',
#   'NOUN',
#   'X',
#   'PUNCT',
#   'NUM',
#   'ADJ',
#   'DET',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'PUNCT',
#   'CCONJ',
#   'PART',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'PUNCT'],
#  ['NOUN',
#   'X',
#   'PUNCT',
#   'NOUN',
#   'X',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'ADP',
#   'NOUN',
#   'ADJ'],
#  ['X',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'X',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'X',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'NUM',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'ADJ',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'X',
#   'X',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'ADJ',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'ADJ',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'ADJ',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'ADV',
#   'X',
#   'X',
#   'ADP',
#   'X',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'X',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'X',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'X',
#   'ADP',
#   'ADJ',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT'],
#  ['NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'AUX',
#   'VERB',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'ADJ'],
#  ['X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'X',
#   'X',
#   'NOUN',
#   'NOUN',
#   'SCONJ',
#   'NOUN',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'NUM',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'X',
#   'DET',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'AUX',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'X',
#   'SCONJ',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'ADJ',
#   'SCONJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'SCONJ',
#   'PUNCT',
#   'PART',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PRON',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'VERB',
#   'PUNCT',
#   'PART',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'DET',
#   'VERB',
#   'CCONJ',
#   'PART',
#   'VERB',
#   'DET',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'ADP',
#   'SCONJ',
#   'PRON',
#   'PART',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'SCONJ',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'X',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'X',
#   'SCONJ',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'PART',
#   'VERB',
#   'SCONJ',
#   'VERB',
#   'NOUN',
#   'PRON',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'ADP',
#   'SCONJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'PART',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'DET',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'SCONJ',
#   'AUX',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['ADP',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'X',
#   'X',
#   'SCONJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PART',
#   'SCONJ',
#   'NOUN',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'PUNCT',
#   'PART',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'CCONJ',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'VERB',
#   'ADP',
#   'PRON',
#   'X',
#   'ADJ',
#   'PUNCT',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'CCONJ',
#   'PRON',
#   'AUX',
#   'ADJ',
#   'CCONJ',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'SCONJ',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'PART',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'ADV',
#   'SCONJ',
#   'PRON',
#   'AUX',
#   'ADP',
#   'ADJ',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'X',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'X',
#   'X',
#   'NOUN',
#   'PRON',
#   'PUNCT',
#   'PART',
#   'PRON',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'SCONJ',
#   'NOUN',
#   'NOUN',
#   'PART',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   'SCONJ',
#   'PUNCT',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'SCONJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'SCONJ',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADV',
#   'SCONJ',
#   'ADJ',
#   'ADP',
#   'PRON',
#   'PART',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'PART',
#   'VERB',
#   'X',
#   'CCONJ',
#   'PRON',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'X',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'X',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'NUM',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'X',
#   'CCONJ',
#   'PROPN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'X',
#   'PUNCT',
#   'ADP',
#   'SCONJ',
#   'PRON',
#   'PART',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADV',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'DET',
#   'NOUN',
#   'DET',
#   'VERB',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'ADP',
#   'NUM',
#   'PUNCT',
#   'PRON',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'X',
#   'X',
#   'NOUN',
#   'X',
#   'ADP',
#   'NUM',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'PUNCT'],
#  ['NOUN', 'X', 'PUNCT', 'NOUN'],
#  ['X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'X',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'ADJ',
#   'X',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'X',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'ADJ',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'ADJ',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'X',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'ADJ',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'ADJ',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'X',
#   'PUNCT'],
#  ['X', 'ADJ', 'VERB', 'ADP', 'NOUN', 'ADJ', 'ADP', 'X', 'ADJ'],
#  ['X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'X',
#   'ADJ',
#   'X',
#   'X',
#   'X',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'PRON',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'NUM',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'SCONJ',
#   'PRON',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'CCONJ',
#   'DET',
#   'VERB',
#   'NOUN',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'ADP',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'SCONJ',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'SCONJ',
#   'VERB',
#   'ADP',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'NUM',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'X',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'X',
#   'PUNCT',
#   'SCONJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'X',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'X',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'X',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'X',
#   'X',
#   'X',
#   'CCONJ',
#   'X',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'PART',
#   'SCONJ',
#   'X',
#   'X',
#   'PART',
#   'VERB',
#   'ADP',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['NOUN',
#   'ADJ',
#   'PUNCT',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN'],
#  ['NOUN',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'X',
#   'X',
#   'NOUN',
#   'SCONJ',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'PUNCT',
#   'PART',
#   'PRON',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'ADJ',
#   'CCONJ',
#   'X',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'VERB',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'DET',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'X',
#   'DET',
#   'VERB',
#   'PRON',
#   'ADJ',
#   'PUNCT',
#   'PART',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'ADV',
#   'PUNCT',
#   'ADP',
#   'DET',
#   'VERB',
#   'CCONJ',
#   'DET',
#   'PRON',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'X',
#   'X',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'X',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'X',
#   'PUNCT',
#   'X',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'CCONJ',
#   'PART',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'ADP',
#   'SCONJ',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'X',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'X',
#   'X',
#   'DET',
#   'VERB',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADP',
#   'SCONJ',
#   'VERB',
#   'NOUN',
#   'PRON',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'PART',
#   'VERB',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'ADP',
#   'ADJ',
#   'SCONJ',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'X',
#   'PROPN',
#   'X',
#   'ADP',
#   'NOUN',
# ...
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'NUM',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'PUNCT',
#   'AUX',
#   'NOUN',
#   'PRON',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'SCONJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADV',
#   'PUNCT',
#   'CCONJ',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'X',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'X',
#   'CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'AUX',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'PART',
#   'VERB',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'PUNCT',
#   'AUX',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'X',
#   'CCONJ',
#   'ADP',
#   'SCONJ',
#   'NOUN',
#   'ADJ',
#   'AUX',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'CCONJ',
#   'NOUN',
#   'PRON',
#   'ADJ',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'SCONJ',
#   'DET',
#   'NOUN',
#   'PART',
#   'VERB',
#   'SCONJ',
#   'X',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'AUX',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'VERB',
#   'NOUN',
#   'PRON',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'X',
#   'ADP',
#   'SCONJ',
#   'NOUN',
#   'DET',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'AUX',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'ADJ',
#   'ADP',
#   'X',
#   'PUNCT',
#   'CCONJ',
#   'ADP',
#   'SCONJ',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'DET',
#   'VERB',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'AUX',
#   'VERB',
#   'X',
#   'NOUN',
#   'X',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'X',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'X',
#   'PUNCT',
#   'ADP',
#   'ADP',
#   'VERB',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'X',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'X',
#   'NOUN',
#   'NOUN',
#   'NUM',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'X',
#   'X',
#   'PUNCT',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'CCONJ',
#   'SCONJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NUM',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'PRON',
#   'ADJ',
#   'ADJ',
#   'PUNCT',
#   'PUNCT'],
#  ['NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'PUNCT',
#   'NUM'],
#  ['NOUN',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NOUN',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'DET',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'CCONJ',
#   'ADP',
#   'PRON',
#   'NUM',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'ADJ',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'AUX',
#   'VERB',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'ADP',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN'],
#  ['NOUN',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'SCONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADJ',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'SCONJ',
#   'PUNCT',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'X',
#   'X',
#   'PUNCT',
#   'NUM',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'X',
#   'NOUN',
#   'X',
#   'CCONJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'DET',
#   'VERB',
#   'ADP',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'CCONJ',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'AUX',
#   'VERB',
#   'SCONJ',
#   'VERB',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'SCONJ',
#   'PRON',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'SCONJ',
#   'PUNCT',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'PRON',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADP',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'PART',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  ['VERB',
#   'NOUN',
#   'SCONJ',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['NOUN',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'PUNCT',
#   'NUM'],
#  ['NOUN',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'DET',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'X',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'NOUN',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADP',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'X',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'DET',
#   'VERB',
#   'ADP',
#   'PRON',
#   'ADP',
#   'PART',
#   'SCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PRON',
#   'PUNCT'],
#  ['CCONJ',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'X',
#   'X',
#   'X',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'PRON',
#   'X',
#   'X',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'PRON',
#   'X',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'PRON',
#   'NUM',
#   'NOUN',
#   'ADP',
#   'SCONJ',
#   'VERB',
#   'X',
#   'NOUN',
#   'PUNCT'],
#  ['VERB',
#   'SCONJ',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'ADV',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'X',
#   'PUNCT'],
#  ['NOUN',
#   'NUM',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN'],
#  ['NOUN',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'SCONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'X',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NUM',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'SCONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'PART',
#   'VERB',
#   'NOUN',
#   'PRON',
#   'PUNCT',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'SCONJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'SCONJ',
#   'DET',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'ADV',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'X',
#   'ADP',
#   'X',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'SCONJ',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'DET',
#   'ADP',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'SCONJ',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'SCONJ',
#   'VERB',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  ['NOUN',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ'],
#  ['NOUN',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'X',
#   'PUNCT',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'CCONJ',
#   'X',
#   'ADP',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'ADP',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CCONJ',
#   'PART',
#   'CCONJ',
#   'SCONJ',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'ADP',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'PUNCT',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'SCONJ',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'SCONJ',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'VERB',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'ADP',
#   'PUNCT',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'PUNCT',
#   'PUNCT'],
#  ['VERB',
#   'ADP',
#   'SCONJ',
#   'NOUN',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'X',
#   'VERB',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'DET',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADJ',
#   'ADP',
#   'NUM',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['NOUN',
#   'X',
#   'NUM',
#   'PUNCT',
#   'X',
#   'PUNCT',
#   'NOUN',
#   'X',
#   'ADP',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM'],
#  ['X',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'X',
#   'X',
#   'ADJ',
#   'ADJ',
#   'X',
#   'X',
#   'NOUN',
#   'NOUN',
#   'PRON',
#   'X',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'ADP',
#   'X',
#   'X',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'PROPN',
#   'PUNCT',
#   'X',
#   'ADJ',
#   'CCONJ',
#   'ADJ',
#   'CCONJ',
#   'NOUN',
#   'X',
#   'PUNCT',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'X',
#   'NOUN',
#   'X',
#   'PUNCT',
#   'NUM',
#   'CCONJ',
#   'NUM',
#   'PUNCT',
#   'PUNCT',
#   'X',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NOUN',
#   'X',
#   'PUNCT'],
#  ['NOUN', 'X', 'PUNCT', 'NOUN', 'NOUN', 'VERB', 'NOUN', 'ADP', 'NOUN', 'ADJ'],
#  ['X',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'NOUN',
#   'NOUN',
#   'SCONJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'X',
#   'NOUN',
#   'CCONJ',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'X',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'X',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'SCONJ',
#   'X',
#   'PART',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'PUNCT',
#   'ADJ',
#   'ADP',
#   'SCONJ',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADV',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'X',
#   'PUNCT',
#   'X',
#   'PUNCT',
#   'PUNCT'],
#  ['ADJ', 'VERB', 'NOUN', 'NUM', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN'],
#  ['X',
#   'PUNCT',
#   'X',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'NUM',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'VERB',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'ADJ',
#   'ADP',
#   'NOUN',
#   'X',
#   'X',
#   'CCONJ',
#   'VERB',
#   'NOUN',
#   'X',
#   'X',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'SCONJ',
#   'PRON',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'NUM',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADJ',
#   'PUNCT'],
#  ['CCONJ',
#   'VERB',
#   'NOUN',
#   'SCONJ',
#   'PUNCT',
#   'NUM',
#   'NUM',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'X',
#   'PUNCT',
#   'DET',
#   'VERB',
#   'PRON',
#   'X',
#   'PUNCT',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PUNCT',
#   'ADP',
#   'PRON',
#   'NUM',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'VERB',
#   'PRON',
#   'NOUN',
#   'X',
#   'ADP',
#   'NOUN',
#   'NOUN',
#   'ADP',
#   'X',
#   'PUNCT'],
#  ...]

# %%
sentences_train, sentences_test, pos_tags_train, pos_tags_test = train_test_split(sentences, pos_tags, test_size=0.1, random_state=42)

# %% [markdown]
# ### Cleaning and Preprocessing

# %%
token_counter = Counter()
for tokens in sentences_train:
    token_counter.update(tokens)
token_to_index = {token: idx + 2 for idx, token in enumerate(token_counter)}
token_to_index['<PAD>'] = 0
token_to_index['<UNK>'] = 1

# %%
token_counter
# Out:
# Counter({'تم': 170,
#          'تشكيل': 47,
#          'فريق': 25,
#          'عمل': 73,
#          'مصري': 38,
#          'ل': 5047,
#          'دراسة': 30,
#          'المشروع': 78,
#          'ب': 4438,
#          'رئاسة': 37,
#          'د': 50,
#          '.': 5480,
#          'إسماعيل': 9,
#          'عبد': 92,
#          'الجليل': 1,
#          'رئيس': 356,
#          'مركز': 61,
#          'بحوث': 5,
#          'الصحراء': 10,
#          'و': 11757,
#          'عضوية': 8,
#          'المهندس': 31,
#          'محمد': 124,
#          'الشحات': 2,
#          'هيئة': 55,
#          'تنمية': 31,
#          'بحيرة': 7,
#          'السد': 6,
#          'العالي': 8,
#          'عدد': 220,
#          'كبير': 65,
#          'من': 3885,
#          'خبراء': 30,
#          'وزارة': 114,
#          'الري': 6,
#          'الموارد': 27,
#          'المائية': 11,
#          'مراكز': 25,
#          'البحوث': 14,
#          'الجامعات': 12,
#          'يمثل': 37,
#          'الجانب': 52,
#          'الياباني': 11,
#          'في': 5304,
#          'خالد': 19,
#          'زيد': 12,
#          'هو': 333,
#          'الجنسية': 14,
#          'يعد': 31,
#          'أحد': 70,
#          'الخبراء': 35,
#          'الدوليين': 4,
#          'العاملين': 33,
#          'مجال': 97,
#          'تكنولوجيا': 11,
#          'الاتصالات': 36,
#          'اليابان': 21,
#          'منذ': 198,
#          'ثلاثين': 2,
#          'عاما': 49,
#          'كلفت': 2,
#          'ه': 2886,
#          'إحدى': 35,
#          'الشركات': 167,
#          'اليابانية': 8,
#          'العملاقة': 2,
#          'التفاوض': 19,
#          'مع': 828,
#          'مصر': 564,
#          'تنفيذ': 115,
#          'الذي': 547,
#          'س': 744,
#          'يتم': 167,
#          'تمويل': 52,
#          'البنك': 103,
#          'اندونيسيا': 16,
#          'يلتقي': 20,
#          'بيريز': 4,
#          'قبل': 200,
#          'وصول': 34,
#          'عرفات': 56,
#          'أضاف': 199,
#          ':': 424,
#          '"': 2779,
#          'إن': 539,
#          'تاريخ': 21,
#          'المسلمين': 51,
#          'الأقباط': 14,
#          'امتد': 2,
#          'معاً': 8,
#          'العصر': 5,
#          'الحديث': 21,
#          'حيث': 205,
#          'خاضوا': 1,
#          'الكثير': 35,
#          'الثورات': 1,
#          'مثل': 104,
#          'ثورة': 7,
#          '1919': 2,
#          'المجيدة': 2,
#          'يوليو': 31,
#          '1952': 3,
#          '،': 3475,
#          'كنا': 6,
#          'كل': 291,
#          'الحروب': 5,
#          'خصوصا': 25,
#          'حرب': 40,
#          '1973': 7,
#          'التي': 988,
#          'قضى': 5,
#          'ها': 2711,
#          'الجيش': 70,
#          'المصري': 259,
#          'على': 2384,
#          'أسطورة': 2,
#          'الإسرائيلي': 59,
#          '1987': 5,
#          '-': 681,
#          'وفاة': 18,
#          'الرئيس': 275,
#          'اللبناني': 57,
#          'كميل': 1,
#          'شمعون': 2,
#          'انتهى': 5,
#          'تقرير': 61,
#          'مفوضي': 2,
#          'الدولة': 135,
#          'قضية': 46,
#          'مولد': 3,
#          'أبو': 52,
#          'حصيرة': 4,
#          'البحيرة': 3,
#          'تباينت': 1,
#          'ردود': 9,
#          'الفعل': 27,
#          'حول': 179,
#          'اتجاه': 35,
#          'البنوك': 93,
#          'المصرية': 342,
#          'خفض': 47,
#          'سعر': 148,
#          'الفائدة': 50,
#          'الإيداعات': 13,
#          'اعتبر': 47,
#          'الموافقون': 1,
#          'أن': 2078,
#          'الوسيلة': 1,
#          'الوحيدة': 18,
#          'إنعاش': 3,
#          'حركة': 66,
#          'الاستثمار': 112,
#          'شهدت': 30,
#          'تراجعا': 1,
#          'كبيراً': 21,
#          'خلال': 482,
#          'العام': 275,
#          'الماضي': 194,
#          'إنقاذ': 18,
#          'تزايد': 24,
#          'نسب': 13,
#          'السيولة': 9,
#          'الودائع': 13,
#          'المحلية': 54,
#          'الأجنبية': 39,
#          'بينما': 39,
#          'يرى': 36,
#          'المعترضون': 1,
#          'تخفيض': 13,
#          'زيادة': 165,
#          'الدولرة': 7,
#          'ارتفاع': 88,
#          'نسبة': 139,
#          'التضخم': 10,
#          'أدت': 7,
#          'إلى': 1109,
#          'تعميق': 3,
#          'الركود': 6,
#          'الأسواق': 42,
#          'يضيف': 8,
#          'ثابت': 11,
#          'بين': 709,
#          'المعوقات': 7,
#          'تعوق': 2,
#          'التجارة': 163,
#          'البلدين': 116,
#          'مشكلة': 35,
#          'الاعتمادات': 7,
#          'المستندية': 3,
#          'مؤكدا': 19,
#          'أنسب': 1,
#          'طرق': 10,
#          'التعامل': 34,
#          'السوق': 182,
#          'السوداني': 12,
#          'تبادل': 29,
#          'سلع': 10,
#          'أخرى': 101,
#          'ما': 796,
#          'يطلق': 8,
#          'علي': 253,
#          'نظام': 83,
#          'الأوفست': 2,
#          'الإضافة': 45,
#          'معوقات': 8,
#          'النقل': 31,
#          'الموصلات': 1,
#          'الجمارك': 29,
#          'قد': 409,
#          'نجح': 3,
#          'المتهمون': 1,
#          'الثلاثة': 23,
#          'اكثر': 72,
#          'اربع': 8,
#          'عمليات': 73,
#          'بلغت': 61,
#          'قيمة': 123,
#          'البضائع': 25,
#          'حوالي': 44,
#          '20': 77,
#          'الف': 37,
#          'دينار': 2,
#          'نفس': 152,
#          'الوقت': 81,
#          'صرح': 35,
#          'المستشار': 15,
#          'صيام': 6,
#          'قدمت': 14,
#          'عرضاً': 2,
#          'استضافة': 4,
#          'مقر': 26,
#          'إقليمي': 6,
#          'مكافحة': 60,
#          'غسل': 6,
#          'الأموال': 39,
#          'يخدم': 14,
#          'منطقة': 139,
#          'الشرق': 141,
#          'الأوسط': 76,
#          'شمال': 93,
#          'أفريقيا': 79,
#          'قال': 552,
#          'المنظمة': 38,
#          'تبحث': 9,
#          'حالياً': 57,
#          'العرض': 19,
#          'بلغ': 46,
#          'حجم': 95,
#          'التهرب': 4,
#          'الضريبي': 6,
#          'مليار': 127,
#          'جنيه': 208,
#          '(': 542,
#          '3.2': 6,
#          'دولار': 343,
#          ')': 542,
#          '2003': 46,
#          'إحالة': 6,
#          'يقرب': 9,
#          '15': 177,
#          'ألف': 102,
#          'شخص': 26,
#          'نيابة': 3,
#          'تمهيدا': 3,
#          'هم': 802,
#          'محكمة': 9,
#          'عاجلة': 9,
#          'عكست': 1,
#          'المواقف': 12,
#          'الايرانية': 12,
#          'السورية': 36,
#          'محادثات': 40,
#          'خدام': 6,
#          'طهران': 33,
#          'توقع': 33,
#          'تصعيد': 9,
#          'اسرائيلي': 5,
#          'واسع': 7,
#          'المنطقة': 180,
#          'رأى': 23,
#          'خاتمي': 22,
#          'ان': 1455,
#          '»': 464,
#          'أي': 154,
#          'عشوائي': 1,
#          'غير': 245,
#          'منطقي': 2,
#          'الكيان': 4,
#          'الصهيوني': 7,
#          'لن': 107,
#          'يخرج': 3,
#          'أزمة': 29,
#          '«': 463,
#          'زاد': 24,
#          'بلاد': 71,
#          'تبقى': 9,
#          'الى': 1194,
#          'جانب': 98,
#          'سورية': 61,
#          'الشعب': 84,
#          'الفلسطيني': 69,
#          'اتساع': 2,
#          'الجرائم': 5,
#          'الاسرائيلية': 55,
#          'يزيد': 28,
#          'الانتفاضة': 14,
#          'اشتعالاً': 2,
#          'نوه': 4,
#          'مواقف': 21,
#          'دمشق': 60,
#          'تطورات': 15,
#          'كما': 276,
#          'حجز': 4,
#          'اللاعب': 3,
#          'أحمد': 45,
#          'عدلي': 1,
#          'مدرب': 17,
#          'حسن': 40,
#          'مستشفيات': 6,
#          'اليونان': 10,
#          'أثناء': 12,
#          'رحلة': 13,
#          'العودة': 34,
#          'تأتي': 26,
#          'ك': 267,
#          'فرص': 32,
#          'كثيرة': 13,
#          'يمكن': 143,
#          'إحراز': 4,
#          'مبلغ': 13,
#          'جيد': 7,
#          'المال': 34,
#          'تساءلت': 1,
#          'المصادر': 46,
#          'اذا': 59,
#          'كان': 327,
#          'هذا': 468,
#          'وضع': 87,
#          'العلاقات': 104,
#          'الاميركية': 68,
#          'ف': 469,
#          'ماذا': 8,
#          'افتعال': 2,
#          'الخوف': 2,
#          'رهان': 3,
#          'بعض': 220,
#          'المسيحيين': 15,
#          'واشنطن': 90,
#          'دام': 10,
#          'رهانا': 1,
#          'فاشلا': 1,
#          'سواء': 35,
#          'خلاف': 21,
#          'سوري': 3,
#          'اميركي': 8,
#          'او': 115,
#          'نجاح': 25,
#          'الهجمة': 1,
#          'العراق': 330,
#          'تصبح': 15,
#          'سوريا': 76,
#          'هي': 207,
#          'الهدف': 19,
#          'اللاحق': 1,
#          'احد': 51,
#          'لا': 561,
#          'التكهن': 6,
#          'تكون': 107,
#          'بعد': 441,
#          'الحملة': 21,
#          'حتى': 200,
#          'الاميركيون': 4,
#          'أنفس': 20,
#          'يراهن': 2,
#          'المجهول': 1,
#          'يحسب': 1,
#          'حسابا': 2,
#          'خطإ': 1,
#          'يحل': 4,
#          '؟': 68,
#          'موسكو': 45,
#          '8': 148,
#          'اف': 106,
#          'نقلت': 39,
#          'وكالة': 100,
#          'انترفاكس': 9,
#          'الأنباء': 21,
#          'عن': 908,
#          'الاميرال': 15,
#          'فلاديمير': 14,
#          'كوروييدوف': 5,
#          'قائد': 21,
#          'البحرية': 28,
#          'الروسية': 58,
#          'قول': 42,
#          'تامل': 1,
#          'البدء': 15,
#          'عملية': 118,
#          'انقاذ': 17,
#          'افراد': 17,
#          'طاقم': 24,
#          'الغواصة': 85,
#          'كورسك': 24,
#          'مساء': 57,
#          'اليوم': 370,
#          'الثلاثاء': 104,
#          'طريق': 58,
#          'انزال': 3,
#          'كبسولة': 6,
#          'شكل': 83,
#          'جرس': 2,
#          'تحط': 1,
#          'ظهر': 32,
#          'المنكوبة': 2,
#          'أشار': 137,
#          'وزير': 314,
#          'الخارجية': 225,
#          'الالمانى': 3,
#          'يوشكا': 1,
#          'فيشر': 1,
#          'المؤتمر': 60,
#          'الاول': 68,
#          'قوة': 50,
#          'تثبيت': 8,
#          'الاستقرار': 38,
#          'فى': 960,
#          'لندن': 34,
#          'ذٰلك': 112,
#          'هامش': 14,
#          'المجلس': 74,
#          'الرسمى': 2,
#          'كستللوريزو': 2,
#          'نا': 273,
#          'دراية': 1,
#          'أبلغنا': 2,
#          'تقدم': 56,
#          'نتائج': 39,
#          'مضيفا': 14,
#          'لم': 331,
#          'يكن': 23,
#          'سرا': 1,
#          'يقول': 46,
#          'التقرير': 69,
#          'الارقام': 5,
#          'أوردت': 2,
#          'شركة': 186,
#          'بريتش': 3,
#          'بيتروليوم': 3,
#          'بي': 19,
#          'تثبت': 6,
#          'الامر': 30,
#          'جلي': 1,
#          'احتياطات': 9,
#          'النفط': 140,
#          'المؤكدة': 2,
#          'عام': 238,
#          '1978': 2,
#          '648.3': 1,
#          'برميل': 31,
#          'الخام': 29,
#          'كانت': 207,
#          'حصة': 14,
#          'افريقيا': 18,
#          '405.7': 1,
#          'يعادل': 7,
#          '63': 4,
#          '%': 271,
#          'ارتفعت': 22,
#          'هذه': 508,
#          'الاحتياطات': 6,
#          '1988': 2,
#          'تصل': 65,
#          '917.8': 1,
#          'الا': 59,
#          'الاخرى': 23,
#          '66': 4,
#          '608.1': 1,
#          'أجرى': 8,
#          'المسئولون': 5,
#          'اتفاقاً': 5,
#          'مبدئياً': 1,
#          'جمعية': 31,
#          'الأعمال': 99,
#          'الفرنسية': 49,
#          'التعاون': 153,
#          'تصدير': 34,
#          'المنتجات': 81,
#          'دول': 151,
#          'غرب': 43,
#          'سخانات': 1,
#          'المياه': 36,
#          'عدادات': 3,
#          'سيارات': 14,
#          'الأجرة': 2,
#          'الثلاجات': 3,
#          'المبردات': 1,
#          'المضخات': 2,
#          'الهوائية': 1,
#          'أسلاك': 1,
#          'النحاس': 2,
#          'تعليق': 16,
#          'الدبلوماسية': 23,
#          'الرحلات': 8,
#          'الجوية': 39,
#          'الهند': 28,
#          'باكستان': 39,
#          'اعقاب': 16,
#          'هجوم': 13,
#          'ارهابى': 1,
#          'مبنى': 5,
#          'البرلمان': 60,
#          'الهندى': 16,
#          'ديسمبر': 31,
#          '2001': 21,
#          'حملت': 3,
#          'المتطرفين': 3,
#          'الدينيين': 1,
#          'مسؤولية': 16,
#          'الهجوم': 13,
#          'قائلة': 4,
#          'يحظون': 1,
#          'رعاية': 13,
#          'اسلام': 9,
#          'اباد': 7,
#          'بيد': 14,
#          'نفت': 4,
#          'صلة': 6,
#          'الحادث': 25,
#          'الهضيبي': 8,
#          'الحالة': 9,
#          'وصلت': 29,
#          'إلي': 79,
#          'الأحوال': 8,
#          'عربية': 27,
#          'إسلامية': 6,
#          'تستدعي': 2,
#          'تضافر': 2,
#          'الجهود': 36,
#          'وحدة': 27,
#          'الصف': 3,
#          'إتقان': 1,
#          'الحوار': 65,
#          'الحضاري': 4,
#          'تحمل': 28,
#          'الشدائد': 1,
#          'تمضي': 2,
#          'المسيرة': 1,
#          'الطريق': 61,
#          'ذلك': 251,
#          'يتطلب': 13,
#          'إخلاص': 1,
#          'النية': 7,
#          'الوجهة': 1,
#          'شحذ': 1,
#          'العزم': 1,
#          'العزائم': 2,
#          'الصبر': 2,
#          'وعثاء': 1,
#          'مفروش': 1,
#          'الورود': 1,
#          'يوم': 208,
#          'نسعى': 3,
#          'تحقيق': 99,
#          'المستوى': 31,
#          'الإيمان': 3,
#          'الفهم': 3,
#          'العمل': 131,
#          'مستوى': 67,
#          'أفراد': 12,
#          'عائلات': 6,
#          'لبنات': 2,
#          'المجتمع': 50,
#          'شعب': 19,
#          'رسالة': 30,
#          'غاية': 4,
#          'تظهر': 14,
#          'الأمة': 13,
#          'يرتفع': 10,
#          'صوت': 9,
#          'تعلن': 11,
#          'كلمة': 29,
#          'كمية': 8,
#          'التعاقد': 3,
#          'تبلغ': 38,
#          '35': 20,
#          'متر': 22,
#          'مربع': 15,
#          'ساعد': 4,
#          'قريباً': 17,
#          'أو': 216,
#          'صديقاً': 2,
#          'مقرباً': 2,
#          'إعداد': 21,
#          'ميزانية': 7,
#          'أكد': 171,
#          'الوزير': 50,
#          'افتتاح': 21,
#          'عدم': 138,
#          'توافر': 4,
#          'حصر': 6,
#          'دقيق': 3,
#          'المخازن': 5,
#          'العمومية': 4,
#          'الفرعية': 3,
#          'التابعة': 26,
#          'وحدات': 13,
#          'الجهاز': 22,
#          'الإداري': 7,
#          'شدد': 32,
#          'الأسعار': 49,
#          'شماعة': 1,
#          'الدولار': 107,
#          'مقبولاً': 1,
#          'لاسيما': 8,
#          'ظل': 46,
#          'التراجع': 10,
#          'المستمر': 10,
#          'الرسمية': 39,
#          'انخفاض': 60,
#          'نحو': 180,
#          '650': 6,
#          'قرشا': 21,
#          'أقل': 23,
#          'شهر': 61,
#          'عمان': 26,
#          '3': 173,
#          'مايو': 172,
#          'بداية': 38,
#          'اعمال': 21,
#          'الشغب': 5,
#          'اندلعت': 2,
#          'اثر': 26,
#          'اشتباك': 6,
#          'الاردني': 6,
#          'اسماعيل': 8,
#          'بني': 5,
#          'هاني': 3,
#          'لاعب': 17,
#          'اماراتي': 1,
#          'قرب': 27,
#          'غرف': 3,
#          'تبديل': 1,
#          'الملابس': 35,
#          'غادر': 11,
#          'ارض': 13,
#          'الملعب': 3,
#          'جلس': 2,
#          'المدرجات': 1,
#          'الشوط': 2,
#          'احتجاجا': 2,
#          'استبدال': 4,
#          'فيلم': 7,
#          'تسجيلي': 1,
#          'تركي': 3,
#          'اول': 38,
#          'طيران': 5,
#          'عثمانية': 2,
#          'فوق': 15,
#          'الشام': 3,
#          'ومصر': 2,
#          'مارسيل': 1,
#          'نصر': 7,
#          'شيع': 1,
#          'مئات': 8,
#          'الأردنيين': 3,
#          'جثمان': 3,
#          'رجل': 20,
#          'الأمن': 70,
#          'الذى': 74,
#          'قتل': 17,
#          'الانفجار': 15,
#          'وقع': 30,
#          'مطار': 23,
#          'امس': 92,
#          'الخميس': 42,
#          'الناجم': 1,
#          'عبوة': 3,
#          'مخلفات': 5,
#          'الحرب': 99,
#          'اثناء': 11,
#          'قيام': 44,
#          'تفتيش': 3,
#          'حقيبة': 3,
#          'مسافر': 2,
#          'يابانى': 2,
#          'قطعة': 13,
#          'الذخيرة': 6,
#          'مضى': 6,
#          'يزال': 16,
#          'هناك': 158,
#          'تحسين': 33,
#          'اداء': 4,
#          'تصرفات': 3,
#          'الاطراف': 18,
#          'يجب': 50,
#          'بذل': 13,
#          'جهود': 25,
#          'منسقة': 2,
#          'التقدم': 10,
#          'الامام': 3,
#          'روبرت': 8,
#          'مردوخ': 5,
#          'يوسع': 1,
#          'حدود': 32,
#          'إمبراطورية': 3,
#          'الاعلامية': 5,
#          'الولايات': 223,
#          'المتحدة': 340,
#          'نافتيج': 1,
#          'سارنا': 4,
#          'المتحدث': 19,
#          'اسم': 99,
#          'الشئون': 5,
#          'وسائل': 28,
#          'الإعلام': 22,
#          'هنا': 44,
#          'ساعات': 16,
#          'تلقى': 16,
#          'دعوة': 23,
#          'رسمية': 26,
#          'نظير': 31,
#          'الباكستانى': 4,
#          'مير': 2,
#          'ظفرالله': 1,
#          'خان': 3,
#          'جمالى': 11,
#          'القيام': 28,
#          'زيارة': 102,
#          'عاود': 3,
#          'فاجبايى': 20,
#          'الكتابة': 4,
#          'قائلا': 16,
#          'الاستعدادات': 6,
#          'المتأنية': 2,
#          'مطلوبة': 2,
#          'مشاركة': 42,
#          'هادفة': 2,
#          'أعلى': 22,
#          'طلبت': 15,
#          'السياحية': 15,
#          'السياحة': 29,
#          'الموافقة': 13,
#          'أسعار': 117,
#          'الحج': 6,
#          'السياحي': 9,
#          '40': 25,
#          'أرجعت': 1,
#          'صرف': 23,
#          'المرة': 28,
#          'الثالثة': 26,
#          'سنوات': 72,
#          'تتهم': 8,
#          'بغداد': 113,
#          'استمرار': 68,
#          'بريطانيا': 43,
#          'تجميد': 6,
#          'عقود': 28,
#          'الغذائية': 21,
#          'الأدوية': 9,
#          'كذٰلك': 62,
#          'قطع': 28,
#          'الغيار': 3,
#          'الضرورية': 7,
#          'الصناعة': 66,
#          'النفطية': 14,
#          'المتضررة': 2,
#          'الخليج': 31,
#          '1991': 9,
#          'المعتقد': 1,
#          'امروزى': 2,
#          'المنسق': 4,
#          'الميدانى': 2,
#          'الهجمات': 15,
#          'تقرر': 24,
#          'محاكمة': 8,
#          '12': 70,
#          'مساهمة': 8,
#          'إيطاليا': 12,
#          'رؤوس': 10,
#          'المصدرة': 19,
#          '31': 16,
#          '2002': 68,
#          'المشروعات': 55,
#          'الاستثمارية': 18,
#          '122.9': 1,
#          'مليون': 387,
#          'إجمالي': 45,
#          'التكلفة': 8,
#          '386': 1,
#          'الاسد': 16,
#          'القرار': 71,
#          '1559': 6,
#          'يهدف': 16,
#          'تدويل': 1,
#          'الملف': 18,
#          'إحداث': 8,
#          'قطيعة': 3,
#          'لبنان': 165,
#          'المتربطان': 1,
#          'مشترك': 26,
#          'أعمال': 73,
#          'بنك': 58,
#          'الإسكندرية': 14,
#          'تراجع': 41,
#          'صافي': 14,
#          'أرباح': 13,
#          '13.3': 1,
#          'سجل': 18,
#          '65': 7,
#          'مقارنة': 24,
#          '75': 12,
#          'يأتي': 39,
#          'الأرباح': 10,
#          'العائد': 13,
#          'المصرفي': 15,
#          '23': 29,
#          'يحقق': 18,
#          '142': 1,
#          'عوض': 9,
#          'الارتفاع': 12,
#          'عمولات': 4,
#          'أتعاب': 4,
#          'الخدمات': 33,
#          'المصرفية': 17,
#          '314': 3,
#          'نمو': 13,
#          '14': 32,
#          'حين': 73,
#          'تتعد': 3,
#          'إيرادات': 8,
#          'العمليات': 23,
#          'الأخرى': 41,
#          'المخصصات': 4,
#          'المكونة': 1,
#          '237': 1,
#          '248': 2,
#          'ارتفع': 16,
#          'أصول': 15,
#          '26': 19,
#          '33': 16,
#          'نتيجة': 49,
#          'تعكس': 8,
#          'أوضاع': 10,
#          'اكستريور': 11,
#          'الحالية': 35,
#          'كشفت': 26,
#          'التسعة': 2,
#          'أشهر': 17,
#          'الأولى': 38,
#          'المالي': 27,
#          'خسائر': 32,
#          '151': 2,
#          '45': 8,
#          'تتضمن': 19,
#          'فترة': 61,
#          'عائد': 7,
#          'القروض': 22,
#          'الأرصدة': 1,
#          'لدى': 83,
#          'يبلغ': 30,
#          '991.6': 1,
#          'أذون': 7,
#          'الخزانة': 8,
#          'السندات': 4,
#          'قدر': 25,
#          '65.52': 1,
#          'يصل': 45,
#          'الفوائد': 5,
#          '157.114': 1,
#          'تكلفة': 26,
#          'الاقتراض': 5,
#          '307': 3,
#          'ملايين': 63,
#          'مما': 74,
#          'أدى': 27,
#          'عجز': 13,
#          'العوائد': 1,
#          'الفترة': 98,
#          'رصد': 15,
#          'البيان': 67,
#          'ارتفاعاً': 7,
#          'الناتج': 10,
#          'المحلي': 41,
#          'الإجمالي': 9,
#          '/': 576,
#          '35.9': 1,
#          'سبق': 28,
#          'متوقعا': 5,
#          'القادم': 32,
#          '450': 3,
#          'مماثلة': 8,
#          'علم': 14,
#          'مصادر': 91,
#          'بيروت': 47,
#          'طائرة': 41,
#          'خاصة': 128,
#          'نوع': 27,
#          'بوينغ': 3,
#          '720': 1,
#          'استاجرتها': 1,
#          'السفارة': 16,
#          'الليبية': 14,
#          'اقلت': 1,
#          'الوفد': 46,
#          'عددا': 13,
#          'الصحافيين': 20,
#          'اضافة': 33,
#          'والدة': 11,
#          'الرهينة': 16,
#          'حذرت': 11,
#          'تركيا': 56,
#          'إسرائيل': 145,
#          'مواصلة': 21,
#          'التنقيب': 8,
#          'يشأ': 1,
#          'الوزراء': 126,
#          'الاسرائيلي': 42,
#          'الاستماع': 6,
#          'آراء': 7,
#          'الدوما': 4,
#          'غينادي': 2,
#          'سيليزينوف': 1,
#          'المنتمي': 1,
#          'جبهة': 8,
#          'القوى': 29,
#          'اليسارية': 1,
#          'المطالبة': 8,
#          'قرارات': 19,
#          'مجلس': 229,
#          'الرافضة': 1,
#          'تلبؤ': 1,
#          'اسرائيل': 103,
#          'موقعاً': 1,
#          'الشرعية': 24,
#          'الدولية': 110,
#          'هدف': 50,
#          'التغطية': 6,
#          'الفضائح': 1,
#          'عقد': 123,
#          'شارون': 63,
#          'عشية': 5,
#          'مغادرة': 13,
#          'لقاءات': 4,
#          'صحافية': 4,
#          'اكد': 33,
#          'الزيارة': 26,
#          'اتفق': 8,
#          'القيادة': 19,
#          'قضايا': 27,
#          'لجنة': 65,
#          'الارهاب': 36,
#          'شدة': 16,
#          'اللجنة': 82,
#          'رغم': 88,
#          'تنفي': 4,
#          'احتمال': 22,
#          'معلومات': 33,
#          'ذات': 72,
#          'طابع': 5,
#          'أمني': 3,
#          'ضمن': 38,
#          'الأطر': 1,
#          'المتعارف': 1,
#          'عدة': 89,
#          'البلدان': 17,
#          'العربية': 181,
#          'أجّلت': 1,
#          'الحكومة': 304,
#          'اجل': 39,
#          'مسمى': 3,
#          'طرح': 48,
#          'أسهم': 10,
#          'الحكومية': 42,
#          'البورصات': 5,
#          'استعادة': 18,
#          'الاقتصاد': 70,
#          'الدولي': 79,
#          'عافية': 1,
#          'أحداث': 7,
#          'أيلول': 10,
#          'سبتمبر': 61,
#          'عمر': 28,
#          'جستنية': 2,
#          'النور': 2,
#          'جاء': 82,
#          'بيان': 67,
#          'صدر': 22,
#          'الاجتماع': 45,
#          'الجانبين': 34,
#          'أكدا': 3,
#          'حرص': 5,
#          'هما': 167,
#          'الوطني': 91,
#          'الوصول': 23,
#          'النتائج': 11,
#          'تحقق': 15,
#          'مصلحة': 39,
#          'الوطن': 13,
#          'الاتفاق': 85,
#          'اجتماع': 54,
#          ...})

# %%
token_to_index
# Out:
# {'تم': 2,
#  'تشكيل': 3,
#  'فريق': 4,
#  'عمل': 5,
#  'مصري': 6,
#  'ل': 7,
#  'دراسة': 8,
#  'المشروع': 9,
#  'ب': 10,
#  'رئاسة': 11,
#  'د': 12,
#  '.': 13,
#  'إسماعيل': 14,
#  'عبد': 15,
#  'الجليل': 16,
#  'رئيس': 17,
#  'مركز': 18,
#  'بحوث': 19,
#  'الصحراء': 20,
#  'و': 21,
#  'عضوية': 22,
#  'المهندس': 23,
#  'محمد': 24,
#  'الشحات': 25,
#  'هيئة': 26,
#  'تنمية': 27,
#  'بحيرة': 28,
#  'السد': 29,
#  'العالي': 30,
#  'عدد': 31,
#  'كبير': 32,
#  'من': 33,
#  'خبراء': 34,
#  'وزارة': 35,
#  'الري': 36,
#  'الموارد': 37,
#  'المائية': 38,
#  'مراكز': 39,
#  'البحوث': 40,
#  'الجامعات': 41,
#  'يمثل': 42,
#  'الجانب': 43,
#  'الياباني': 44,
#  'في': 45,
#  'خالد': 46,
#  'زيد': 47,
#  'هو': 48,
#  'الجنسية': 49,
#  'يعد': 50,
#  'أحد': 51,
#  'الخبراء': 52,
#  'الدوليين': 53,
#  'العاملين': 54,
#  'مجال': 55,
#  'تكنولوجيا': 56,
#  'الاتصالات': 57,
#  'اليابان': 58,
#  'منذ': 59,
#  'ثلاثين': 60,
#  'عاما': 61,
#  'كلفت': 62,
#  'ه': 63,
#  'إحدى': 64,
#  'الشركات': 65,
#  'اليابانية': 66,
#  'العملاقة': 67,
#  'التفاوض': 68,
#  'مع': 69,
#  'مصر': 70,
#  'تنفيذ': 71,
#  'الذي': 72,
#  'س': 73,
#  'يتم': 74,
#  'تمويل': 75,
#  'البنك': 76,
#  'اندونيسيا': 77,
#  'يلتقي': 78,
#  'بيريز': 79,
#  'قبل': 80,
#  'وصول': 81,
#  'عرفات': 82,
#  'أضاف': 83,
#  ':': 84,
#  '"': 85,
#  'إن': 86,
#  'تاريخ': 87,
#  'المسلمين': 88,
#  'الأقباط': 89,
#  'امتد': 90,
#  'معاً': 91,
#  'العصر': 92,
#  'الحديث': 93,
#  'حيث': 94,
#  'خاضوا': 95,
#  'الكثير': 96,
#  'الثورات': 97,
#  'مثل': 98,
#  'ثورة': 99,
#  '1919': 100,
#  'المجيدة': 101,
#  'يوليو': 102,
#  '1952': 103,
#  '،': 104,
#  'كنا': 105,
#  'كل': 106,
#  'الحروب': 107,
#  'خصوصا': 108,
#  'حرب': 109,
#  '1973': 110,
#  'التي': 111,
#  'قضى': 112,
#  'ها': 113,
#  'الجيش': 114,
#  'المصري': 115,
#  'على': 116,
#  'أسطورة': 117,
#  'الإسرائيلي': 118,
#  '1987': 119,
#  '-': 120,
#  'وفاة': 121,
#  'الرئيس': 122,
#  'اللبناني': 123,
#  'كميل': 124,
#  'شمعون': 125,
#  'انتهى': 126,
#  'تقرير': 127,
#  'مفوضي': 128,
#  'الدولة': 129,
#  'قضية': 130,
#  'مولد': 131,
#  'أبو': 132,
#  'حصيرة': 133,
#  'البحيرة': 134,
#  'تباينت': 135,
#  'ردود': 136,
#  'الفعل': 137,
#  'حول': 138,
#  'اتجاه': 139,
#  'البنوك': 140,
#  'المصرية': 141,
#  'خفض': 142,
#  'سعر': 143,
#  'الفائدة': 144,
#  'الإيداعات': 145,
#  'اعتبر': 146,
#  'الموافقون': 147,
#  'أن': 148,
#  'الوسيلة': 149,
#  'الوحيدة': 150,
#  'إنعاش': 151,
#  'حركة': 152,
#  'الاستثمار': 153,
#  'شهدت': 154,
#  'تراجعا': 155,
#  'كبيراً': 156,
#  'خلال': 157,
#  'العام': 158,
#  'الماضي': 159,
#  'إنقاذ': 160,
#  'تزايد': 161,
#  'نسب': 162,
#  'السيولة': 163,
#  'الودائع': 164,
#  'المحلية': 165,
#  'الأجنبية': 166,
#  'بينما': 167,
#  'يرى': 168,
#  'المعترضون': 169,
#  'تخفيض': 170,
#  'زيادة': 171,
#  'الدولرة': 172,
#  'ارتفاع': 173,
#  'نسبة': 174,
#  'التضخم': 175,
#  'أدت': 176,
#  'إلى': 177,
#  'تعميق': 178,
#  'الركود': 179,
#  'الأسواق': 180,
#  'يضيف': 181,
#  'ثابت': 182,
#  'بين': 183,
#  'المعوقات': 184,
#  'تعوق': 185,
#  'التجارة': 186,
#  'البلدين': 187,
#  'مشكلة': 188,
#  'الاعتمادات': 189,
#  'المستندية': 190,
#  'مؤكدا': 191,
#  'أنسب': 192,
#  'طرق': 193,
#  'التعامل': 194,
#  'السوق': 195,
#  'السوداني': 196,
#  'تبادل': 197,
#  'سلع': 198,
#  'أخرى': 199,
#  'ما': 200,
#  'يطلق': 201,
#  'علي': 202,
#  'نظام': 203,
#  'الأوفست': 204,
#  'الإضافة': 205,
#  'معوقات': 206,
#  'النقل': 207,
#  'الموصلات': 208,
#  'الجمارك': 209,
#  'قد': 210,
#  'نجح': 211,
#  'المتهمون': 212,
#  'الثلاثة': 213,
#  'اكثر': 214,
#  'اربع': 215,
#  'عمليات': 216,
#  'بلغت': 217,
#  'قيمة': 218,
#  'البضائع': 219,
#  'حوالي': 220,
#  '20': 221,
#  'الف': 222,
#  'دينار': 223,
#  'نفس': 224,
#  'الوقت': 225,
#  'صرح': 226,
#  'المستشار': 227,
#  'صيام': 228,
#  'قدمت': 229,
#  'عرضاً': 230,
#  'استضافة': 231,
#  'مقر': 232,
#  'إقليمي': 233,
#  'مكافحة': 234,
#  'غسل': 235,
#  'الأموال': 236,
#  'يخدم': 237,
#  'منطقة': 238,
#  'الشرق': 239,
#  'الأوسط': 240,
#  'شمال': 241,
#  'أفريقيا': 242,
#  'قال': 243,
#  'المنظمة': 244,
#  'تبحث': 245,
#  'حالياً': 246,
#  'العرض': 247,
#  'بلغ': 248,
#  'حجم': 249,
#  'التهرب': 250,
#  'الضريبي': 251,
#  'مليار': 252,
#  'جنيه': 253,
#  '(': 254,
#  '3.2': 255,
#  'دولار': 256,
#  ')': 257,
#  '2003': 258,
#  'إحالة': 259,
#  'يقرب': 260,
#  '15': 261,
#  'ألف': 262,
#  'شخص': 263,
#  'نيابة': 264,
#  'تمهيدا': 265,
#  'هم': 266,
#  'محكمة': 267,
#  'عاجلة': 268,
#  'عكست': 269,
#  'المواقف': 270,
#  'الايرانية': 271,
#  'السورية': 272,
#  'محادثات': 273,
#  'خدام': 274,
#  'طهران': 275,
#  'توقع': 276,
#  'تصعيد': 277,
#  'اسرائيلي': 278,
#  'واسع': 279,
#  'المنطقة': 280,
#  'رأى': 281,
#  'خاتمي': 282,
#  'ان': 283,
#  '»': 284,
#  'أي': 285,
#  'عشوائي': 286,
#  'غير': 287,
#  'منطقي': 288,
#  'الكيان': 289,
#  'الصهيوني': 290,
#  'لن': 291,
#  'يخرج': 292,
#  'أزمة': 293,
#  '«': 294,
#  'زاد': 295,
#  'بلاد': 296,
#  'تبقى': 297,
#  'الى': 298,
#  'جانب': 299,
#  'سورية': 300,
#  'الشعب': 301,
#  'الفلسطيني': 302,
#  'اتساع': 303,
#  'الجرائم': 304,
#  'الاسرائيلية': 305,
#  'يزيد': 306,
#  'الانتفاضة': 307,
#  'اشتعالاً': 308,
#  'نوه': 309,
#  'مواقف': 310,
#  'دمشق': 311,
#  'تطورات': 312,
#  'كما': 313,
#  'حجز': 314,
#  'اللاعب': 315,
#  'أحمد': 316,
#  'عدلي': 317,
#  'مدرب': 318,
#  'حسن': 319,
#  'مستشفيات': 320,
#  'اليونان': 321,
#  'أثناء': 322,
#  'رحلة': 323,
#  'العودة': 324,
#  'تأتي': 325,
#  'ك': 326,
#  'فرص': 327,
#  'كثيرة': 328,
#  'يمكن': 329,
#  'إحراز': 330,
#  'مبلغ': 331,
#  'جيد': 332,
#  'المال': 333,
#  'تساءلت': 334,
#  'المصادر': 335,
#  'اذا': 336,
#  'كان': 337,
#  'هذا': 338,
#  'وضع': 339,
#  'العلاقات': 340,
#  'الاميركية': 341,
#  'ف': 342,
#  'ماذا': 343,
#  'افتعال': 344,
#  'الخوف': 345,
#  'رهان': 346,
#  'بعض': 347,
#  'المسيحيين': 348,
#  'واشنطن': 349,
#  'دام': 350,
#  'رهانا': 351,
#  'فاشلا': 352,
#  'سواء': 353,
#  'خلاف': 354,
#  'سوري': 355,
#  'اميركي': 356,
#  'او': 357,
#  'نجاح': 358,
#  'الهجمة': 359,
#  'العراق': 360,
#  'تصبح': 361,
#  'سوريا': 362,
#  'هي': 363,
#  'الهدف': 364,
#  'اللاحق': 365,
#  'احد': 366,
#  'لا': 367,
#  'التكهن': 368,
#  'تكون': 369,
#  'بعد': 370,
#  'الحملة': 371,
#  'حتى': 372,
#  'الاميركيون': 373,
#  'أنفس': 374,
#  'يراهن': 375,
#  'المجهول': 376,
#  'يحسب': 377,
#  'حسابا': 378,
#  'خطإ': 379,
#  'يحل': 380,
#  '؟': 381,
#  'موسكو': 382,
#  '8': 383,
#  'اف': 384,
#  'نقلت': 385,
#  'وكالة': 386,
#  'انترفاكس': 387,
#  'الأنباء': 388,
#  'عن': 389,
#  'الاميرال': 390,
#  'فلاديمير': 391,
#  'كوروييدوف': 392,
#  'قائد': 393,
#  'البحرية': 394,
#  'الروسية': 395,
#  'قول': 396,
#  'تامل': 397,
#  'البدء': 398,
#  'عملية': 399,
#  'انقاذ': 400,
#  'افراد': 401,
#  'طاقم': 402,
#  'الغواصة': 403,
#  'كورسك': 404,
#  'مساء': 405,
#  'اليوم': 406,
#  'الثلاثاء': 407,
#  'طريق': 408,
#  'انزال': 409,
#  'كبسولة': 410,
#  'شكل': 411,
#  'جرس': 412,
#  'تحط': 413,
#  'ظهر': 414,
#  'المنكوبة': 415,
#  'أشار': 416,
#  'وزير': 417,
#  'الخارجية': 418,
#  'الالمانى': 419,
#  'يوشكا': 420,
#  'فيشر': 421,
#  'المؤتمر': 422,
#  'الاول': 423,
#  'قوة': 424,
#  'تثبيت': 425,
#  'الاستقرار': 426,
#  'فى': 427,
#  'لندن': 428,
#  'ذٰلك': 429,
#  'هامش': 430,
#  'المجلس': 431,
#  'الرسمى': 432,
#  'كستللوريزو': 433,
#  'نا': 434,
#  'دراية': 435,
#  'أبلغنا': 436,
#  'تقدم': 437,
#  'نتائج': 438,
#  'مضيفا': 439,
#  'لم': 440,
#  'يكن': 441,
#  'سرا': 442,
#  'يقول': 443,
#  'التقرير': 444,
#  'الارقام': 445,
#  'أوردت': 446,
#  'شركة': 447,
#  'بريتش': 448,
#  'بيتروليوم': 449,
#  'بي': 450,
#  'تثبت': 451,
#  'الامر': 452,
#  'جلي': 453,
#  'احتياطات': 454,
#  'النفط': 455,
#  'المؤكدة': 456,
#  'عام': 457,
#  '1978': 458,
#  '648.3': 459,
#  'برميل': 460,
#  'الخام': 461,
#  'كانت': 462,
#  'حصة': 463,
#  'افريقيا': 464,
#  '405.7': 465,
#  'يعادل': 466,
#  '63': 467,
#  '%': 468,
#  'ارتفعت': 469,
#  'هذه': 470,
#  'الاحتياطات': 471,
#  '1988': 472,
#  'تصل': 473,
#  '917.8': 474,
#  'الا': 475,
#  'الاخرى': 476,
#  '66': 477,
#  '608.1': 478,
#  'أجرى': 479,
#  'المسئولون': 480,
#  'اتفاقاً': 481,
#  'مبدئياً': 482,
#  'جمعية': 483,
#  'الأعمال': 484,
#  'الفرنسية': 485,
#  'التعاون': 486,
#  'تصدير': 487,
#  'المنتجات': 488,
#  'دول': 489,
#  'غرب': 490,
#  'سخانات': 491,
#  'المياه': 492,
#  'عدادات': 493,
#  'سيارات': 494,
#  'الأجرة': 495,
#  'الثلاجات': 496,
#  'المبردات': 497,
#  'المضخات': 498,
#  'الهوائية': 499,
#  'أسلاك': 500,
#  'النحاس': 501,
#  'تعليق': 502,
#  'الدبلوماسية': 503,
#  'الرحلات': 504,
#  'الجوية': 505,
#  'الهند': 506,
#  'باكستان': 507,
#  'اعقاب': 508,
#  'هجوم': 509,
#  'ارهابى': 510,
#  'مبنى': 511,
#  'البرلمان': 512,
#  'الهندى': 513,
#  'ديسمبر': 514,
#  '2001': 515,
#  'حملت': 516,
#  'المتطرفين': 517,
#  'الدينيين': 518,
#  'مسؤولية': 519,
#  'الهجوم': 520,
#  'قائلة': 521,
#  'يحظون': 522,
#  'رعاية': 523,
#  'اسلام': 524,
#  'اباد': 525,
#  'بيد': 526,
#  'نفت': 527,
#  'صلة': 528,
#  'الحادث': 529,
#  'الهضيبي': 530,
#  'الحالة': 531,
#  'وصلت': 532,
#  'إلي': 533,
#  'الأحوال': 534,
#  'عربية': 535,
#  'إسلامية': 536,
#  'تستدعي': 537,
#  'تضافر': 538,
#  'الجهود': 539,
#  'وحدة': 540,
#  'الصف': 541,
#  'إتقان': 542,
#  'الحوار': 543,
#  'الحضاري': 544,
#  'تحمل': 545,
#  'الشدائد': 546,
#  'تمضي': 547,
#  'المسيرة': 548,
#  'الطريق': 549,
#  'ذلك': 550,
#  'يتطلب': 551,
#  'إخلاص': 552,
#  'النية': 553,
#  'الوجهة': 554,
#  'شحذ': 555,
#  'العزم': 556,
#  'العزائم': 557,
#  'الصبر': 558,
#  'وعثاء': 559,
#  'مفروش': 560,
#  'الورود': 561,
#  'يوم': 562,
#  'نسعى': 563,
#  'تحقيق': 564,
#  'المستوى': 565,
#  'الإيمان': 566,
#  'الفهم': 567,
#  'العمل': 568,
#  'مستوى': 569,
#  'أفراد': 570,
#  'عائلات': 571,
#  'لبنات': 572,
#  'المجتمع': 573,
#  'شعب': 574,
#  'رسالة': 575,
#  'غاية': 576,
#  'تظهر': 577,
#  'الأمة': 578,
#  'يرتفع': 579,
#  'صوت': 580,
#  'تعلن': 581,
#  'كلمة': 582,
#  'كمية': 583,
#  'التعاقد': 584,
#  'تبلغ': 585,
#  '35': 586,
#  'متر': 587,
#  'مربع': 588,
#  'ساعد': 589,
#  'قريباً': 590,
#  'أو': 591,
#  'صديقاً': 592,
#  'مقرباً': 593,
#  'إعداد': 594,
#  'ميزانية': 595,
#  'أكد': 596,
#  'الوزير': 597,
#  'افتتاح': 598,
#  'عدم': 599,
#  'توافر': 600,
#  'حصر': 601,
#  'دقيق': 602,
#  'المخازن': 603,
#  'العمومية': 604,
#  'الفرعية': 605,
#  'التابعة': 606,
#  'وحدات': 607,
#  'الجهاز': 608,
#  'الإداري': 609,
#  'شدد': 610,
#  'الأسعار': 611,
#  'شماعة': 612,
#  'الدولار': 613,
#  'مقبولاً': 614,
#  'لاسيما': 615,
#  'ظل': 616,
#  'التراجع': 617,
#  'المستمر': 618,
#  'الرسمية': 619,
#  'انخفاض': 620,
#  'نحو': 621,
#  '650': 622,
#  'قرشا': 623,
#  'أقل': 624,
#  'شهر': 625,
#  'عمان': 626,
#  '3': 627,
#  'مايو': 628,
#  'بداية': 629,
#  'اعمال': 630,
#  'الشغب': 631,
#  'اندلعت': 632,
#  'اثر': 633,
#  'اشتباك': 634,
#  'الاردني': 635,
#  'اسماعيل': 636,
#  'بني': 637,
#  'هاني': 638,
#  'لاعب': 639,
#  'اماراتي': 640,
#  'قرب': 641,
#  'غرف': 642,
#  'تبديل': 643,
#  'الملابس': 644,
#  'غادر': 645,
#  'ارض': 646,
#  'الملعب': 647,
#  'جلس': 648,
#  'المدرجات': 649,
#  'الشوط': 650,
#  'احتجاجا': 651,
#  'استبدال': 652,
#  'فيلم': 653,
#  'تسجيلي': 654,
#  'تركي': 655,
#  'اول': 656,
#  'طيران': 657,
#  'عثمانية': 658,
#  'فوق': 659,
#  'الشام': 660,
#  'ومصر': 661,
#  'مارسيل': 662,
#  'نصر': 663,
#  'شيع': 664,
#  'مئات': 665,
#  'الأردنيين': 666,
#  'جثمان': 667,
#  'رجل': 668,
#  'الأمن': 669,
#  'الذى': 670,
#  'قتل': 671,
#  'الانفجار': 672,
#  'وقع': 673,
#  'مطار': 674,
#  'امس': 675,
#  'الخميس': 676,
#  'الناجم': 677,
#  'عبوة': 678,
#  'مخلفات': 679,
#  'الحرب': 680,
#  'اثناء': 681,
#  'قيام': 682,
#  'تفتيش': 683,
#  'حقيبة': 684,
#  'مسافر': 685,
#  'يابانى': 686,
#  'قطعة': 687,
#  'الذخيرة': 688,
#  'مضى': 689,
#  'يزال': 690,
#  'هناك': 691,
#  'تحسين': 692,
#  'اداء': 693,
#  'تصرفات': 694,
#  'الاطراف': 695,
#  'يجب': 696,
#  'بذل': 697,
#  'جهود': 698,
#  'منسقة': 699,
#  'التقدم': 700,
#  'الامام': 701,
#  'روبرت': 702,
#  'مردوخ': 703,
#  'يوسع': 704,
#  'حدود': 705,
#  'إمبراطورية': 706,
#  'الاعلامية': 707,
#  'الولايات': 708,
#  'المتحدة': 709,
#  'نافتيج': 710,
#  'سارنا': 711,
#  'المتحدث': 712,
#  'اسم': 713,
#  'الشئون': 714,
#  'وسائل': 715,
#  'الإعلام': 716,
#  'هنا': 717,
#  'ساعات': 718,
#  'تلقى': 719,
#  'دعوة': 720,
#  'رسمية': 721,
#  'نظير': 722,
#  'الباكستانى': 723,
#  'مير': 724,
#  'ظفرالله': 725,
#  'خان': 726,
#  'جمالى': 727,
#  'القيام': 728,
#  'زيارة': 729,
#  'عاود': 730,
#  'فاجبايى': 731,
#  'الكتابة': 732,
#  'قائلا': 733,
#  'الاستعدادات': 734,
#  'المتأنية': 735,
#  'مطلوبة': 736,
#  'مشاركة': 737,
#  'هادفة': 738,
#  'أعلى': 739,
#  'طلبت': 740,
#  'السياحية': 741,
#  'السياحة': 742,
#  'الموافقة': 743,
#  'أسعار': 744,
#  'الحج': 745,
#  'السياحي': 746,
#  '40': 747,
#  'أرجعت': 748,
#  'صرف': 749,
#  'المرة': 750,
#  'الثالثة': 751,
#  'سنوات': 752,
#  'تتهم': 753,
#  'بغداد': 754,
#  'استمرار': 755,
#  'بريطانيا': 756,
#  'تجميد': 757,
#  'عقود': 758,
#  'الغذائية': 759,
#  'الأدوية': 760,
#  'كذٰلك': 761,
#  'قطع': 762,
#  'الغيار': 763,
#  'الضرورية': 764,
#  'الصناعة': 765,
#  'النفطية': 766,
#  'المتضررة': 767,
#  'الخليج': 768,
#  '1991': 769,
#  'المعتقد': 770,
#  'امروزى': 771,
#  'المنسق': 772,
#  'الميدانى': 773,
#  'الهجمات': 774,
#  'تقرر': 775,
#  'محاكمة': 776,
#  '12': 777,
#  'مساهمة': 778,
#  'إيطاليا': 779,
#  'رؤوس': 780,
#  'المصدرة': 781,
#  '31': 782,
#  '2002': 783,
#  'المشروعات': 784,
#  'الاستثمارية': 785,
#  '122.9': 786,
#  'مليون': 787,
#  'إجمالي': 788,
#  'التكلفة': 789,
#  '386': 790,
#  'الاسد': 791,
#  'القرار': 792,
#  '1559': 793,
#  'يهدف': 794,
#  'تدويل': 795,
#  'الملف': 796,
#  'إحداث': 797,
#  'قطيعة': 798,
#  'لبنان': 799,
#  'المتربطان': 800,
#  'مشترك': 801,
#  'أعمال': 802,
#  'بنك': 803,
#  'الإسكندرية': 804,
#  'تراجع': 805,
#  'صافي': 806,
#  'أرباح': 807,
#  '13.3': 808,
#  'سجل': 809,
#  '65': 810,
#  'مقارنة': 811,
#  '75': 812,
#  'يأتي': 813,
#  'الأرباح': 814,
#  'العائد': 815,
#  'المصرفي': 816,
#  '23': 817,
#  'يحقق': 818,
#  '142': 819,
#  'عوض': 820,
#  'الارتفاع': 821,
#  'عمولات': 822,
#  'أتعاب': 823,
#  'الخدمات': 824,
#  'المصرفية': 825,
#  '314': 826,
#  'نمو': 827,
#  '14': 828,
#  'حين': 829,
#  'تتعد': 830,
#  'إيرادات': 831,
#  'العمليات': 832,
#  'الأخرى': 833,
#  'المخصصات': 834,
#  'المكونة': 835,
#  '237': 836,
#  '248': 837,
#  'ارتفع': 838,
#  'أصول': 839,
#  '26': 840,
#  '33': 841,
#  'نتيجة': 842,
#  'تعكس': 843,
#  'أوضاع': 844,
#  'اكستريور': 845,
#  'الحالية': 846,
#  'كشفت': 847,
#  'التسعة': 848,
#  'أشهر': 849,
#  'الأولى': 850,
#  'المالي': 851,
#  'خسائر': 852,
#  '151': 853,
#  '45': 854,
#  'تتضمن': 855,
#  'فترة': 856,
#  'عائد': 857,
#  'القروض': 858,
#  'الأرصدة': 859,
#  'لدى': 860,
#  'يبلغ': 861,
#  '991.6': 862,
#  'أذون': 863,
#  'الخزانة': 864,
#  'السندات': 865,
#  'قدر': 866,
#  '65.52': 867,
#  'يصل': 868,
#  'الفوائد': 869,
#  '157.114': 870,
#  'تكلفة': 871,
#  'الاقتراض': 872,
#  '307': 873,
#  'ملايين': 874,
#  'مما': 875,
#  'أدى': 876,
#  'عجز': 877,
#  'العوائد': 878,
#  'الفترة': 879,
#  'رصد': 880,
#  'البيان': 881,
#  'ارتفاعاً': 882,
#  'الناتج': 883,
#  'المحلي': 884,
#  'الإجمالي': 885,
#  '/': 886,
#  '35.9': 887,
#  'سبق': 888,
#  'متوقعا': 889,
#  'القادم': 890,
#  '450': 891,
#  'مماثلة': 892,
#  'علم': 893,
#  'مصادر': 894,
#  'بيروت': 895,
#  'طائرة': 896,
#  'خاصة': 897,
#  'نوع': 898,
#  'بوينغ': 899,
#  '720': 900,
#  'استاجرتها': 901,
#  'السفارة': 902,
#  'الليبية': 903,
#  'اقلت': 904,
#  'الوفد': 905,
#  'عددا': 906,
#  'الصحافيين': 907,
#  'اضافة': 908,
#  'والدة': 909,
#  'الرهينة': 910,
#  'حذرت': 911,
#  'تركيا': 912,
#  'إسرائيل': 913,
#  'مواصلة': 914,
#  'التنقيب': 915,
#  'يشأ': 916,
#  'الوزراء': 917,
#  'الاسرائيلي': 918,
#  'الاستماع': 919,
#  'آراء': 920,
#  'الدوما': 921,
#  'غينادي': 922,
#  'سيليزينوف': 923,
#  'المنتمي': 924,
#  'جبهة': 925,
#  'القوى': 926,
#  'اليسارية': 927,
#  'المطالبة': 928,
#  'قرارات': 929,
#  'مجلس': 930,
#  'الرافضة': 931,
#  'تلبؤ': 932,
#  'اسرائيل': 933,
#  'موقعاً': 934,
#  'الشرعية': 935,
#  'الدولية': 936,
#  'هدف': 937,
#  'التغطية': 938,
#  'الفضائح': 939,
#  'عقد': 940,
#  'شارون': 941,
#  'عشية': 942,
#  'مغادرة': 943,
#  'لقاءات': 944,
#  'صحافية': 945,
#  'اكد': 946,
#  'الزيارة': 947,
#  'اتفق': 948,
#  'القيادة': 949,
#  'قضايا': 950,
#  'لجنة': 951,
#  'الارهاب': 952,
#  'شدة': 953,
#  'اللجنة': 954,
#  'رغم': 955,
#  'تنفي': 956,
#  'احتمال': 957,
#  'معلومات': 958,
#  'ذات': 959,
#  'طابع': 960,
#  'أمني': 961,
#  'ضمن': 962,
#  'الأطر': 963,
#  'المتعارف': 964,
#  'عدة': 965,
#  'البلدان': 966,
#  'العربية': 967,
#  'أجّلت': 968,
#  'الحكومة': 969,
#  'اجل': 970,
#  'مسمى': 971,
#  'طرح': 972,
#  'أسهم': 973,
#  'الحكومية': 974,
#  'البورصات': 975,
#  'استعادة': 976,
#  'الاقتصاد': 977,
#  'الدولي': 978,
#  'عافية': 979,
#  'أحداث': 980,
#  'أيلول': 981,
#  'سبتمبر': 982,
#  'عمر': 983,
#  'جستنية': 984,
#  'النور': 985,
#  'جاء': 986,
#  'بيان': 987,
#  'صدر': 988,
#  'الاجتماع': 989,
#  'الجانبين': 990,
#  'أكدا': 991,
#  'حرص': 992,
#  'هما': 993,
#  'الوطني': 994,
#  'الوصول': 995,
#  'النتائج': 996,
#  'تحقق': 997,
#  'مصلحة': 998,
#  'الوطن': 999,
#  'الاتفاق': 1000,
#  'اجتماع': 1001,
#  ...}

# %%
tag_counter = Counter(tag for tags in pos_tags_train for tag in tags)
tag_to_index = {tag: idx + 1 for idx, tag in enumerate(tag_counter)}
tag_to_index['<PAD>'] = 0

# %%
tag_to_index
# Out:
# {'VERB': 1,
#  'NOUN': 2,
#  'ADJ': 3,
#  'ADP': 4,
#  'X': 5,
#  'PUNCT': 6,
#  'CCONJ': 7,
#  'PRON': 8,
#  'NUM': 9,
#  'DET': 10,
#  'AUX': 11,
#  'PART': 12,
#  'ADV': 13,
#  'SCONJ': 14,
#  'SYM': 15,
#  'PROPN': 16,
#  'INTJ': 17,
#  '<PAD>': 0}

# %%
max_len = max(max(len(s) for s in sentences_train), max(len(s) for s in sentences_test))
X_train = [[token_to_index.get(token, token_to_index['<UNK>']) for token in tokens] for tokens in sentences_train]
X_train = np.array([np.pad(x, (0, max_len - len(x)), mode='constant') for x in X_train])
y_train = [[tag_to_index[tag] for tag in tags] for tags in pos_tags_train]
y_train = np.array([np.pad(t, (0, max_len - len(t)), mode='constant') for t in y_train])
#y_train = y_train[..., np.newaxis]

X_test = [[token_to_index.get(token, token_to_index['<UNK>']) for token in tokens] for tokens in sentences_test]
X_test = np.array([np.pad(x, (0, max_len - len(x)), mode='constant') for x in X_test])
y_test = [[tag_to_index[tag] for tag in tags] for tags in pos_tags_test]
y_test = np.array([np.pad(t, (0, max_len - len(t)), mode='constant') for t in y_test])
#y_test = y_test[..., np.newaxis]

# %%
y_test
# Out:
# array([[ 7,  1,  2, ...,  0,  0,  0],
#        [ 4,  2, 12, ...,  0,  0,  0],
#        [ 7,  1,  2, ...,  0,  0,  0],
#        ...,
#        [ 2,  2,  3, ...,  0,  0,  0],
#        [ 7,  1,  2, ...,  0,  0,  0],
#        [ 1,  2,  3, ...,  0,  0,  0]])

# %% [markdown]
# ### Modelling

# %%
embedding_dim = 128
hidden_units = 64
num_tags = len(tag_to_index)

# %%
model = Sequential([
    Embedding(input_dim=len(token_to_index), output_dim=embedding_dim, input_length=max_len, mask_zero=True),
    Bidirectional(LSTM(units=hidden_units, return_sequences=True, dropout=0.5, recurrent_dropout=0.5)),
    TimeDistributed(Dense(units=num_tags, activation='softmax'))
])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 398, 128)          2675328
#
#  bidirectional (Bidirectiona  (None, 398, 128)         98816
#  l)
#
#  time_distributed (TimeDistr  (None, 398, 18)          2322
#  ibuted)
#
# =================================================================
# Total params: 2,776,466
# Trainable params: 2,776,466
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, batch_size=256, epochs=4, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/4
# 20/20 [==============================] - 175s 8s/step - loss: 0.2139 - accuracy: 0.3308 - val_loss: 0.2064 - val_accuracy: 0.3316
# Epoch 2/4
# 20/20 [==============================] - 167s 8s/step - loss: 0.1942 - accuracy: 0.3345 - val_loss: 0.1937 - val_accuracy: 0.3333
# Epoch 3/4
# 20/20 [==============================] - 183s 9s/step - loss: 0.1795 - accuracy: 0.3733 - val_loss: 0.1724 - val_accuracy: 0.4968
# Epoch 4/4
# 20/20 [==============================] - 172s 9s/step - loss: 0.1517 - accuracy: 0.5401 - val_loss: 0.1331 - val_accuracy: 0.6086

# %% [markdown]
# #### Evaluation

# %% [markdown]
# **Evaluation metric:**
# Accuracy

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose=1)
print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# 19/19 [==============================] - 16s 849ms/step - loss: 0.1268 - accuracy: 0.6032
# Test Accuracy: 0.6032

# %% [markdown]
# ### Enhancement

# %% [markdown]
# ### Conclusion and final results

# %% [markdown]
# #### Done!
